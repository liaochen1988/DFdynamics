# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.interpolate import CubicSpline
from sklearn.metrics import mean_squared_error
import warnings
import itertools
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
import scipy.stats.kde as kde

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#             A2         ASF356  Acetatifactor  Acetatifactor_dash_muris  \
# SampleID
# sample131  0.0  108301.701888    7101.750943                       0.0
# sample132  0.0  405068.034693   50064.588558                       0.0
# sample133  0.0   36169.603950   45332.570284                       0.0
# sample134  0.0  484302.054587   10150.043060                       0.0
# sample135  0.0   91489.970533   42374.302141                       0.0
#
#            Acidovorax  Acinetobacter  \
# SampleID
# sample131         0.0            0.0
# sample132         0.0            0.0
# sample133         0.0            0.0
# sample134         0.0            0.0
# sample135         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample131                                                0.0
# sample132                                                0.0
# sample133                                                0.0
# sample134                                                0.0
# sample135                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample131                       0.0                       0.000000
# sample132                       0.0                       0.000000
# sample133                       0.0                       0.000000
# sample134                       0.0                       0.000000
# sample135                       0.0                   12519.680178
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample131                       0.0  ...
# sample132                       0.0  ...
# sample133                       0.0  ...
# sample134                       0.0  ...
# sample135                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample131                                                0.0
# sample132                                                0.0
# sample133                                                0.0
# sample134                                                0.0
# sample135                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample131                                       63028.039623
# sample132                                       80103.341692
# sample133                                           0.000000
# sample134                                      105850.449056
# sample135                                           0.000000
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample131                                                0.0
# sample132                                                0.0
# sample133                                                0.0
# sample134                                                0.0
# sample135                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample131                                                0.0
# sample132                                                0.0
# sample133                                                0.0
# sample134                                                0.0
# sample135                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample131                                                0.0
# sample132                                                0.0
# sample133                                                0.0
# sample134                                                0.0
# sample135                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample131        165115.709436                             0.0
# sample132        106501.033841                             0.0
# sample133        221840.237562                             0.0
# sample134        919303.900024                             0.0
# sample135        581683.602124                             0.0
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample131                     0.0         0.0                    1.322701e+05
# sample132                     0.0         0.0                    1.003112e+06
# sample133                     0.0         0.0                    1.866352e+05
# sample134                     0.0         0.0                    8.714537e+05
# sample135                     0.0         0.0                    5.335310e+05
#
# [5 rows x 304 columns]

# %% [markdown]
# # Add pseudocount for zeros

# %%
for sample_id in df_16S.index:
    sample = np.array(df_16S.loc[sample_id])
    minval = np.min(sample[np.nonzero(sample)]) # minimum non-zero value
    sample[sample==0] = minval
    df_16S.loc[sample_id] = sample
df_16S.head()
# Out:
#                     A2         ASF356  Acetatifactor  \
# SampleID
# sample131   887.718868  108301.701888    7101.750943
# sample132   910.265247  405068.034693   50064.588558
# sample133   482.261386   36169.603950   45332.570284
# sample134  2900.012303  484302.054587   10150.043060
# sample135  1926.104643   91489.970533   42374.302141
#
#            Acetatifactor_dash_muris   Acidovorax  Acinetobacter  \
# SampleID
# sample131                887.718868   887.718868     887.718868
# sample132                910.265247   910.265247     910.265247
# sample133                482.261386   482.261386     482.261386
# sample134               2900.012303  2900.012303    2900.012303
# sample135               1926.104643  1926.104643    1926.104643
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample131                                         887.718868
# sample132                                         910.265247
# sample133                                         482.261386
# sample134                                        2900.012303
# sample135                                        1926.104643
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample131                887.718868                     887.718868
# sample132                910.265247                     910.265247
# sample133                482.261386                     482.261386
# sample134               2900.012303                    2900.012303
# sample135               1926.104643                   12519.680178
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample131                887.718868  ...
# sample132                910.265247  ...
# sample133                482.261386  ...
# sample134               2900.012303  ...
# sample135               1926.104643  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample131                                         887.718868
# sample132                                         910.265247
# sample133                                         482.261386
# sample134                                        2900.012303
# sample135                                        1926.104643
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample131                                       63028.039623
# sample132                                       80103.341692
# sample133                                         482.261386
# sample134                                      105850.449056
# sample135                                        1926.104643
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample131                                         887.718868
# sample132                                         910.265247
# sample133                                         482.261386
# sample134                                        2900.012303
# sample135                                        1926.104643
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample131                                         887.718868
# sample132                                         910.265247
# sample133                                         482.261386
# sample134                                        2900.012303
# sample135                                        1926.104643
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample131                                         887.718868
# sample132                                         910.265247
# sample133                                         482.261386
# sample134                                        2900.012303
# sample135                                        1926.104643
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample131        165115.709436                      887.718868
# sample132        106501.033841                      910.265247
# sample133        221840.237562                      482.261386
# sample134        919303.900024                     2900.012303
# sample135        581683.602124                     1926.104643
#
#            marine_dash_metagenome   metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample131              887.718868   887.718868                    1.322701e+05
# sample132              910.265247   910.265247                    1.003112e+06
# sample133              482.261386   482.261386                    1.866352e+05
# sample134             2900.012303  2900.012303                    8.714537e+05
# sample135             1926.104643  1926.104643                    5.335310e+05
#
# [5 rows x 304 columns]

# %% [markdown]
# # Read metadata for rs and control

# %%
df_meta = pd.read_excel('../../../../../data/meta_data.xlsx', index_col=0)
df_meta = df_meta[(df_meta.Diet=='Resistant starch') | (df_meta.Diet=='Control')]
df_meta['Diet'] = [1 if g=='Resistant starch' else 0 for g in df_meta['Diet']]
df_meta.head()
# Out:
#           MiceID   Vendor  Day  Diet
# SampleID
# sample131    BC1  Beijing    0     0
# sample132    BC2  Beijing    0     0
# sample133    BC3  Beijing    0     0
# sample134    BC4  Beijing    0     0
# sample135    BC5  Beijing    0     0

# %% [markdown]
# # Select the 20 most abundant taxa

# %%
topX = 20
df_16S_T = df_16S.loc[df_meta.index].T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Faecalibaculum  Bacteroides_dash_acidifaciens  \
# SampleID
# sample131    2.178906e+07    2.175266e+07                   1.682227e+06
# sample132    2.539822e+07    1.732963e+07                   4.455748e+06
# sample133    1.379895e+07    1.250166e+07                   1.339240e+06
# sample134    3.867746e+07    2.484296e+07                   1.024574e+07
# sample135    1.994192e+07    1.935254e+07                   4.775776e+06
#
#            Lachnospiraceae_dash_NK4A136_dash_group  \
# SampleID
# sample131                             2.719971e+06
# sample132                             3.721164e+06
# sample133                             7.354486e+05
# sample134                             4.120917e+06
# sample135                             1.094990e+06
#
#            Parabacteroides_dash_goldsteinii   Bacteroides  Lachnospiraceae  \
# SampleID
# sample131                     103863.107548  3.826068e+05     3.380433e+06
# sample132                      59167.241023  2.645231e+06     4.563160e+06
# sample133                      46297.093056  7.802989e+05     7.508810e+05
# sample134                     184150.781235  4.157168e+06     8.172235e+06
# sample135                      72228.924105  1.040097e+06     1.251005e+06
#
#            Alloprevotella  Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SampleID
# sample131    9.717858e+06                                   1.012000e+05
# sample132    2.849130e+05                                   7.898372e+06
# sample133    1.040238e+06                                   2.083369e+05
# sample134    3.694616e+06                                   1.566007e+05
# sample135    1.814391e+06                                   6.067230e+04
#
#            Desulfovibrionaceae  Parasutterella  Akkermansia_dash_muciniphila  \
# SampleID
# sample131         1.819824e+05    2.213083e+06                  3.771030e+06
# sample132         9.912789e+05    3.591907e+06                  2.610641e+06
# sample133         1.504656e+05    4.753168e+06                  3.729327e+06
# sample134         2.321460e+06    4.982221e+06                  2.262880e+07
# sample135         2.725438e+05    3.164590e+06                  4.727624e+06
#
#            Oscillospiraceae  Rikenellaceae_dash_RC9_dash_gut_dash_group  \
# SampleID
# sample131      6.249541e+05                                6.779509e+06
# sample132      3.932346e+06                                3.418046e+06
# sample133      5.290407e+05                                5.057957e+06
# sample134      5.088072e+06                                2.312180e+07
# sample135      5.441246e+05                                1.064558e+07
#
#            Lachnospiraceae_dash_bacterium_dash_10_dash_1  \
# SampleID
# sample131                                  674666.339629
# sample132                                   90116.259404
# sample133                                   21701.762370
# sample134                                  511852.171464
# sample135                                   42374.302141
#
#            Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# SampleID
# sample131                                        7101.750943
# sample132                                       10012.917712
# sample133                                        4822.613860
# sample134                                       21750.092272
# sample135                                        1926.104643
#
#            Helicobacter_dash_ganmani  Mucispirillum_dash_schaedleri  \
# SampleID
# sample131                5326.313208                   2.008020e+06
# sample132               11833.448205                   1.345281e+07
# sample133                5304.875246                   4.054854e+06
# sample134               20300.086120                   5.086622e+06
# sample135                6741.366250                   7.617744e+05
#
#            Clostridia_dash_vadinBB60_dash_group     Alistipes
# SampleID
# sample131                         470491.000005  1.064375e+06
# sample132                         142911.643701  1.247063e+06
# sample133                         175060.883119  1.064833e+06
# sample134                         194300.824295  8.069284e+06
# sample135                          45263.459106  2.844857e+06

# %%
list(df_16S_topX.columns)
# Out:
# ['Muribaculaceae',
#  'Faecalibaculum',
#  'Bacteroides_dash_acidifaciens',
#  'Lachnospiraceae_dash_NK4A136_dash_group',
#  'Parabacteroides_dash_goldsteinii',
#  'Bacteroides',
#  'Lachnospiraceae',
#  'Alloprevotella',
#  'Lachnospiraceae_dash_bacterium_dash_28_dash_4',
#  'Desulfovibrionaceae',
#  'Parasutterella',
#  'Akkermansia_dash_muciniphila',
#  'Oscillospiraceae',
#  'Rikenellaceae_dash_RC9_dash_gut_dash_group',
#  'Lachnospiraceae_dash_bacterium_dash_10_dash_1',
#  'Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57',
#  'Helicobacter_dash_ganmani',
#  'Mucispirillum_dash_schaedleri',
#  'Clostridia_dash_vadinBB60_dash_group',
#  'Alistipes']

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX_w_meta = pd.merge(df_meta, df_16S_topX/df_16S_topX.max().max(), left_index=True, right_index=True, how='inner')
df_16S_topX_w_meta.head()
# Out:
#           MiceID   Vendor  Day  Diet  Muribaculaceae  Faecalibaculum  \
# SampleID
# sample131    BC1  Beijing    0     0        0.121890        0.121687
# sample132    BC2  Beijing    0     0        0.142080        0.096944
# sample133    BC3  Beijing    0     0        0.077193        0.069936
# sample134    BC4  Beijing    0     0        0.216366        0.138974
# sample135    BC5  Beijing    0     0        0.111557        0.108260
#
#            Bacteroides_dash_acidifaciens  \
# SampleID
# sample131                       0.009411
# sample132                       0.024926
# sample133                       0.007492
# sample134                       0.057316
# sample135                       0.026716
#
#            Lachnospiraceae_dash_NK4A136_dash_group  \
# SampleID
# sample131                                 0.015216
# sample132                                 0.020817
# sample133                                 0.004114
# sample134                                 0.023053
# sample135                                 0.006125
#
#            Parabacteroides_dash_goldsteinii  Bacteroides  ...  Parasutterella  \
# SampleID                                                  ...
# sample131                          0.000581     0.002140  ...        0.012380
# sample132                          0.000331     0.014798  ...        0.020094
# sample133                          0.000259     0.004365  ...        0.026590
# sample134                          0.001030     0.023256  ...        0.027871
# sample135                          0.000404     0.005818  ...        0.017703
#
#            Akkermansia_dash_muciniphila  Oscillospiraceae  \
# SampleID
# sample131                      0.021096          0.003496
# sample132                      0.014604          0.021998
# sample133                      0.020862          0.002960
# sample134                      0.126588          0.028463
# sample135                      0.026447          0.003044
#
#            Rikenellaceae_dash_RC9_dash_gut_dash_group  \
# SampleID
# sample131                                    0.037925
# sample132                                    0.019121
# sample133                                    0.028295
# sample134                                    0.129346
# sample135                                    0.059553
#
#            Lachnospiraceae_dash_bacterium_dash_10_dash_1  \
# SampleID
# sample131                                       0.003774
# sample132                                       0.000504
# sample133                                       0.000121
# sample134                                       0.002863
# sample135                                       0.000237
#
#            Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# SampleID
# sample131                                           0.000040
# sample132                                           0.000056
# sample133                                           0.000027
# sample134                                           0.000122
# sample135                                           0.000011
#
#            Helicobacter_dash_ganmani  Mucispirillum_dash_schaedleri  \
# SampleID
# sample131                   0.000030                       0.011233
# sample132                   0.000066                       0.075256
# sample133                   0.000030                       0.022683
# sample134                   0.000114                       0.028455
# sample135                   0.000038                       0.004261
#
#            Clostridia_dash_vadinBB60_dash_group  Alistipes
# SampleID
# sample131                              0.002632   0.005954
# sample132                              0.000799   0.006976
# sample133                              0.000979   0.005957
# sample134                              0.001087   0.045140
# sample135                              0.000253   0.015914
#
# [5 rows x 24 columns]

# %% [markdown]
# # Calculate log-derivatives (dlog(B)/dt)

# %%
df_deriv = deepcopy(df_16S_topX_w_meta)
for curr_mice in set(df_deriv.MiceID):
    curr_df = df_deriv[df_deriv.MiceID==curr_mice]
    for taxon in bacterial_taxa:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[taxon])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_deriv.loc[df_deriv.MiceID==curr_mice, taxon] = ydata_d1
df_deriv.head()
# Out:
#           MiceID   Vendor  Day  Diet  Muribaculaceae  Faecalibaculum  \
# SampleID
# sample131    BC1  Beijing    0     0       -0.074386       -0.254233
# sample132    BC2  Beijing    0     0       -0.135226       -0.193439
# sample133    BC3  Beijing    0     0       -0.007883       -0.148905
# sample134    BC4  Beijing    0     0       -0.021238       -0.148056
# sample135    BC5  Beijing    0     0        0.149464       -0.060736
#
#            Bacteroides_dash_acidifaciens  \
# SampleID
# sample131                      -0.004071
# sample132                      -0.036332
# sample133                      -0.022818
# sample134                      -0.078009
# sample135                      -0.009520
#
#            Lachnospiraceae_dash_NK4A136_dash_group  \
# SampleID
# sample131                                -0.004919
# sample132                                 0.017515
# sample133                                 0.000002
# sample134                                 0.054405
# sample135                                 0.043082
#
#            Parabacteroides_dash_goldsteinii  Bacteroides  ...  Parasutterella  \
# SampleID                                                  ...
# sample131                          0.000152     0.091566  ...       -0.029396
# sample132                          0.000315    -0.006180  ...       -0.038113
# sample133                          0.000183     0.069495  ...       -0.065846
# sample134                         -0.000708    -0.014161  ...       -0.021315
# sample135                          0.000137     0.040215  ...       -0.000796
#
#            Akkermansia_dash_muciniphila  Oscillospiraceae  \
# SampleID
# sample131                     -0.032129          0.017712
# sample132                     -0.024804         -0.006381
# sample133                     -0.021541          0.018099
# sample134                     -0.197212          0.027841
# sample135                     -0.034933          0.009670
#
#            Rikenellaceae_dash_RC9_dash_gut_dash_group  \
# SampleID
# sample131                                    0.019519
# sample132                                    0.011125
# sample133                                    0.010002
# sample134                                   -0.042253
# sample135                                   -0.026264
#
#            Lachnospiraceae_dash_bacterium_dash_10_dash_1  \
# SampleID
# sample131                                      -0.005393
# sample132                                       0.000221
# sample133                                      -0.001413
# sample134                                      -0.002511
# sample135                                       0.000484
#
#            Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# SampleID
# sample131                                           0.000088
# sample132                                          -0.000053
# sample133                                          -0.000018
# sample134                                          -0.000173
# sample135                                           0.000010
#
#            Helicobacter_dash_ganmani  Mucispirillum_dash_schaedleri  \
# SampleID
# sample131                   0.006910                      -0.007715
# sample132                   0.093857                      -0.093251
# sample133                   0.019876                      -0.033317
# sample134                   0.000063                      -0.026145
# sample135                   0.000023                       0.007328
#
#            Clostridia_dash_vadinBB60_dash_group  Alistipes
# SampleID
# sample131                             -0.000913   0.039701
# sample132                              0.002053   0.009724
# sample133                              0.021856   0.063697
# sample134                              0.009527  -0.045128
# sample135                              0.004431   0.022808
#
# [5 rows x 24 columns]

# %% [markdown]
# # Construct regression matrix

# %%
# Ymat should be samples by bacteria
Ymat = df_deriv[bacterial_taxa].values
Ymat = Ymat.flatten(order='F')
Ymat = StandardScaler().fit_transform(Ymat.reshape(-1,1)).reshape(1,-1)[0] # standardize
Ymat
# Out:
# array([-2.44202305, -4.44927117, -0.24797056, ...,  0.09420514,
#         0.18872496,  0.10023815])

# %%
len(Ymat)
# Out:
# 7200

# %%
Xmat = np.zeros(shape=(topX*len(df_deriv.index), (topX+2)*topX))
for k in np.arange(topX):
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)] = 1
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+1] = df_deriv.Diet.values
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+2:(k+1)*(topX+2)] = df_16S_topX_w_meta[bacterial_taxa].values
Xmat
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 1.21890330e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.42080364e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 7.71927743e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         8.52639403e-04, 3.11541320e-03, 7.79673146e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.77657663e-04, 1.00598652e-02, 1.67109239e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         8.25431847e-05, 2.60386228e-03, 8.34436558e-03]])

# %% [markdown]
# # Write stan program

# %% [markdown]
# ## write data

# %%
json_str = '{\n"N" : %d,\n'%(len(Ymat))

# y variable
json_str += '\"dlogX\" : [%s],\n'%(','.join(list(Ymat.astype(str))))

# x variable
for k1,c1 in enumerate(bacterial_taxa):
    # growth rate
    json_str += '\"growth_rate_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)].astype(str))))
    # diet response
    json_str += '\"rs_response_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)+1].astype(str))))
    # bacterial interactions
    for k2,c2 in enumerate(bacterial_taxa):
        v = list(Xmat[:,k1*(topX+2)+2+k2].astype(str))
        json_str += '\"pairwise_interaction_%s_%s\" : [%s]'%(c1,c2,','.join(v))
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            json_str += '\n}'
        else:
            json_str += ',\n'
#print(json_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.data.json", "w")
text_file.write("%s" % json_str)
text_file.close()

# %% [markdown]
# ## write model

# %%
# data block
model_str = 'data {\n'
model_str += '\tint<lower=0> N;\n'
model_str += '\tvector[N] dlogX;\n'
for c1 in bacterial_taxa:
    model_str += '\tvector[N] growth_rate_%s;\n'%(c1)
    model_str += '\tvector[N] rs_response_%s;\n'%(c1)
    for c2 in bacterial_taxa:
        model_str += '\tvector[N] pairwise_interaction_%s_%s;\n'%(c1,c2)
model_str += '}\n'

# parameter block
model_str += 'parameters {\n\treal<lower=0,upper=1> sigma;\n'
for c1 in bacterial_taxa:
    model_str += '\treal alpha__%s;\n'%(c1) # growth rate
    model_str += '\treal epsilon__%s;\n'%(c1) # resistance starch response
    for c2 in bacterial_taxa:
        model_str += '\treal beta__%s_%s;\n'%(c1,c2)
model_str += '}\n'       
        
# model block
model_str += 'model {\n\tsigma ~ uniform(0,1);\n'
for c1 in bacterial_taxa:
    model_str += '\talpha__%s ~ normal(0,1);\n'%(c1) # growth rate
    model_str += '\tepsilon__%s ~ normal(0,1);\n'%(c1) # rs response
    for c2 in bacterial_taxa:
        model_str += '\tbeta__%s_%s ~ normal(0,1);\n'%(c1,c2)
model_str += '\tdlogX ~ normal('
for c1 in bacterial_taxa:
    model_str += 'alpha__%s*growth_rate_%s+'%(c1,c1) # growth rate
    model_str += 'epsilon__%s*rs_response_%s+'%(c1,c1) # rs response
    for c2 in bacterial_taxa:
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s'%(c1,c2,c1,c2)
        else:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s+'%(c1,c2,c1,c2)
model_str += ', sigma);\n}'
#print(model_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.stan", "w")
text_file.write("%s" % model_str)
text_file.close()

# %% [markdown]
# # Plot stan output

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d.csv"%(i) for i in [1,3]])

# %%
lines = []
    
# basal growth rate
for c in bacterial_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# rs response
for c in bacterial_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['rs_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])

# pairwise interactions
for c1 in bacterial_taxa:
    for c2 in bacterial_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-ae88610a7285> in <module>
#       6     data = []
#       7     for i in np.arange(0,3):
# ----> 8         data.extend(list(fit.posterior[var][i].values))
#       9     hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
#      10     assert len(hpd_mu) == 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     640         else:
#     641             # xarray-style array indexing
# --> 642             return self.isel(indexers=self._item_key_to_dict(key))
#     643
#     644     def __setitem__(self, key: Any, value: Any) -> None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1037
#    1038         if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1039             ds = self._to_temp_dataset()._isel_fancy(
#    1040                 indexers, drop=drop, missing_dims=missing_dims
#    1041             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataset.py in _isel_fancy(self, indexers, drop, missing_dims)
#    2011
#    2012             if name in self.indexes:
# -> 2013                 new_var, new_index = isel_variable_and_index(
#    2014                     name, var, self.indexes[name], var_indexers
#    2015                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexes.py in isel_variable_and_index(name, variable, index, indexers)
#     104         )
#     105
# --> 106     new_variable = variable.isel(indexers)
#     107
#     108     if new_variable.dims != (name,):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1116
#    1117         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1118         return self[key]
#    1119
#    1120     def squeeze(self, dim=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     765         """
#     766         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 767         data = as_indexable(self._data)[indexer]
#     768         if new_order:
#     769             data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, indexer)
#    1432             return NumpyIndexingAdapter(self.array.values)[indexer]
#    1433
# -> 1434         result = self.array[key]
#    1435
#    1436         if isinstance(result, pd.Index):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
df_stan_output_summary.to_excel('bayesian_regression_summary_top20.xlsx')

# %% [markdown]
# # Plot

# %%
#df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True]
df_stan_output_summary
# Out:
#                      Type                                               Taxa  \
# 20        inulin_response                                     Muribaculaceae
# 21        inulin_response                      Bacteroides_dash_acidifaciens
# 23        inulin_response                                     Faecalibaculum
# 24        inulin_response                                     Parasutterella
# 25        inulin_response                                        Bacteroides
# 40   pairwise_interaction               ('Muribaculaceae', 'Muribaculaceae')
# 41   pairwise_interaction  ('Muribaculaceae', 'Bacteroides_dash_acidifaci...
# 51   pairwise_interaction          ('Muribaculaceae', 'Desulfovibrionaceae')
# 52   pairwise_interaction  ('Muribaculaceae', 'Clostridia_dash_UCG_dash_0...
# 60   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Muribaculac...
# 62   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Akkermansia...
# 63   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Faecalibacu...
# 64   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Parasuttere...
# 65   pairwise_interaction   ('Bacteroides_dash_acidifaciens', 'Bacteroides')
# 81   pairwise_interaction  ('Akkermansia_dash_muciniphila', 'Bacteroides_...
# 100  pairwise_interaction               ('Faecalibaculum', 'Muribaculaceae')
# 376  pairwise_interaction  ('Escherichia_dash_Shigella', 'Escherichia_das...
#
#      Left  Right  Middle        SNR  Significant
# 20   1.08   1.62   1.350   9.958040         True
# 21   1.89   2.42   2.155  15.846923         True
# 23   0.48   1.01   0.745   5.506163         True
# 24   0.14   0.68   0.410   3.039780         True
# 25   0.04   0.58   0.310   2.265775         True
# 40  -1.59  -0.29  -0.940  -2.864951         True
# 41   0.23   2.31   1.270   2.392931         True
# 51   0.27   3.71   1.990   2.280134         True
# 52  -3.74  -0.06  -1.900  -2.016358         True
# 60  -3.81  -2.50  -3.155  -9.603366         True
# 62  -4.57  -1.77  -3.170  -4.472396         True
# 63  -4.31  -1.00  -2.655  -3.148145         True
# 64  -4.26  -0.57  -2.415  -2.600989         True
# 65  -5.89  -2.35  -4.120  -4.574359         True
# 81   0.01   2.09   1.050   1.970520         True
# 100 -1.77  -0.47  -1.120  -3.398489         True
# 376  0.60   3.69   2.145   2.731059         True
