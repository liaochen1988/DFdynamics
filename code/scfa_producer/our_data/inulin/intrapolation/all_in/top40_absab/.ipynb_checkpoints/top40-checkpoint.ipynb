# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (use all data)

# %%
df_meta = pd.read_excel('../../../../../../../data/meta_data.xlsx', index_col=0)

# change HI5 to HI3
df_meta.loc[df_meta.MiceID=='HI5','MiceID'] = 'HI3'

df_meta = df_meta[df_meta.Diet == 'Inulin']
df_meta.head()
# Out:
#           MiceID   Vendor  Day    Diet
# SampleID
# sample141    BI1  Beijing    0  Inulin
# sample142    BI2  Beijing    0  Inulin
# sample143    BI3  Beijing    0  Inulin
# sample144    BI4  Beijing    0  Inulin
# sample145    BI5  Beijing    0  Inulin

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_excel('../../../../../../../data/SCFA.xlsx', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
common_samples = list(set(df_meta.index).intersection(set(df_scfa.index)))
df_scfa = df_scfa.loc[[x for x in df_meta.index if x in list(df_scfa.index)]]
df_scfa.head()
# Out:
#              Acetate   Butyrate  Propionate
# SampleID
# sample443  28.755036   9.791194   14.443533
# sample325  26.871238  10.064667   10.653087
# sample235  10.872069   2.648912    5.668429
# sample412   8.106016   0.942044    1.438978
# sample369  20.169510   5.318122   13.223484

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.571590    0.477416
# Butyrate    0.571590  1.000000    0.254948
# Propionate  0.477416  0.254948    1.000000

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('../../../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_meta.index]
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#                     A2         ASF356  Acetatifactor  \
# SampleID
# sample443      0.00000   83093.131674   70109.829850
# sample325      0.00000  410870.120960   39601.939370
# sample235      0.00000  328263.805646  184345.191348
# sample412  21281.21717  175316.693830  191530.954531
# sample369      0.00000   37142.100783       0.000000
#
#            Acetatifactor_dash_muris  Acidovorax  Acinetobacter  \
# SampleID
# sample443                       0.0         0.0            0.0
# sample325                       0.0         0.0            0.0
# sample235                       0.0         0.0            0.0
# sample412                       0.0         0.0            0.0
# sample369                       0.0         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample443                                                0.0
# sample325                                                0.0
# sample235                                                0.0
# sample412                                                0.0
# sample369                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample443                       0.0                            0.0
# sample325                       0.0                            0.0
# sample235                       0.0                            0.0
# sample412                       0.0                            0.0
# sample369                       0.0                            0.0
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample443                       0.0  ...
# sample325                       0.0  ...
# sample235                       0.0  ...
# sample412                       0.0  ...
# sample369                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample443                                                0.0
# sample325                                                0.0
# sample235                                                0.0
# sample412                                                0.0
# sample369                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample443                                           0.000000
# sample325                                           0.000000
# sample235                                           0.000000
# sample412                                      147955.128897
# sample369                                           0.000000
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample443                                                0.0
# sample325                                                0.0
# sample235                                                0.0
# sample412                                                0.0
# sample369                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample443                                                0.0
# sample325                                                0.0
# sample235                                                0.0
# sample412                                                0.0
# sample369                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample443                                                0.0
# sample325                                                0.0
# sample235                                                0.0
# sample412                                                0.0
# sample369                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample443        171379.584077                        0.000000
# sample325         94054.606003                        0.000000
# sample235         42043.640132                        0.000000
# sample412         27361.564933                     1013.391294
# sample369        135303.367138                        0.000000
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample443                     0.0         0.0                    4.751888e+05
# sample325                     0.0         0.0                    2.390967e+06
# sample235                     0.0         0.0                    6.788431e+06
# sample412                     0.0         0.0                    6.485704e+04
# sample369                     0.0         0.0                    3.037693e+05
#
# [5 rows x 304 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Akkermansia_dash_muciniphila  \
# SampleID
# sample443    1.359092e+08                  4.928461e+07
# sample325    1.358099e+08                  6.749161e+07
# sample235    1.359950e+08                  2.810456e+06
# sample412    1.473775e+07                  7.843649e+05
# sample369    8.063815e+07                  6.699772e+07
#
#            Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# SampleID
# sample443                   4.974942e+07    1.014775e+07    9.111681e+06
# sample325                   4.961628e+07    1.488043e+07    1.157367e+07
# sample235                   1.076964e+06    7.271933e+06    1.732360e+07
# sample412                   3.435396e+05    4.417373e+06    2.807094e+05
# sample369                   1.161752e+07    1.093570e+07    3.933083e+06
#
#            Bacteroides_dash_uniformis   Bacteroides  Alloprevotella  \
# SampleID
# sample443                7.901637e+06  1.011659e+07    8.883175e+06
# sample325                4.655703e+07  1.162317e+07    5.940291e+06
# sample235                3.557539e+04  3.070803e+06    1.491902e+07
# sample412                2.411871e+05  8.056461e+05    1.014709e+07
# sample369                5.645997e+07  4.596335e+06    6.708129e+06
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample443                  3.061722e+07
# sample325                  1.366267e+06
# sample235                  1.251607e+06
# sample412                  4.043431e+05
# sample369                  1.192527e+06
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  Parabacteroides  \
# SampleID                                            ...
# sample443                             1.246397e+06  ...     8.491079e+05
# sample325                             4.374034e+07  ...     1.831590e+05
# sample235                             1.015516e+06  ...     1.811111e+05
# sample412                             4.475136e+06  ...     4.185306e+06
# sample369                             3.952981e+05  ...     5.000919e+05
#
#            Bacteroides_dash_caecimuris  Lactobacillus  Anaerotruncus  \
# SampleID
# sample443                 2.199371e+06   2.259095e+05   6.933083e+05
# sample325                 0.000000e+00   1.985047e+06   2.321664e+06
# sample235                 5.336308e+04   7.438490e+04   5.223114e+05
# sample412                 5.877670e+04   2.695621e+05   1.843359e+06
# sample369                 0.000000e+00   3.316259e+04   1.087733e+05
#
#            Ruminococcaceae     Bilophila  Desulfovibrio  Gastranaerophilales  \
# SampleID
# sample443     2.155228e+05  3.635325e+04   0.000000e+00         1.095271e+07
# sample325     8.613422e+05  0.000000e+00   3.346364e+06         0.000000e+00
# sample235     4.560118e+05  1.395525e+06   0.000000e+00         4.689483e+04
# sample412     1.271806e+06  3.242852e+04   2.209193e+05         4.864278e+04
# sample369     5.703965e+04  0.000000e+00   3.860125e+05         0.000000e+00
#
#            mouse_dash_gut_dash_metagenome  Helicobacter_dash_mastomyrinus
# SampleID
# sample443                    4.751888e+05                    2.251305e+06
# sample325                    2.390967e+06                    1.732585e+06
# sample235                    6.788431e+06                    0.000000e+00
# sample412                    6.485704e+04                    5.827000e+05
# sample369                    3.037693e+05                    2.560152e+05
#
# [5 rows x 40 columns]

# %%
print(df_16S_topX.columns)
# Out:
# Index(['Muribaculaceae', 'Akkermansia_dash_muciniphila',
#        'Bacteroides_dash_acidifaciens', 'Faecalibaculum', 'Parasutterella',
#        'Bacteroides_dash_uniformis', 'Bacteroides', 'Alloprevotella',
#        'Clostridia_dash_UCG_dash_014',
#        'Lachnospiraceae_dash_NK4A136_dash_group', 'Lachnospiraceae',
#        'Escherichia_dash_Shigella', 'Parabacteroides_dash_goldsteinii',
#        'Desulfovibrionaceae', 'Helicobacter_dash_ganmani',
#        'Mucispirillum_dash_schaedleri', 'Oscillospiraceae', 'Muribaculum',
#        'Lachnospiraceae_dash_bacterium_dash_10_dash_1', 'Roseburia',
#        'Colidextribacter', 'Lachnoclostridium',
#        'Clostridia_dash_vadinBB60_dash_group',
#        'Bacteroides_dash_vulgatus_dash_ATCC_dash_8482',
#        'Lachnospiraceae_dash_bacterium_dash_28_dash_4', 'Oscillibacter',
#        'Rikenellaceae_dash_RC9_dash_gut_dash_group', 'Alistipes',
#        'Dubosiella_dash_newyorkensis',
#        'Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57', 'Parabacteroides',
#        'Bacteroides_dash_caecimuris', 'Lactobacillus', 'Anaerotruncus',
#        'Ruminococcaceae', 'Bilophila', 'Desulfovibrio', 'Gastranaerophilales',
#        'mouse_dash_gut_dash_metagenome', 'Helicobacter_dash_mastomyrinus'],
#       dtype='object')

# %%
df_16S_topX.to_csv('independent_variables_top40.csv')

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.8249530937182269

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.MiceID):
    curr_df = df_scfa_meta[df_scfa_meta.MiceID==curr_mice].sort_values(by='Day')
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
# Acetate [ 5.88080247 12.14596203 -0.43475069 -8.45481698  1.05565162  0.85030676
#  -0.11793858 -0.42130764  5.1597708 ]
# Butyrate [ 4.40141892  3.95282015 -0.40283892 -2.17749593 -0.07661079 -0.27001784
#   0.02312691  0.18139178  0.42008895]
# Propionate [12.40412765  6.67637979 -1.66930152 -2.46950507  0.35743635 -0.49134213
#  -0.15876576 -0.08418748  0.15196148]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-155-263f172ac015> in <module>
#      13         df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
#      14     if curr_mice=='BI1':
# ---> 15         assert 0
#      16 df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
#      17 df_scfa_deriv.head()
#
# AssertionError:

# %%
df_scfa_deriv.loc['sample141']
# Out:
# MiceID            BI1
# Vendor        Beijing
# Day                 0
# Diet           Inulin
# Acetate      -8.45482
# Butyrate      -2.1775
# Propionate   -2.46951
# Name: sample141, dtype: object

# %%
df_scfa_deriv.to_csv('response_variables_scfa_deriv.csv')

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#            Muribaculaceae  Akkermansia_dash_muciniphila  \
# SampleID
# sample443        0.365589                      0.132573
# sample325        0.365322                      0.181549
# sample235        0.365820                      0.007560
# sample412        0.039644                      0.002110
# sample369        0.216913                      0.180221
#
#            Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# SampleID
# sample443                       0.133824        0.027297        0.024510
# sample325                       0.133465        0.040028        0.031133
# sample235                       0.002897        0.019561        0.046600
# sample412                       0.000924        0.011883        0.000755
# sample369                       0.031251        0.029417        0.010580
#
#            Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  \
# SampleID
# sample443                    0.021255     0.027213        0.023895
# sample325                    0.125236     0.031266        0.015979
# sample235                    0.000096     0.008260        0.040131
# sample412                    0.000649     0.002167        0.027295
# sample369                    0.151875     0.012364        0.018045
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample443                      0.082359
# sample325                      0.003675
# sample235                      0.003367
# sample412                      0.001088
# sample369                      0.003208
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  Parabacteroides  \
# SampleID                                            ...
# sample443                                 0.003353  ...         0.002284
# sample325                                 0.117659  ...         0.000493
# sample235                                 0.002732  ...         0.000487
# sample412                                 0.012038  ...         0.011258
# sample369                                 0.001063  ...         0.001345
#
#            Bacteroides_dash_caecimuris  Lactobacillus  Anaerotruncus  \
# SampleID
# sample443                     0.005916       0.000608       0.001865
# sample325                     0.000000       0.005340       0.006245
# sample235                     0.000144       0.000200       0.001405
# sample412                     0.000158       0.000725       0.004959
# sample369                     0.000000       0.000089       0.000293
#
#            Ruminococcaceae  Bilophila  Desulfovibrio  Gastranaerophilales  \
# SampleID
# sample443         0.000580   0.000098       0.000000             0.029462
# sample325         0.002317   0.000000       0.009002             0.000000
# sample235         0.001227   0.003754       0.000000             0.000126
# sample412         0.003421   0.000087       0.000594             0.000131
# sample369         0.000153   0.000000       0.001038             0.000000
#
#            mouse_dash_gut_dash_metagenome  Helicobacter_dash_mastomyrinus
# SampleID
# sample443                        0.001278                        0.006056
# sample325                        0.006432                        0.004661
# sample235                        0.018261                        0.000000
# sample412                        0.000174                        0.001567
# sample369                        0.000817                        0.000689
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson  Spearman
# 0  Acetate                 Muribaculaceae -0.019421  0.080017
# 1  Acetate   Akkermansia_dash_muciniphila -0.088484 -0.007938
# 2  Acetate  Bacteroides_dash_acidifaciens  0.094321  0.059250
# 3  Acetate                 Faecalibaculum  0.077760  0.036824
# 4  Acetate                 Parasutterella -0.016523  0.034493

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasticnet.head()
# Out:
#              BestAlpha  L1Ratio        R2  Muribaculaceae  \
# SCFA
# Acetate     625.297743   0.0001  0.000000   -0.000000e+00
# Butyrate    632.967662   0.0001  0.000000   -5.538987e-20
# Propionate    0.405716   0.1000  0.001302    0.000000e+00
#
#             Bacteroides_dash_acidifaciens
# SCFA
# Acetate                          0.000000
# Butyrate                         0.000000
# Propionate                       0.126561

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 25.8min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 26.6min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 24.0min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           650         sqrt       10.0                  2
# 1    Butyrate          1100         sqrt       30.0                  5
# 2  Propionate           200         sqrt        NaN                  5
#
#    min_samples_leaf  bootstrap
# 0                 4       True
# 1                 4       True
# 2                 4       True

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
df_opt_paras = pd.read_excel('optimal_rf_hyperparameters_top40.xlsx', index_col=0)
df_opt_paras.head()
# Out:
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           650         sqrt       10.0                  2
# 1    Butyrate          1100         sqrt       30.0                  5
# 2  Propionate           200         sqrt        NaN                  5
#
#    min_samples_leaf  bootstrap
# 0                 4       True
# 1                 4       True
# 2                 4       True

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Muribaculaceae  Akkermansia_dash_muciniphila  \
# 0     Acetate  0.524254        0.029255                      0.023163
# 1    Butyrate  0.490726        0.024955                      0.026706
# 2  Propionate  0.452121        0.017484                      0.018553
#
#    Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# 0                       0.036697        0.038801        0.035018
# 1                       0.029957        0.027024        0.031491
# 2                       0.042638        0.066684        0.041232
#
#    Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  ...  \
# 0                    0.016180     0.029714        0.023524  ...
# 1                    0.016492     0.044350        0.029808  ...
# 2                    0.020746     0.039404        0.013923  ...
#
#    Parabacteroides  Bacteroides_dash_caecimuris  Lactobacillus  Anaerotruncus  \
# 0         0.023889                     0.015270       0.034001       0.020209
# 1         0.031843                     0.012049       0.031066       0.024456
# 2         0.024707                     0.021782       0.033925       0.025483
#
#    Ruminococcaceae  Bilophila  Desulfovibrio  Gastranaerophilales  \
# 0         0.027741   0.039381       0.014288             0.011504
# 1         0.033091   0.023546       0.010692             0.008955
# 2         0.030965   0.042283       0.011234             0.015484
#
#    mouse_dash_gut_dash_metagenome  Helicobacter_dash_mastomyrinus
# 0                        0.026975                        0.016166
# 1                        0.024782                        0.011012
# 2                        0.052103                        0.031042
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# ## plot

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0).set_index('SCFA')

fig, ax = plt.subplots(figsize=(20, 10), nrows=1, ncols=3, constrained_layout=True)
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_rf.loc[scfa].reset_index()
    curr_df.columns = ['SCFA','Taxon','Importance']
    curr_df = curr_df.sort_values('Importance',ascending=False)
    _ = sns.barplot(y='Taxon', x='Importance',  data=curr_df, orient='h', ax=ax[k], palette='Set1')
    ax[k].legend(loc='lower right')
    ax[k].set_xlim(0,0.12)
    ax[k].set_xticks([0,0.06,0.12])
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson
# 0  Acetate                 Muribaculaceae -0.019421
# 1  Acetate   Akkermansia_dash_muciniphila -0.088484
# 2  Acetate  Bacteroides_dash_acidifaciens  0.094321
# 3  Acetate                 Faecalibaculum  0.077760
# 4  Acetate                 Parasutterella -0.016523

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasnet.head()
# Out:
#          SCFA                       Variable   Coefficient
# 0     Acetate                 Muribaculaceae  0.000000e+00
# 1     Acetate  Bacteroides_dash_acidifaciens  0.000000e+00
# 2    Butyrate                 Muribaculaceae -5.538987e-20
# 3    Butyrate  Bacteroides_dash_acidifaciens  0.000000e+00
# 4  Propionate                 Muribaculaceae  0.000000e+00

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA                       Variable      Gini
# 0  Acetate                 Muribaculaceae  0.029255
# 1  Acetate   Akkermansia_dash_muciniphila  0.023163
# 2  Acetate  Bacteroides_dash_acidifaciens  0.036697
# 3  Acetate                 Faecalibaculum  0.038801
# 4  Acetate                 Parasutterella  0.035018

# %%
#df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_rf, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#          SCFA                     Taxon  RandomForest    ElasticNet
# 0     Acetate            Muribaculaceae      0.029255  0.000000e+00
# 1     Acetate  Bacteroides-acidifaciens      0.036697  0.000000e+00
# 2    Butyrate            Muribaculaceae      0.024955 -5.538987e-20
# 3    Butyrate  Bacteroides-acidifaciens      0.029957  0.000000e+00
# 4  Propionate            Muribaculaceae      0.017484  0.000000e+00

# %%
fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df.iloc[0:10,:] 
        
    # normalize to -1 and 1
    for c in ['ElasticNet','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
