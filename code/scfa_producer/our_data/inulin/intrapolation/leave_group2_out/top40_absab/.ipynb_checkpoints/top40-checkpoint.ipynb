# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (remove mice with suffix 2)

# %%
df_meta = pd.read_excel('../../../../../../../data/meta_data.xlsx', index_col=0)

# change HI5 to HI3
df_meta.loc[df_meta.MiceID=='HI5','MiceID'] = 'HI3'

df_meta = df_meta[~df_meta.MiceID.str.contains('2')]
df_meta = df_meta[df_meta.Diet == 'Inulin']
df_meta.head()
# Out:
#           MiceID   Vendor  Day    Diet
# SampleID
# sample141    BI1  Beijing    0  Inulin
# sample143    BI3  Beijing    0  Inulin
# sample144    BI4  Beijing    0  Inulin
# sample145    BI5  Beijing    0  Inulin
# sample156    BI1  Beijing    1  Inulin

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_excel('../../../../../../../data/SCFA.xlsx', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
common_samples = [x for x in df_meta.index if x in list(df_scfa.index)]
df_scfa = df_scfa.loc[common_samples]
df_meta = df_meta.loc[common_samples]
df_scfa.head()
# Out:
#              Acetate  Butyrate  Propionate
# SampleID
# sample141   5.233899  1.109582    1.930933
# sample143  18.075378  1.682656    2.859916
# sample144  12.580368  1.477688    3.148773
# sample145   8.065127  1.835172    3.134209
# sample156  14.944810  5.382770   11.384803

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.540255    0.519624
# Butyrate    0.540255  1.000000    0.240717
# Propionate  0.519624  0.240717    1.000000

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('../../../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_meta.index]
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#                     A2         ASF356  Acetatifactor  \
# SampleID
# sample141      0.00000   58318.686780   98146.082630
# sample143      0.00000  137987.686312   64115.490610
# sample144  61973.98659  142310.635874   94108.646304
# sample145      0.00000  122899.454628  119532.346282
# sample156      0.00000  182420.266467  194421.599787
#
#            Acetatifactor_dash_muris  Acidovorax  Acinetobacter  \
# SampleID
# sample141                  0.000000         0.0            0.0
# sample143                  0.000000         0.0            0.0
# sample144                  0.000000         0.0            0.0
# sample145                  0.000000         0.0            0.0
# sample156               4800.533328         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample141                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
# sample156                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample141                       0.0                            0.0
# sample143                       0.0                            0.0
# sample144                       0.0                            0.0
# sample145                       0.0                            0.0
# sample156                       0.0                            0.0
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample141                       0.0  ...
# sample143                       0.0  ...
# sample144                       0.0  ...
# sample145                       0.0  ...
# sample156                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample141                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
# sample156                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample141                                       49784.244812
# sample143                                       58540.230557
# sample144                                      119357.307507
# sample145                                       69025.721092
# sample156                                           0.000000
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample141                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
# sample156                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample141                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
# sample156                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample141                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
# sample156                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample141        200559.386244                        0.000000
# sample143        167257.801590                        0.000000
# sample144        165263.964241                        0.000000
# sample145        368698.363883                        0.000000
# sample156         24002.666640                     2400.266664
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample141                 0.00000         0.0                    2.076714e+05
# sample143                 0.00000         0.0                    2.717939e+05
# sample144              6885.99851         0.0                    0.000000e+00
# sample145                 0.00000         0.0                    7.407638e+04
# sample156                 0.00000         0.0                    1.101722e+06
#
# [5 rows x 304 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Bacteroides_dash_acidifaciens  \
# SampleID
# sample141    2.558057e+07                   7.311172e+05
# sample143    2.765050e+07                   1.919005e+07
# sample144    2.018975e+07                   5.359602e+06
# sample145    4.461250e+07                   3.589337e+06
# sample156    6.293019e+07                   6.328303e+07
#
#            Akkermansia_dash_muciniphila  Faecalibaculum  Parasutterella  \
# SampleID
# sample141                  2.803564e+06    1.503484e+07    6.520314e+06
# sample143                  3.721486e+05    7.158634e+06    4.014187e+05
# sample144                  5.967865e+04    2.648814e+06    1.032900e+05
# sample145                  6.279657e+05    1.075791e+07    7.912705e+04
# sample156                  2.520280e+05    5.762800e+07    8.175308e+06
#
#            Bacteroides_dash_uniformis   Bacteroides  Alloprevotella  \
# SampleID
# sample141                19913.697925  3.797827e+05    6.841778e+05
# sample143                27876.300265  2.028001e+06    3.982826e+07
# sample144                34429.992550  1.315226e+06    2.598317e+06
# sample145                40405.300152  3.833453e+06    2.133737e+07
# sample156                67207.466593  1.785798e+06    1.848205e+05
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample141                  1.877577e+05
# sample143                  1.076025e+06
# sample144                  1.407039e+06
# sample145                  1.880530e+06
# sample156                  8.160907e+04
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  \
# SampleID                                            ...
# sample141                             5.789196e+05  ...
# sample143                             1.998731e+06  ...
# sample144                             3.550880e+06  ...
# sample145                             2.452938e+06  ...
# sample156                             1.022754e+07  ...
#
#            Dubosiella_dash_newyorkensis  Lactobacillus  Gastranaerophilales  \
# SampleID
# sample141                 116637.373560   1.069650e+06         2.474988e+05
# sample143                      0.000000   5.658889e+05         2.313733e+05
# sample144                   4590.665673   5.967865e+04         4.820199e+04
# sample145                      0.000000   3.198753e+04         1.188589e+06
# sample156                  33603.733297   4.536504e+05         1.680187e+04
#
#            Anaerotruncus  Desulfovibrio  Ruminococcaceae  \
# SampleID
# sample141   3.442225e+05       0.000000     6.415056e+05
# sample143   9.700952e+05   33451.560318     6.829694e+05
# sample144   2.947207e+06  135424.637364     1.223412e+06
# sample145   5.825097e+05   43772.408498     5.909275e+05
# sample156   1.032115e+06   14401.599984     2.280253e+05
#
#            Helicobacter_dash_mastomyrinus  Peptococcaceae  \
# SampleID
# sample141                    0.000000e+00    46939.430823
# sample143                    1.063481e+06   131018.611246
# sample144                    5.187452e+05   144605.968711
# sample145                    4.747623e+05   109431.021244
# sample156                    0.000000e+00   110412.266546
#
#            mouse_dash_gut_dash_metagenome  Bifidobacterium_dash_choerinum
# SampleID
# sample141                    2.076714e+05                    98146.082630
# sample143                    2.717939e+05                        0.000000
# sample144                    0.000000e+00                        0.000000
# sample145                    7.407638e+04                        0.000000
# sample156                    1.101722e+06                    48005.333281
#
# [5 rows x 40 columns]

# %%
df_16S_topX.to_csv('independent_variables_top40.csv')

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.8213995590112567

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.MiceID):
    curr_df = df_scfa_meta[df_scfa_meta.MiceID==curr_mice].sort_values(by='Day')
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#              Acetate   Butyrate  Propionate
# SampleID
# sample141   5.880802   4.401419   12.404128
# sample143  23.205175  10.299538   27.076697
# sample144   2.137760   1.817389    2.258550
# sample145   8.669110   4.911881    1.435425
# sample156  12.145962   3.952820    6.676380

# %%
df_scfa_deriv.to_csv('response_variables_scfa_deriv.csv')

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#            Muribaculaceae  Bacteroides_dash_acidifaciens  \
# SampleID
# sample141        0.068811                       0.001967
# sample143        0.074379                       0.051620
# sample144        0.054309                       0.014417
# sample145        0.120006                       0.009655
# sample156        0.169279                       0.170228
#
#            Akkermansia_dash_muciniphila  Faecalibaculum  Parasutterella  \
# SampleID
# sample141                      0.007541        0.040443        0.017539
# sample143                      0.001001        0.019256        0.001080
# sample144                      0.000161        0.007125        0.000278
# sample145                      0.001689        0.028938        0.000213
# sample156                      0.000678        0.155017        0.021991
#
#            Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  \
# SampleID
# sample141                    0.000054     0.001022        0.001840
# sample143                    0.000075     0.005455        0.107136
# sample144                    0.000093     0.003538        0.006989
# sample145                    0.000109     0.010312        0.057397
# sample156                    0.000181     0.004804        0.000497
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample141                      0.000505
# sample143                      0.002894
# sample144                      0.003785
# sample145                      0.005059
# sample156                      0.000220
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  \
# SampleID                                            ...
# sample141                                 0.001557  ...
# sample143                                 0.005376  ...
# sample144                                 0.009552  ...
# sample145                                 0.006598  ...
# sample156                                 0.027512  ...
#
#            Dubosiella_dash_newyorkensis  Lactobacillus  Gastranaerophilales  \
# SampleID
# sample141                      0.000314       0.002877             0.000666
# sample143                      0.000000       0.001522             0.000622
# sample144                      0.000012       0.000161             0.000130
# sample145                      0.000000       0.000086             0.003197
# sample156                      0.000090       0.001220             0.000045
#
#            Anaerotruncus  Desulfovibrio  Ruminococcaceae  \
# SampleID
# sample141       0.000926       0.000000         0.001726
# sample143       0.002610       0.000090         0.001837
# sample144       0.007928       0.000364         0.003291
# sample145       0.001567       0.000118         0.001590
# sample156       0.002776       0.000039         0.000613
#
#            Helicobacter_dash_mastomyrinus  Peptococcaceae  \
# SampleID
# sample141                        0.000000        0.000126
# sample143                        0.002861        0.000352
# sample144                        0.001395        0.000389
# sample145                        0.001277        0.000294
# sample156                        0.000000        0.000297
#
#            mouse_dash_gut_dash_metagenome  Bifidobacterium_dash_choerinum
# SampleID
# sample141                        0.000559                        0.000264
# sample143                        0.000731                        0.000000
# sample144                        0.000000                        0.000000
# sample145                        0.000199                        0.000000
# sample156                        0.002964                        0.000129
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson  Spearman
# 0  Acetate                 Muribaculaceae -0.206212 -0.138291
# 1  Acetate  Bacteroides_dash_acidifaciens -0.019047  0.023522
# 2  Acetate   Akkermansia_dash_muciniphila -0.070066 -0.039155
# 3  Acetate                 Faecalibaculum -0.169892 -0.052279
# 4  Acetate                 Parasutterella -0.209824 -0.217162

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasticnet.head()
# Out:
#             BestAlpha  L1Ratio        R2  Muribaculaceae  \
# SCFA
# Acetate      2.798474   0.0001  0.002019       -0.100738
# Butyrate     0.499463   0.0001  0.015344       -0.284996
# Propionate   0.002049   0.1000  0.144221       -4.257556
#
#             Bacteroides_dash_acidifaciens  Akkermansia_dash_muciniphila  \
# SCFA
# Acetate                         -0.004551                     -0.012351
# Butyrate                         0.028431                     -0.048793
# Propionate                       2.969418                     -2.021977
#
#             Faecalibaculum  Parasutterella  Bacteroides_dash_uniformis  \
# SCFA
# Acetate          -0.016493       -0.014279                   -0.012091
# Butyrate         -0.032887       -0.045252                   -0.045697
# Propionate       -3.022031       -5.365714                   -0.895321
#
#             Bacteroides  ...  Dubosiella_dash_newyorkensis  Lactobacillus  \
# SCFA                     ...
# Acetate        0.004144  ...                     -0.000987      -0.000130
# Butyrate       0.018225  ...                     -0.002767      -0.000354
# Propionate    -5.217828  ...                     -0.304588       0.375643
#
#             Gastranaerophilales  Anaerotruncus  Desulfovibrio  \
# SCFA
# Acetate               -0.000000       0.001012      -0.000000
# Butyrate              -0.001226       0.002678      -0.000587
# Propionate            -0.526411       1.015096      -0.054333
#
#             Ruminococcaceae  Helicobacter_dash_mastomyrinus  Peptococcaceae  \
# SCFA
# Acetate            0.000522                       -0.000485        0.001282
# Butyrate           0.002642                       -0.000733        0.004943
# Propionate         0.369971                       -0.142638        0.000000
#
#             mouse_dash_gut_dash_metagenome  Bifidobacterium_dash_choerinum
# SCFA
# Acetate                           0.000063                       -0.000753
# Butyrate                         -0.000325                       -0.002015
# Propionate                       -0.000000                       -0.209919
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 21.0min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 37.2min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 35.0min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 41.3min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 40.9min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 48.9min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt        NaN                  5
# 1    Butyrate          1550         auto       10.0                  2
# 2  Propionate           650         sqrt        NaN                  5
#
#    min_samples_leaf  bootstrap
# 0                 2       True
# 1                 2      False
# 2                 2      False

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
df_opt_paras = pd.read_excel('optimal_rf_hyperparameters_top40.xlsx', index_col=0)
df_opt_paras.head()
# Out:
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt        NaN                  5
# 1    Butyrate          1550         auto       10.0                  2
# 2  Propionate           650         sqrt        NaN                  5
#
#    min_samples_leaf  bootstrap
# 0                 2       True
# 1                 2      False
# 2                 2      False

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Muribaculaceae  Bacteroides_dash_acidifaciens  \
# 0     Acetate  0.773971        0.056905                       0.015856
# 1    Butyrate  0.833751        0.420681                       0.009893
# 2  Propionate  0.928018        0.058606                       0.028114
#
#    Akkermansia_dash_muciniphila  Faecalibaculum  Parasutterella  \
# 0                      0.017795        0.029406        0.056378
# 1                      0.001317        0.010499        0.033559
# 2                      0.010445        0.030450        0.061303
#
#    Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  ...  \
# 0                    0.019883     0.024310        0.025136  ...
# 1                    0.000483     0.015779        0.021751  ...
# 2                    0.008646     0.024985        0.017930  ...
#
#    Dubosiella_dash_newyorkensis  Lactobacillus  Gastranaerophilales  \
# 0                      0.005065       0.015918             0.007396
# 1                      0.000000       0.001331             0.000000
# 2                      0.009797       0.016564             0.010543
#
#    Anaerotruncus  Desulfovibrio  Ruminococcaceae  \
# 0       0.050118       0.009726         0.038892
# 1       0.006164       0.000233         0.000237
# 2       0.039990       0.003795         0.040535
#
#    Helicobacter_dash_mastomyrinus  Peptococcaceae  \
# 0                        0.011976        0.030155
# 1                        0.000130        0.000000
# 2                        0.020533        0.032562
#
#    mouse_dash_gut_dash_metagenome  Bifidobacterium_dash_choerinum
# 0                        0.013269                        0.006041
# 1                        0.026493                        0.000000
# 2                        0.014277                        0.002324
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# ## plot

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0).set_index('SCFA')

fig, ax = plt.subplots(figsize=(20, 10), nrows=1, ncols=3, constrained_layout=True)
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_rf.loc[scfa].reset_index()
    curr_df.columns = ['SCFA','Taxon','Importance']
    curr_df = curr_df.sort_values('Importance',ascending=False)
    _ = sns.barplot(y='Taxon', x='Importance',  data=curr_df, orient='h', ax=ax[k], palette='Set1')
    ax[k].legend(loc='lower right')
    ax[k].set_xlim(0,0.12)
    ax[k].set_xticks([0,0.06,0.12])
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson
# 0  Acetate                 Muribaculaceae -0.206212
# 1  Acetate  Bacteroides_dash_acidifaciens -0.019047
# 2  Acetate   Akkermansia_dash_muciniphila -0.070066
# 3  Acetate                 Faecalibaculum -0.169892
# 4  Acetate                 Parasutterella -0.209824

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasnet.head()
# Out:
#       SCFA                       Variable  Coefficient
# 0  Acetate                 Muribaculaceae    -0.100738
# 1  Acetate  Bacteroides_dash_acidifaciens    -0.004551
# 2  Acetate   Akkermansia_dash_muciniphila    -0.012351
# 3  Acetate                 Faecalibaculum    -0.016493
# 4  Acetate                 Parasutterella    -0.014279

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA                       Variable      Gini
# 0  Acetate                 Muribaculaceae  0.056905
# 1  Acetate  Bacteroides_dash_acidifaciens  0.015856
# 2  Acetate   Akkermansia_dash_muciniphila  0.017795
# 3  Acetate                 Faecalibaculum  0.029406
# 4  Acetate                 Parasutterella  0.056378

# %%
#df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_rf, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA                     Taxon  RandomForest  ElasticNet
# 0  Acetate            Muribaculaceae      0.056905   -0.100738
# 1  Acetate  Bacteroides-acidifaciens      0.015856   -0.004551
# 2  Acetate   Akkermansia-muciniphila      0.017795   -0.012351
# 3  Acetate            Faecalibaculum      0.029406   -0.016493
# 4  Acetate            Parasutterella      0.056378   -0.014279

# %%
fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df.iloc[0:10,:] 
        
    # normalize to -1 and 1
    for c in ['ElasticNet','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
