# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (remove Shanghai mice data)

# %%
df_meta = pd.read_excel('../../../../../../data/meta_data.xlsx', index_col=0)
df_meta = df_meta[df_meta.Vendor != 'Shanghai']
df_meta = df_meta[df_meta.Diet == 'Inulin']
df_meta.head()
# Out:
#           MiceID   Vendor  Day    Diet
# SampleID
# sample141    BI1  Beijing    0  Inulin
# sample142    BI2  Beijing    0  Inulin
# sample143    BI3  Beijing    0  Inulin
# sample144    BI4  Beijing    0  Inulin
# sample145    BI5  Beijing    0  Inulin

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_excel('../../../../../../data/SCFA.xlsx', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
df_scfa = df_scfa.loc[[x for x in df_meta.index if x in df_scfa.index]]
df_scfa.head()
# Out:
#              Acetate  Butyrate  Propionate
# SampleID
# sample141   5.233899  1.109582    1.930933
# sample142  13.459823  1.546647    3.621771
# sample143  18.075378  1.682656    2.859916
# sample144  12.580368  1.477688    3.148773
# sample145   8.065127  1.835172    3.134209

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.570111    0.596792
# Butyrate    0.570111  1.000000    0.625222
# Propionate  0.596792  0.625222    1.000000

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('../../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_scfa.index]
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#                      A2         ASF356  Acetatifactor  \
# SampleID
# sample141      0.000000   58318.686780   98146.082630
# sample142  79938.738108   25274.748078   33503.735825
# sample143      0.000000  137987.686312   64115.490610
# sample144  61973.986590  142310.635874   94108.646304
# sample145      0.000000  122899.454628  119532.346282
#
#            Acetatifactor_dash_muris  Acidovorax  Acinetobacter  \
# SampleID
# sample141                       0.0         0.0            0.0
# sample142                       0.0         0.0            0.0
# sample143                       0.0         0.0            0.0
# sample144                       0.0         0.0            0.0
# sample145                       0.0         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample141                       0.0                            0.0
# sample142                       0.0                            0.0
# sample143                       0.0                            0.0
# sample144                       0.0                            0.0
# sample145                       0.0                            0.0
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample141                       0.0  ...
# sample142                       0.0  ...
# sample143                       0.0  ...
# sample144                       0.0  ...
# sample145                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample141                                       49784.244812
# sample142                                       18809.114849
# sample143                                       58540.230557
# sample144                                      119357.307507
# sample145                                       69025.721092
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample141        200559.386244                             0.0
# sample142         48198.356800                             0.0
# sample143        167257.801590                             0.0
# sample144        165263.964241                             0.0
# sample145        368698.363883                             0.0
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample141                0.000000         0.0                   207671.421217
# sample142             1763.354517         0.0                   108152.410381
# sample143                0.000000         0.0                   271793.927584
# sample144             6885.998510         0.0                        0.000000
# sample145                0.000000         0.0                    74076.383611
#
# [5 rows x 304 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Bacteroides_dash_acidifaciens  \
# SampleID
# sample141    2.558057e+07                   7.311172e+05
# sample142    1.221770e+07                   1.518836e+06
# sample143    2.765050e+07                   1.919005e+07
# sample144    2.018975e+07                   5.359602e+06
# sample145    4.461250e+07                   3.589337e+06
#
#            Akkermansia_dash_muciniphila  Faecalibaculum  \
# SampleID
# sample141                  2.803564e+06    1.503484e+07
# sample142                  1.240226e+05    8.628681e+06
# sample143                  3.721486e+05    7.158634e+06
# sample144                  5.967865e+04    2.648814e+06
# sample145                  6.279657e+05    1.075791e+07
#
#            Bacteroides_dash_uniformis  Parasutterella  Alloprevotella  \
# SampleID
# sample141                19913.697925    6.520314e+06    6.841778e+05
# sample142                17045.760332    1.957324e+06    1.537645e+06
# sample143                27876.300265    4.014187e+05    3.982826e+07
# sample144                34429.992550    1.032900e+05    2.598317e+06
# sample145                40405.300152    7.912705e+04    2.133737e+07
#
#            Clostridia_dash_UCG_dash_014  Lachnospiraceae  \
# SampleID
# sample141                  1.877577e+05     1.514863e+06
# sample142                  5.207774e+05     6.877083e+05
# sample143                  1.076025e+06     6.340464e+06
# sample144                  1.407039e+06     8.983933e+06
# sample145                  1.880530e+06     2.707155e+06
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  Lactobacillus  \
# SampleID                                            ...
# sample141                             5.789196e+05  ...   1.069650e+06
# sample142                             9.469214e+05  ...   6.060062e+05
# sample143                             1.998731e+06  ...   5.658889e+05
# sample144                             3.550880e+06  ...   5.967865e+04
# sample145                             2.452938e+06  ...   3.198753e+04
#
#                Bilophila  Anaerotruncus  Gastranaerophilales  Ruminococcaceae  \
# SampleID
# sample141  236119.561110   3.442225e+05         2.474988e+05     6.415056e+05
# sample142  317403.813075   1.610530e+05         3.996937e+04     4.320219e+05
# sample143   96173.235914   9.700952e+05         2.313733e+05     6.829694e+05
# sample144  218056.619485   2.947207e+06         4.820199e+04     1.223412e+06
# sample145  114481.683763   5.825097e+05         1.188589e+06     5.909275e+05
#
#            mouse_dash_gut_dash_metagenome  \
# SampleID
# sample141                   207671.421217
# sample142                   108152.410381
# sample143                   271793.927584
# sample144                        0.000000
# sample145                    74076.383611
#
#            Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SampleID
# sample141                                   1.294390e+05
# sample142                                   1.921469e+06
# sample143                                   2.383424e+05
# sample144                                   2.295333e+05
# sample145                                   9.596259e+04
#
#            Helicobacter_dash_mastomyrinus  Desulfovibrio  \
# SampleID
# sample141                    0.000000e+00       0.000000
# sample142                    0.000000e+00    4114.493873
# sample143                    1.063481e+06   33451.560318
# sample144                    5.187452e+05  135424.637364
# sample145                    4.747623e+05   43772.408498
#
#            Bifidobacterium_dash_choerinum
# SampleID
# sample141                    98146.082630
# sample142                    38206.014537
# sample143                        0.000000
# sample144                        0.000000
# sample145                        0.000000
#
# [5 rows x 40 columns]

# %%
df_16S_topX.to_csv('independent_variables_top40.csv')

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.8247120111526891

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.MiceID):
    curr_df = df_scfa_meta[df_scfa_meta.MiceID==curr_mice]
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#              Acetate   Butyrate  Propionate
# SampleID
# sample141   5.880802   4.401419   12.404128
# sample142  18.463945   6.679364   18.569295
# sample143  23.205175  10.299538   27.076697
# sample144   2.137760   1.817389    2.258550
# sample145   8.669110   4.911881    1.435425

# %%
df_scfa_deriv.to_csv('response_variables_scfa_deriv.csv')

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#            Muribaculaceae  Bacteroides_dash_acidifaciens  \
# SampleID
# sample141        0.068811                       0.001967
# sample142        0.032865                       0.004086
# sample143        0.074379                       0.051620
# sample144        0.054309                       0.014417
# sample145        0.120006                       0.009655
#
#            Akkermansia_dash_muciniphila  Faecalibaculum  \
# SampleID
# sample141                      0.007541        0.040443
# sample142                      0.000334        0.023211
# sample143                      0.001001        0.019256
# sample144                      0.000161        0.007125
# sample145                      0.001689        0.028938
#
#            Bacteroides_dash_uniformis  Parasutterella  Alloprevotella  \
# SampleID
# sample141                    0.000054        0.017539        0.001840
# sample142                    0.000046        0.005265        0.004136
# sample143                    0.000075        0.001080        0.107136
# sample144                    0.000093        0.000278        0.006989
# sample145                    0.000109        0.000213        0.057397
#
#            Clostridia_dash_UCG_dash_014  Lachnospiraceae  \
# SampleID
# sample141                      0.000505         0.004075
# sample142                      0.001401         0.001850
# sample143                      0.002894         0.017056
# sample144                      0.003785         0.024166
# sample145                      0.005059         0.007282
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  Lactobacillus  \
# SampleID                                            ...
# sample141                                 0.001557  ...       0.002877
# sample142                                 0.002547  ...       0.001630
# sample143                                 0.005376  ...       0.001522
# sample144                                 0.009552  ...       0.000161
# sample145                                 0.006598  ...       0.000086
#
#            Bilophila  Anaerotruncus  Gastranaerophilales  Ruminococcaceae  \
# SampleID
# sample141   0.000635       0.000926             0.000666         0.001726
# sample142   0.000854       0.000433             0.000108         0.001162
# sample143   0.000259       0.002610             0.000622         0.001837
# sample144   0.000587       0.007928             0.000130         0.003291
# sample145   0.000308       0.001567             0.003197         0.001590
#
#            mouse_dash_gut_dash_metagenome  \
# SampleID
# sample141                        0.000559
# sample142                        0.000291
# sample143                        0.000731
# sample144                        0.000000
# sample145                        0.000199
#
#            Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SampleID
# sample141                                       0.000348
# sample142                                       0.005169
# sample143                                       0.000641
# sample144                                       0.000617
# sample145                                       0.000258
#
#            Helicobacter_dash_mastomyrinus  Desulfovibrio  \
# SampleID
# sample141                        0.000000       0.000000
# sample142                        0.000000       0.000011
# sample143                        0.002861       0.000090
# sample144                        0.001395       0.000364
# sample145                        0.001277       0.000118
#
#            Bifidobacterium_dash_choerinum
# SampleID
# sample141                        0.000264
# sample142                        0.000103
# sample143                        0.000000
# sample144                        0.000000
# sample145                        0.000000
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson  Spearman
# 0  Acetate                 Muribaculaceae -0.286158 -0.236145
# 1  Acetate  Bacteroides_dash_acidifaciens  0.011093  0.063066
# 2  Acetate   Akkermansia_dash_muciniphila -0.100114 -0.112174
# 3  Acetate                 Faecalibaculum -0.187283 -0.093168
# 4  Acetate     Bacteroides_dash_uniformis -0.080364  0.005454

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
df_elasticnet.head()
# Out:
#             BestAlpha  L1Ratio        R2  Muribaculaceae  \
# SCFA
# Acetate      0.042597      0.1  0.074153       -3.846206
# Butyrate     0.027823      0.1  0.116293       -1.908178
# Propionate   0.023283      0.1  0.160898       -5.649018
#
#             Bacteroides_dash_acidifaciens  Akkermansia_dash_muciniphila  \
# SCFA
# Acetate                          0.000000                     -0.619639
# Butyrate                         0.514980                     -0.314467
# Propionate                       0.328949                     -1.831197
#
#             Faecalibaculum  Bacteroides_dash_uniformis  Parasutterella  \
# SCFA
# Acetate          -1.009797                   -0.693556       -0.352703
# Butyrate         -0.215585                   -0.449101       -0.319699
# Propionate       -1.016201                   -1.082866       -1.006160
#
#             Alloprevotella  ...  Lactobacillus  Bilophila  Anaerotruncus  \
# SCFA                        ...
# Acetate          -0.033343  ...            0.0  -0.000000            0.0
# Butyrate          0.023230  ...            0.0  -0.000000            0.0
# Propionate        0.289934  ...            0.0  -0.097742            0.0
#
#             Gastranaerophilales  Ruminococcaceae  \
# SCFA
# Acetate                     0.0             -0.0
# Butyrate                   -0.0              0.0
# Propionate                 -0.0             -0.0
#
#             mouse_dash_gut_dash_metagenome  \
# SCFA
# Acetate                                0.0
# Butyrate                              -0.0
# Propionate                            -0.0
#
#             Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SCFA
# Acetate                                               0.0
# Butyrate                                              0.0
# Propionate                                            0.0
#
#             Helicobacter_dash_mastomyrinus  Desulfovibrio  \
# SCFA
# Acetate                               -0.0           -0.0
# Butyrate                              -0.0            0.0
# Propionate                            -0.0           -0.0
#
#             Bifidobacterium_dash_choerinum
# SCFA
# Acetate                               -0.0
# Butyrate                              -0.0
# Propionate                            -0.0
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 34.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 46.7min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 55.6min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 41.9min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 50.6min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 26.8min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 34.8min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt       20.0                  2
# 1    Butyrate           200         sqrt       20.0                  5
# 2  Propionate           200         auto        NaN                  2
#
#    min_samples_leaf  bootstrap
# 0                 2       True
# 1                 4       True
# 2                 4       True

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
df_opt_paras = pd.read_excel('optimal_rf_hyperparameters_top40.xlsx', index_col=0)
df_opt_paras.head()
# Out:
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt       20.0                  2
# 1    Butyrate           200         sqrt       20.0                  5
# 2  Propionate           200         auto        NaN                  2
#
#    min_samples_leaf  bootstrap
# 0                 2       True
# 1                 4       True
# 2                 4       True

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Muribaculaceae  Bacteroides_dash_acidifaciens  \
# 0     Acetate  0.771213        0.065259                       0.019334
# 1    Butyrate  0.652381        0.092813                       0.025631
# 2  Propionate  0.705699        0.451797                       0.035780
#
#    Akkermansia_dash_muciniphila  Faecalibaculum  Bacteroides_dash_uniformis  \
# 0                      0.040486        0.029696                    0.033620
# 1                      0.025553        0.023386                    0.020130
# 2                      0.007491        0.029253                    0.007025
#
#    Parasutterella  Alloprevotella  Clostridia_dash_UCG_dash_014  ...  \
# 0        0.053813        0.029222                      0.036956  ...
# 1        0.054482        0.029441                      0.075362  ...
# 2        0.050639        0.005153                      0.010131  ...
#
#    Lactobacillus  Bilophila  Anaerotruncus  Gastranaerophilales  \
# 0       0.019774   0.011356       0.031541             0.009310
# 1       0.017796   0.010491       0.014664             0.012414
# 2       0.014853   0.001009       0.001419             0.001925
#
#    Ruminococcaceae  mouse_dash_gut_dash_metagenome  \
# 0         0.029993                        0.014246
# 1         0.030409                        0.008379
# 2         0.022649                        0.014895
#
#    Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# 0                                       0.039299
# 1                                       0.026539
# 2                                       0.031287
#
#    Helicobacter_dash_mastomyrinus  Desulfovibrio  \
# 0                        0.016120       0.015115
# 1                        0.018768       0.018267
# 2                        0.004725       0.001884
#
#    Bifidobacterium_dash_choerinum
# 0                        0.004089
# 1                        0.002633
# 2                        0.000072
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# ## plot

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0).set_index('SCFA')

fig, ax = plt.subplots(figsize=(20, 10), nrows=1, ncols=3, constrained_layout=True)
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_rf.loc[scfa].reset_index()
    curr_df.columns = ['SCFA','Taxon','Importance']
    curr_df = curr_df.sort_values('Importance',ascending=False)
    _ = sns.barplot(y='Taxon', x='Importance',  data=curr_df, orient='h', ax=ax[k], palette='Set1')
    ax[k].legend(loc='lower right')
    ax[k].set_xlim(0,0.2)
    ax[k].set_xticks([0,0.1,0.2])
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson
# 0  Acetate                 Muribaculaceae -0.286158
# 1  Acetate  Bacteroides_dash_acidifaciens  0.011093
# 2  Acetate   Akkermansia_dash_muciniphila -0.100114
# 3  Acetate                 Faecalibaculum -0.187283
# 4  Acetate     Bacteroides_dash_uniformis -0.080364

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasnet.head()
# Out:
#       SCFA                       Variable  Coefficient
# 0  Acetate                 Muribaculaceae    -3.846206
# 1  Acetate  Bacteroides_dash_acidifaciens     0.000000
# 2  Acetate   Akkermansia_dash_muciniphila    -0.619639
# 3  Acetate                 Faecalibaculum    -1.009797
# 4  Acetate     Bacteroides_dash_uniformis    -0.693556

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA                       Variable      Gini
# 0  Acetate                 Muribaculaceae  0.065259
# 1  Acetate  Bacteroides_dash_acidifaciens  0.019334
# 2  Acetate   Akkermansia_dash_muciniphila  0.040486
# 3  Acetate                 Faecalibaculum  0.029696
# 4  Acetate     Bacteroides_dash_uniformis  0.033620

# %%
#df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_rf, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA                     Taxon  RandomForest  ElasticNet
# 0  Acetate            Muribaculaceae      0.065259   -3.846206
# 1  Acetate  Bacteroides-acidifaciens      0.019334    0.000000
# 2  Acetate   Akkermansia-muciniphila      0.040486   -0.619639
# 3  Acetate            Faecalibaculum      0.029696   -1.009797
# 4  Acetate     Bacteroides-uniformis      0.033620   -0.693556

# %%
fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df[curr_df.ElasticNet !=0]
    curr_df = curr_df.iloc[0:10,:] 
    
    # normalize to -1 and 1
    for c in ['ElasticNet','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
