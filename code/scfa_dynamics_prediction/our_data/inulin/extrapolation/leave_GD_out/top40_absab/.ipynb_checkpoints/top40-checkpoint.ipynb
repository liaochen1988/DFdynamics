# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (remove Guangdong mice data)

# %%
df_meta = pd.read_excel('../../../../../../data/meta_data.xlsx', index_col=0)
df_meta = df_meta[df_meta.Vendor != 'Guangdong']
df_meta = df_meta[df_meta.Diet == 'Inulin']
df_meta.head()
# Out:
#           MiceID   Vendor  Day    Diet
# SampleID
# sample141    BI1  Beijing    0  Inulin
# sample142    BI2  Beijing    0  Inulin
# sample143    BI3  Beijing    0  Inulin
# sample144    BI4  Beijing    0  Inulin
# sample145    BI5  Beijing    0  Inulin

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_excel('../../../../../../data/SCFA.xlsx', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
df_scfa = df_scfa.loc[[x for x in df_meta.index if x in df_scfa.index]]
df_scfa.head()
# Out:
#              Acetate  Butyrate  Propionate
# SampleID
# sample141   5.233899  1.109582    1.930933
# sample142  13.459823  1.546647    3.621771
# sample143  18.075378  1.682656    2.859916
# sample144  12.580368  1.477688    3.148773
# sample145   8.065127  1.835172    3.134209

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.549807    0.393892
# Butyrate    0.549807  1.000000    0.135812
# Propionate  0.393892  0.135812    1.000000

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('../../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_scfa.index]
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#                      A2         ASF356  Acetatifactor  \
# SampleID
# sample141      0.000000   58318.686780   98146.082630
# sample142  79938.738108   25274.748078   33503.735825
# sample143      0.000000  137987.686312   64115.490610
# sample144  61973.986590  142310.635874   94108.646304
# sample145      0.000000  122899.454628  119532.346282
#
#            Acetatifactor_dash_muris  Acidovorax  Acinetobacter  \
# SampleID
# sample141                       0.0         0.0            0.0
# sample142                       0.0         0.0            0.0
# sample143                       0.0         0.0            0.0
# sample144                       0.0         0.0            0.0
# sample145                       0.0         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample141                       0.0                            0.0
# sample142                       0.0                            0.0
# sample143                       0.0                            0.0
# sample144                       0.0                            0.0
# sample145                       0.0                            0.0
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample141                       0.0  ...
# sample142                       0.0  ...
# sample143                       0.0  ...
# sample144                       0.0  ...
# sample145                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample141                                       49784.244812
# sample142                                       18809.114849
# sample143                                       58540.230557
# sample144                                      119357.307507
# sample145                                       69025.721092
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample141                                                0.0
# sample142                                                0.0
# sample143                                                0.0
# sample144                                                0.0
# sample145                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample141        200559.386244                             0.0
# sample142         48198.356800                             0.0
# sample143        167257.801590                             0.0
# sample144        165263.964241                             0.0
# sample145        368698.363883                             0.0
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample141                0.000000         0.0                   207671.421217
# sample142             1763.354517         0.0                   108152.410381
# sample143                0.000000         0.0                   271793.927584
# sample144             6885.998510         0.0                        0.000000
# sample145                0.000000         0.0                    74076.383611
#
# [5 rows x 304 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Akkermansia_dash_muciniphila  \
# SampleID
# sample141    2.558057e+07                  2.803564e+06
# sample142    1.221770e+07                  1.240226e+05
# sample143    2.765050e+07                  3.721486e+05
# sample144    2.018975e+07                  5.967865e+04
# sample145    4.461250e+07                  6.279657e+05
#
#            Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# SampleID
# sample141                   7.311172e+05    1.503484e+07    6.520314e+06
# sample142                   1.518836e+06    8.628681e+06    1.957324e+06
# sample143                   1.919005e+07    7.158634e+06    4.014187e+05
# sample144                   5.359602e+06    2.648814e+06    1.032900e+05
# sample145                   3.589337e+06    1.075791e+07    7.912705e+04
#
#            Bacteroides_dash_uniformis   Bacteroides  Alloprevotella  \
# SampleID
# sample141                19913.697925  3.797827e+05    6.841778e+05
# sample142                17045.760332  2.697932e+05    1.537645e+06
# sample143                27876.300265  2.028001e+06    3.982826e+07
# sample144                34429.992550  1.315226e+06    2.598317e+06
# sample145                40405.300152  3.833453e+06    2.133737e+07
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample141                  1.877577e+05
# sample142                  5.207774e+05
# sample143                  1.076025e+06
# sample144                  1.407039e+06
# sample145                  1.880530e+06
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...    Muribaculum  \
# SampleID                                            ...
# sample141                             5.789196e+05  ...  445213.389322
# sample142                             9.469214e+05  ...  362663.245680
# sample143                             1.998731e+06  ...  381905.313631
# sample144                             3.550880e+06  ...  174445.295588
# sample145                             2.452938e+06  ...  267685.113504
#
#            Desulfovibrionaceae  Parabacteroides  \
# SampleID
# sample141         2.176283e+05     1.934474e+05
# sample142         1.616408e+05     9.874785e+04
# sample143         6.668011e+06     7.668770e+06
# sample144         2.834966e+07     5.738332e+05
# sample145         7.579361e+06     4.865472e+05
#
#            Helicobacter_dash_mastomyrinus  Anaerotruncus  \
# SampleID
# sample141                    0.000000e+00   3.442225e+05
# sample142                    0.000000e+00   1.610530e+05
# sample143                    1.063481e+06   9.700952e+05
# sample144                    5.187452e+05   2.947207e+06
# sample145                    4.747623e+05   5.825097e+05
#
#            Clostridiales_dash_bacterium_dash_CIEAF_dash_020  \
# SampleID
# sample141                                          0.000000
# sample142                                          0.000000
# sample143                                          0.000000
# sample144                                      52792.655244
# sample145                                      85861.262822
#
#            Rikenellaceae_dash_RC9_dash_gut_dash_group  Ruminococcaceae  \
# SampleID
# sample141                                4.127825e+06     6.415056e+05
# sample142                                2.091338e+06     4.320219e+05
# sample143                                5.711854e+06     6.829694e+05
# sample144                                2.336649e+06     1.223412e+06
# sample145                                4.708901e+06     5.909275e+05
#
#            Candidatus_dash_Saccharimonas  Lachnospiraceae_dash_UCG_dash_006
# SampleID
# sample141                   0.000000e+00                      516333.739054
# sample142                   4.702279e+04                      144007.285562
# sample143                   2.097692e+06                      288519.707743
# sample144                   4.932670e+06                      454475.901663
# sample145                   1.593652e+07                      254216.680120
#
# [5 rows x 40 columns]

# %%
df_16S_topX.to_csv('independent_variables_top40.csv')

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.7950513058100828

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.MiceID):
    curr_df = df_scfa_meta[df_scfa_meta.MiceID==curr_mice]
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#              Acetate   Butyrate  Propionate
# SampleID
# sample141   5.880802   4.401419   12.404128
# sample142  18.463945   6.679364   18.569295
# sample143  23.205175  10.299538   27.076697
# sample144   2.137760   1.817389    2.258550
# sample145   8.669110   4.911881    1.435425

# %%
df_scfa_deriv.to_csv('response_variables_scfa_deriv.csv')

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#            Muribaculaceae  Akkermansia_dash_muciniphila  \
# SampleID
# sample141        0.079311                      0.008692
# sample142        0.037880                      0.000385
# sample143        0.085728                      0.001154
# sample144        0.062597                      0.000185
# sample145        0.138318                      0.001947
#
#            Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# SampleID
# sample141                       0.002267        0.046614        0.020216
# sample142                       0.004709        0.026753        0.006069
# sample143                       0.059497        0.022195        0.001245
# sample144                       0.016617        0.008212        0.000320
# sample145                       0.011128        0.033354        0.000245
#
#            Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  \
# SampleID
# sample141                    0.000062     0.001177        0.002121
# sample142                    0.000053     0.000836        0.004767
# sample143                    0.000086     0.006288        0.123485
# sample144                    0.000107     0.004078        0.008056
# sample145                    0.000125     0.011885        0.066155
#
#            Clostridia_dash_UCG_dash_014  \
# SampleID
# sample141                      0.000582
# sample142                      0.001615
# sample143                      0.003336
# sample144                      0.004362
# sample145                      0.005830
#
#            Lachnospiraceae_dash_NK4A136_dash_group  ...  Muribaculum  \
# SampleID                                            ...
# sample141                                 0.001795  ...     0.001380
# sample142                                 0.002936  ...     0.001124
# sample143                                 0.006197  ...     0.001184
# sample144                                 0.011009  ...     0.000541
# sample145                                 0.007605  ...     0.000830
#
#            Desulfovibrionaceae  Parabacteroides  \
# SampleID
# sample141             0.000675         0.000600
# sample142             0.000501         0.000306
# sample143             0.020674         0.023776
# sample144             0.087896         0.001779
# sample145             0.023499         0.001509
#
#            Helicobacter_dash_mastomyrinus  Anaerotruncus  \
# SampleID
# sample141                        0.000000       0.001067
# sample142                        0.000000       0.000499
# sample143                        0.003297       0.003008
# sample144                        0.001608       0.009138
# sample145                        0.001472       0.001806
#
#            Clostridiales_dash_bacterium_dash_CIEAF_dash_020  \
# SampleID
# sample141                                          0.000000
# sample142                                          0.000000
# sample143                                          0.000000
# sample144                                          0.000164
# sample145                                          0.000266
#
#            Rikenellaceae_dash_RC9_dash_gut_dash_group  Ruminococcaceae  \
# SampleID
# sample141                                    0.012798         0.001989
# sample142                                    0.006484         0.001339
# sample143                                    0.017709         0.002117
# sample144                                    0.007245         0.003793
# sample145                                    0.014600         0.001832
#
#            Candidatus_dash_Saccharimonas  Lachnospiraceae_dash_UCG_dash_006
# SampleID
# sample141                       0.000000                           0.001601
# sample142                       0.000146                           0.000446
# sample143                       0.006504                           0.000895
# sample144                       0.015293                           0.001409
# sample145                       0.049410                           0.000788
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson  Spearman
# 0  Acetate                 Muribaculaceae -0.237422 -0.181663
# 1  Acetate   Akkermansia_dash_muciniphila -0.111591 -0.043394
# 2  Acetate  Bacteroides_dash_acidifaciens -0.009663  0.005513
# 3  Acetate                 Faecalibaculum -0.199834 -0.070219
# 4  Acetate                 Parasutterella -0.261154 -0.258240

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
df_elasticnet.head()
# Out:
#             BestAlpha  L1Ratio        R2  Muribaculaceae  \
# SCFA
# Acetate      0.000794     0.99  0.481102       -5.597753
# Butyrate     0.000446     1.00  0.524797       -2.110950
# Propionate   0.000090     1.00  0.838791       -6.166626
#
#             Akkermansia_dash_muciniphila  Bacteroides_dash_acidifaciens  \
# SCFA
# Acetate                         5.591412                      -0.877916
# Butyrate                        1.759875                       0.737869
# Propionate                      2.377858                      -1.046617
#
#             Faecalibaculum  Parasutterella  Bacteroides_dash_uniformis  \
# SCFA
# Acetate         -12.674858      -10.894415                   -7.803035
# Butyrate         -4.296463      -12.176157                   -3.340996
# Propionate        9.943105        1.944229                   -1.690632
#
#             Bacteroides  ...  Muribaculum  Desulfovibrionaceae  \
# SCFA                     ...
# Acetate      -32.737886  ...   -15.886416           -33.730897
# Butyrate     -13.167075  ...    -0.000000           -15.723421
# Propionate    -7.956589  ...  -875.720484          -150.118990
#
#             Parabacteroides  Helicobacter_dash_mastomyrinus  Anaerotruncus  \
# SCFA
# Acetate          176.282771                      -29.761852      75.213529
# Butyrate          63.180403                      -14.409912       0.000000
# Propionate        85.256737                     -387.253838     617.123949
#
#             Clostridiales_dash_bacterium_dash_CIEAF_dash_020  \
# SCFA
# Acetate                                            -0.000000
# Butyrate                                          -23.947926
# Propionate                                         20.015937
#
#             Rikenellaceae_dash_RC9_dash_gut_dash_group  Ruminococcaceae  \
# SCFA
# Acetate                                     138.851048         0.000000
# Butyrate                                    146.908515         0.000000
# Propionate                                  797.011255        55.570574
#
#             Candidatus_dash_Saccharimonas  Lachnospiraceae_dash_UCG_dash_006
# SCFA
# Acetate                          0.000000                           0.000000
# Butyrate                         0.000000                           0.000000
# Propionate                    -391.663246                        1097.308807
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 25.3min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 30.7min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 32.0min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 38.3min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 30.6min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate          1100         auto       30.0                  2
# 1    Butyrate           200         auto       20.0                  2
# 2  Propionate           200         sqrt        NaN                  2
#
#    min_samples_leaf  bootstrap
# 0                 1       True
# 1                 4       True
# 2                 2       True

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
df_opt_paras = pd.read_excel('optimal_rf_hyperparameters_top40.xlsx', index_col=0)
df_opt_paras.head()
# Out:
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate          1100         auto       30.0                  2
# 1    Butyrate           200         auto       20.0                  2
# 2  Propionate           200         sqrt        NaN                  2
#
#    min_samples_leaf  bootstrap
# 0                 1       True
# 1                 4       True
# 2                 2       True

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Muribaculaceae  Akkermansia_dash_muciniphila  \
# 0     Acetate  0.905069        0.011586                      0.006559
# 1    Butyrate  0.745154        0.093258                      0.010384
# 2  Propionate  0.777142        0.015750                      0.007068
#
#    Bacteroides_dash_acidifaciens  Faecalibaculum  Parasutterella  \
# 0                       0.012089        0.018849        0.103895
# 1                       0.011557        0.003950        0.300688
# 2                       0.020039        0.021814        0.033091
#
#    Bacteroides_dash_uniformis  Bacteroides  Alloprevotella  ...  Muribaculum  \
# 0                    0.008292     0.017627        0.010110  ...     0.026246
# 1                    0.007344     0.008336        0.003881  ...     0.000119
# 2                    0.008073     0.015095        0.028091  ...     0.021441
#
#    Desulfovibrionaceae  Parabacteroides  Helicobacter_dash_mastomyrinus  \
# 0             0.005541         0.042715                        0.005499
# 1             0.005622         0.002125                        0.003305
# 2             0.040344         0.084455                        0.004399
#
#    Anaerotruncus  Clostridiales_dash_bacterium_dash_CIEAF_dash_020  \
# 0       0.020195                                          0.041964
# 1       0.010333                                          0.007130
# 2       0.035902                                          0.012528
#
#    Rikenellaceae_dash_RC9_dash_gut_dash_group  Ruminococcaceae  \
# 0                                    0.012893         0.015931
# 1                                    0.018552         0.008619
# 2                                    0.065778         0.040126
#
#    Candidatus_dash_Saccharimonas  Lachnospiraceae_dash_UCG_dash_006
# 0                       0.004539                           0.012526
# 1                       0.002203                           0.008809
# 2                       0.024491                           0.023264
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# ## plot

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0).set_index('SCFA')

fig, ax = plt.subplots(figsize=(20, 10), nrows=1, ncols=3, constrained_layout=True)
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_rf.loc[scfa].reset_index()
    curr_df.columns = ['SCFA','Taxon','Importance']
    curr_df = curr_df.sort_values('Importance',ascending=False)
    _ = sns.barplot(y='Taxon', x='Importance',  data=curr_df, orient='h', ax=ax[k], palette='Set1')
    ax[k].legend(loc='lower right')
    ax[k].set_xlim(0,0.4)
    ax[k].set_xticks([0,0.2,0.4])
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA                       Variable   Pearson
# 0  Acetate                 Muribaculaceae -0.237422
# 1  Acetate   Akkermansia_dash_muciniphila -0.111591
# 2  Acetate  Bacteroides_dash_acidifaciens -0.009663
# 3  Acetate                 Faecalibaculum -0.199834
# 4  Acetate                 Parasutterella -0.261154

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasnet.head()
# Out:
#       SCFA                       Variable  Coefficient
# 0  Acetate                 Muribaculaceae    -5.597753
# 1  Acetate   Akkermansia_dash_muciniphila     5.591412
# 2  Acetate  Bacteroides_dash_acidifaciens    -0.877916
# 3  Acetate                 Faecalibaculum   -12.674858
# 4  Acetate                 Parasutterella   -10.894415

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA                       Variable      Gini
# 0  Acetate                 Muribaculaceae  0.011586
# 1  Acetate   Akkermansia_dash_muciniphila  0.006559
# 2  Acetate  Bacteroides_dash_acidifaciens  0.012089
# 3  Acetate                 Faecalibaculum  0.018849
# 4  Acetate                 Parasutterella  0.103895

# %%
#df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_rf, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA                     Taxon  RandomForest  ElasticNet
# 0  Acetate            Muribaculaceae      0.011586   -5.597753
# 1  Acetate   Akkermansia-muciniphila      0.006559    5.591412
# 2  Acetate  Bacteroides-acidifaciens      0.012089   -0.877916
# 3  Acetate            Faecalibaculum      0.018849  -12.674858
# 4  Acetate            Parasutterella      0.103895  -10.894415

# %%
fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df[curr_df.ElasticNet !=0]
    curr_df = curr_df.iloc[0:10,:] 
    
    # normalize to -1 and 1
    for c in ['ElasticNet','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
