# %%
import pandas as pd
import numpy as np
import skbio.io
from ete3 import NCBITaxa
import os
import subprocess
import pickle

# %% [markdown]
# # Parse blast results

# %%
with open('asv_ncbi_microbial16S_top100_hits.blast', 'r') as fh:
    df = skbio.io.read(fh, into=pd.DataFrame)
df.head()
# Out:
#                             qaccver      saccver   pident  length  mismatch  \
# 0  5fb94f804715b4d90f191c413efef44e  NR_146011.1  100.000   427.0       0.0
# 1  5fb94f804715b4d90f191c413efef44e  NR_042110.1   89.145   433.0      34.0
# 2  5fb94f804715b4d90f191c413efef44e  NR_156910.1   87.907   430.0      46.0
# 3  5fb94f804715b4d90f191c413efef44e  NR_113163.1   87.907   430.0      45.0
# 4  5fb94f804715b4d90f191c413efef44e  NR_118672.1   87.674   430.0      46.0
#
#    gapopen  qstart   qend  sstart   send         evalue  bitscore
# 0      0.0     1.0  427.0   347.0  773.0   0.000000e+00     789.0
# 1     12.0     1.0  427.0   323.0  748.0  2.130000e-149     527.0
# 2      6.0     1.0  427.0   327.0  753.0  1.290000e-141     501.0
# 3      7.0     1.0  427.0   359.0  784.0  4.650000e-141     499.0
# 4      7.0     1.0  427.0   366.0  791.0  6.020000e-140     496.0

# %% [markdown]
# # Keep top hits (if multiple hits tie, keep all of them)

# %%
# keep the top hits
all_asvs = list(set(df.qaccver))
index_to_keep = []
for asv in all_asvs:
    df_tmp = df[df.qaccver==asv].sort_values(by='evalue')
    df_tmp = df_tmp[df_tmp.evalue==df_tmp.iloc[0]['evalue']]
    index_to_keep.extend(list(df_tmp.index)) 
df = df.loc[index_to_keep].reset_index(drop=True)
df.head()
# Out:
#                             qaccver      saccver  pident  length  mismatch  \
# 0  30bedc56d781e8612120ba609f2e4889  NR_074535.1  84.870   423.0      43.0
# 1  30bedc56d781e8612120ba609f2e4889  NR_113075.1  84.870   423.0      43.0
# 2  871184f055ce26efdf43303c09277a38  NR_156080.1  97.015   402.0      12.0
# 3  871184f055ce26efdf43303c09277a38  NR_044289.1  95.025   402.0      20.0
# 4  871184f055ce26efdf43303c09277a38  NR_134772.1  95.037   403.0      18.0
#
#    gapopen  qstart   qend  sstart   send         evalue  bitscore
# 0     10.0     1.0  404.0   351.0  771.0  2.740000e-113     407.0
# 1     10.0     1.0  404.0   351.0  771.0  2.740000e-113     407.0
# 2      0.0     1.0  402.0   353.0  754.0   0.000000e+00     676.0
# 3      0.0     1.0  402.0   345.0  746.0   0.000000e+00     632.0
# 4      2.0     1.0  402.0   314.0  715.0   0.000000e+00     632.0

# %% [markdown]
# # Map sequence id to taxonomy id

# %%
unique_saccver = list(set(df['saccver']))
try:
    acc2taxid
except NameError:
    acc2taxid = {}

# automatic extraction may fail, correct the link manually
manual_curation = {'NR_028951.1':'163202',
                   'NR_137237.1':'1515612',
                   'NR_024706.1':'1336237',
                   'NR_116026.1':'29489',
                   'NR_112816.1':'229204',
                   'NR_117163.1':'48256',
                   'NR_041457.1':'381742',
                   'NR_113140.1':'1505',
                   'NR_148578.1':'1324864'
                  }
    
for idx, acc in enumerate(unique_saccver):
    if acc not in acc2taxid.keys():
        if acc in manual_curation.keys():
            acc2taxid[acc] = manual_curation[acc]
        else:
            command = "/Users/liaoc/edirect/esearch -db nuccore -query " + acc + "|/Users/liaoc/edirect/elink -target taxonomy|/Users/liaoc/edirect/efetch -format uid"
            acc2taxid[acc] = subprocess.check_output(command, shell=True).decode("utf-8").rstrip('\n') 
    if (idx % 100 == 0):
        print(idx)
pickle.dump(acc2taxid, open("acc2taxid.p", "wb" ))

# %% [markdown]
# # Get taxonomic description

# %%
acc2taxid = pickle.load( open( "acc2taxid.p", "rb" ) )

ncbi = NCBITaxa()
desired_ranks = ['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']

# taxa id merged
merged_table = {}

try:
    ncbiid_species200
except NameError:
    ncbi_rank = {'kingdom':[],
                 'phylum':[],
                 'class':[],
                 'order':[],
                 'family':[],
                 'genus':[],
                 'species':[]}
    ncbiid_species = []
    ncbiid_genus = []
    max_index = -1

for index, row in df.iterrows(): 
    if index < max_index:
        continue
    else:
        max_index = index
        
    taxid = acc2taxid[row.saccver]
    
    # resolve incompatible taxid
    if taxid in merged_table:
        taxid = merged_table[taxid] 
        
    # get lineage
    try:
        lineage = ncbi.get_lineage(taxid)
        lineage2ranks = ncbi.get_rank(lineage)
    except:
        print(row.saccver)
        print(taxid)
        print(lineage)
        raise

    # use superkingdom as kingdom
    ranks2lineage = dict((rank, taxid) for (taxid, rank) in lineage2ranks.items())
    if 'kingdom' not in ranks2lineage.keys():
        ranks2lineage['kingdom'] = ranks2lineage.get('superkingdom', '')

    replace_text = {}
    for rank in desired_ranks:
        rank_id = ranks2lineage.get(rank, '')
        if rank_id == '':
            ncbi_rank[rank].append('')
        else:
            ncbi_rank[rank].append(ncbi.get_taxid_translator([rank_id])[rank_id])
            
df['kingdom']=ncbi_rank['kingdom']
df['phylum']=ncbi_rank['phylum']
df['class']=ncbi_rank['class']
df['order']=ncbi_rank['order']
df['family']=ncbi_rank['family']
df['genus']=ncbi_rank['genus']
df['species']=ncbi_rank['species']
df.head()
# Out:
#                             qaccver      saccver  pident  length  mismatch  \
# 0  30bedc56d781e8612120ba609f2e4889  NR_074535.1  84.870   423.0      43.0
# 1  30bedc56d781e8612120ba609f2e4889  NR_113075.1  84.870   423.0      43.0
# 2  871184f055ce26efdf43303c09277a38  NR_156080.1  97.015   402.0      12.0
# 3  871184f055ce26efdf43303c09277a38  NR_044289.1  95.025   402.0      20.0
# 4  871184f055ce26efdf43303c09277a38  NR_134772.1  95.037   403.0      18.0
#
#    gapopen  qstart   qend  sstart   send         evalue  bitscore   kingdom  \
# 0     10.0     1.0  404.0   351.0  771.0  2.740000e-113     407.0  Bacteria
# 1     10.0     1.0  404.0   351.0  771.0  2.740000e-113     407.0  Bacteria
# 2      0.0     1.0  402.0   353.0  754.0   0.000000e+00     676.0  Bacteria
# 3      0.0     1.0  402.0   345.0  746.0   0.000000e+00     632.0  Bacteria
# 4      2.0     1.0  402.0   314.0  715.0   0.000000e+00     632.0  Bacteria
#
#           phylum        class          order            family          genus  \
# 0  Bacteroidetes  Bacteroidia  Bacteroidales  Odoribacteraceae    Odoribacter
# 1  Bacteroidetes  Bacteroidia  Bacteroidales  Odoribacteraceae    Odoribacter
# 2     Firmicutes   Clostridia  Clostridiales   Lachnospiraceae     Kineothrix
# 3     Firmicutes   Clostridia  Clostridiales   Lachnospiraceae  Enterocloster
# 4     Firmicutes   Clostridia  Clostridiales   Lachnospiraceae      Murimonas
#
#                     species
# 0  Odoribacter splanchnicus
# 1  Odoribacter splanchnicus
# 2      Kineothrix alysoides
# 3  Enterocloster lavalensis
# 4       Murimonas intestini

# %% [markdown]
# # Read NJC19

# %%
df_njc = pd.read_csv('NJC19.csv')
df_njc = df_njc[df_njc['Small-molecule metabolite or macromolecule'].isin(['Acetate','Butyrate', 'Propanoate (Propionate)'])]
df_njc = df_njc[['Species','Small-molecule metabolite or macromolecule','Metabolic activity']]
df_njc.columns = ['species','molecule','activity']
df_njc = df_njc[~df_njc.activity.str.contains('(-)')] # remove negative phenotypes
df_njc = df_njc[df_njc.activity.str.contains('(export)')] # only consider producer
df_njc = df_njc.drop('activity', axis=1)
df_njc['is_producer']=1
df_njc = pd.pivot_table(data=df_njc, index='species', columns='molecule', values='is_producer').reset_index().fillna(0)
df_njc.index.name = None
df_njc.columns = ['species','Acetate','Butyrate','Propionate']
df_njc.head()
# Out:
# /Users/liaoc/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                        species  Acetate  Butyrate  Propionate
# 0            Absiella dolichum      1.0       1.0         0.0
# 1  Acetoanaerobium sticklandii      1.0       1.0         1.0
# 2     Acetobacter pasteurianus      1.0       0.0         0.0
# 3        Acetobacterium woodii      1.0       0.0         0.0
# 4     Acetohalobium arabaticum      1.0       0.0         0.0

# %% [markdown]
# # Find SCFA producers

# %%
df_producer = df[['qaccver','species']]
df_producer = pd.merge(df_producer, df_njc, left_on='species', right_on='species', how='left').fillna(0)
df_producer.columns = ['ASV','Species','IsAcetateProducer','IsButyrateProducer','IsPropionateProducer']
df_producer = df_producer.drop('Species', axis=1)
df_producer = df_producer.groupby('ASV').agg(sum)
df_producer[df_producer>0.5]=1
df_producer.head()
# Out:
#                                   IsAcetateProducer  IsButyrateProducer  \
# ASV
# 00018d3f623ee7401f834d27ba565897                1.0                 1.0
# 00105152f972067ec3030c86d2413cb5                1.0                 0.0
# 00176b87ffffd210d7fa50c3a4f9bdc0                0.0                 0.0
# 002c4d1d7cc9d2da59a1c93e602e42b0                0.0                 0.0
# 00398f0ccf0ca0e27bc80a606310bced                0.0                 0.0
#
#                                   IsPropionateProducer
# ASV
# 00018d3f623ee7401f834d27ba565897                   0.0
# 00105152f972067ec3030c86d2413cb5                   0.0
# 00176b87ffffd210d7fa50c3a4f9bdc0                   0.0
# 002c4d1d7cc9d2da59a1c93e602e42b0                   0.0
# 00398f0ccf0ca0e27bc80a606310bced                   0.0

# %% [markdown]
# # Append SCFA producer columns to taxonomy table

# %%
df_tax = pd.read_csv('../taxonomy.csv', index_col=0)
df_tax = pd.merge(df_tax, df_producer, left_index=True, right_index=True, how='left').fillna(0)
df_tax.to_csv('../taxonomy_plus_scfa_producers.csv')
df_tax.head()
# Out:
#                                   Confidence   Kingdom      Phylum  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a    0.868217  Bacteria  Firmicutes
# f9a0f152d1e38da0a8c3af4946338341    0.997812  Bacteria  Firmicutes
# 9f0bbcabda2399eea0e437030f464f63    0.998060  Bacteria  Firmicutes
# 44958330e81e18a06d9a9108d5469c4d    0.998535  Bacteria  Firmicutes
# e900e85f23b48faf3b225dd67d2cde43    0.986061  Bacteria  Firmicutes
#
#                                        Class                       Order  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a  Clostridia          Clostridia-UCG-014
# f9a0f152d1e38da0a8c3af4946338341  Clostridia  Clostridia-vadinBB60-group
# 9f0bbcabda2399eea0e437030f464f63  Clostridia  Clostridia-vadinBB60-group
# 44958330e81e18a06d9a9108d5469c4d  Clostridia  Clostridia-vadinBB60-group
# e900e85f23b48faf3b225dd67d2cde43  Clostridia  Clostridia-vadinBB60-group
#
#                                                            Family  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a  uncultured-Firmicutes-bacterium
# f9a0f152d1e38da0a8c3af4946338341             uncultured-bacterium
# 9f0bbcabda2399eea0e437030f464f63             uncultured-bacterium
# 44958330e81e18a06d9a9108d5469c4d             uncultured-bacterium
# e900e85f23b48faf3b225dd67d2cde43             uncultured-bacterium
#
#                                          Genus       Species  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a  unclassified  unclassified
# f9a0f152d1e38da0a8c3af4946338341  unclassified  unclassified
# 9f0bbcabda2399eea0e437030f464f63  unclassified  unclassified
# 44958330e81e18a06d9a9108d5469c4d  unclassified  unclassified
# e900e85f23b48faf3b225dd67d2cde43  unclassified  unclassified
#
#                                  LowestClassifiedTaxon_Species  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a            Clostridia-UCG-014
# f9a0f152d1e38da0a8c3af4946338341    Clostridia-vadinBB60-group
# 9f0bbcabda2399eea0e437030f464f63    Clostridia-vadinBB60-group
# 44958330e81e18a06d9a9108d5469c4d    Clostridia-vadinBB60-group
# e900e85f23b48faf3b225dd67d2cde43    Clostridia-vadinBB60-group
#
#                                  LowestClassifiedTaxon_Genus  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a          Clostridia-UCG-014
# f9a0f152d1e38da0a8c3af4946338341  Clostridia-vadinBB60-group
# 9f0bbcabda2399eea0e437030f464f63  Clostridia-vadinBB60-group
# 44958330e81e18a06d9a9108d5469c4d  Clostridia-vadinBB60-group
# e900e85f23b48faf3b225dd67d2cde43  Clostridia-vadinBB60-group
#
#                                  LowestClassifiedTaxon_Family  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a           Clostridia-UCG-014
# f9a0f152d1e38da0a8c3af4946338341   Clostridia-vadinBB60-group
# 9f0bbcabda2399eea0e437030f464f63   Clostridia-vadinBB60-group
# 44958330e81e18a06d9a9108d5469c4d   Clostridia-vadinBB60-group
# e900e85f23b48faf3b225dd67d2cde43   Clostridia-vadinBB60-group
#
#                                  LowestClassifiedTaxon_Order  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a          Clostridia-UCG-014
# f9a0f152d1e38da0a8c3af4946338341  Clostridia-vadinBB60-group
# 9f0bbcabda2399eea0e437030f464f63  Clostridia-vadinBB60-group
# 44958330e81e18a06d9a9108d5469c4d  Clostridia-vadinBB60-group
# e900e85f23b48faf3b225dd67d2cde43  Clostridia-vadinBB60-group
#
#                                  LowestClassifiedTaxon_Class  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a                  Clostridia
# f9a0f152d1e38da0a8c3af4946338341                  Clostridia
# 9f0bbcabda2399eea0e437030f464f63                  Clostridia
# 44958330e81e18a06d9a9108d5469c4d                  Clostridia
# e900e85f23b48faf3b225dd67d2cde43                  Clostridia
#
#                                  LowestClassifiedTaxon_Phylum  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a                   Firmicutes
# f9a0f152d1e38da0a8c3af4946338341                   Firmicutes
# 9f0bbcabda2399eea0e437030f464f63                   Firmicutes
# 44958330e81e18a06d9a9108d5469c4d                   Firmicutes
# e900e85f23b48faf3b225dd67d2cde43                   Firmicutes
#
#                                   IsAcetateProducer  IsButyrateProducer  \
# ASV
# 672ec931466c5cbb3d24a0bfe429081a                0.0                 0.0
# f9a0f152d1e38da0a8c3af4946338341                0.0                 0.0
# 9f0bbcabda2399eea0e437030f464f63                0.0                 0.0
# 44958330e81e18a06d9a9108d5469c4d                0.0                 0.0
# e900e85f23b48faf3b225dd67d2cde43                0.0                 0.0
#
#                                   IsPropionateProducer
# ASV
# 672ec931466c5cbb3d24a0bfe429081a                   0.0
# f9a0f152d1e38da0a8c3af4946338341                   0.0
# 9f0bbcabda2399eea0e437030f464f63                   0.0
# 44958330e81e18a06d9a9108d5469c4d                   0.0
# e900e85f23b48faf3b225dd67d2cde43                   0.0

# %% [markdown]
# # Append SCFA producer columns to phenotypes predicted by PIcrust2

# %%
# read picrust2 output
df_pi2 = pd.read_csv('pheno_predicted_and_nsti.tsv.gz', compression='gzip', sep='\t', index_col=0).drop('metadata_NSTI', axis=1)

# add scfa producers
df_tax = pd.read_csv('../taxonomy.csv', index_col=0)
df_tax = df_tax[['IsAcetateProducer','IsButyrateProducer','IsPropionateProducer']]
df_pi2 = pd.merge(df_pi2, df_tax, left_index=True, right_index=True, how='outer').fillna(0)

# compute functional representation
df_16S = pd.read_csv('../16S_absolute_abundance_asv.csv', index_col=0).T
common_ASVs = list(set(df_16S.columns).intersection(set(df_pi2.index)))
df_pi2 = df_pi2.loc[common_ASVs]
df_16S = df_16S[common_ASVs]
df_func = df_16S.dot(df_pi2)

# remove constant traits (no variance)
df_std = df_func.std()
df_std = df_std[df_std<1e-10]
df_func = df_func[[c for c in df_func.columns if c not in list(df_std.index)]]
print('total number of features = %d'%(len(df_func.columns)))

df_func.to_csv('../pi2_phenotype_plus_scfa_producers.csv')
df_func.head()
# Out:
# total number of features = 43
#            Acetyl.CoA_assimilation        Aerobe  Biotin_prototroph  \
# sample131             37284.192454  4.567314e+07       37284.192454
# sample132             34590.079362  6.043433e+07       34590.079362
# sample133             11574.273264  3.323649e+07       11574.273264
# sample134             56550.239907  1.151000e+08       49300.209150
# sample135             39485.145176  4.531065e+07       35632.935891
#
#            Carbon_fixation  Coenzyme_A_prototroph  \
# sample131              0.0           77231.541513
# sample132              0.0           84654.667913
# sample133              0.0           53048.752461
# sample134              0.0          155150.658206
# sample135              0.0           74155.028746
#
#            Dissimilatory_sulfate_reduction  Fructose_utilizing  \
# sample131                     1.899718e+05        46161.381134
# sample132                     1.004933e+06        32769.548869
# sample133                     1.538414e+05        25077.592072
# sample134                     2.347560e+06        92800.393693
# sample135                     2.725438e+05        66450.610175
#
#            Galactose_utilizing  Glucose_utilizing  Glycine_prototroph  ...  \
# sample131         37284.192454       50599.975474        9.143948e+07  ...
# sample132         34590.079362       71000.689217        1.168817e+08  ...
# sample133         11574.273264       27488.899002        5.826634e+07  ...
# sample134         49300.209150      101500.430602        2.125303e+08  ...
# sample135         35632.935891       68376.714817        8.782459e+07  ...
#
#            Maltose_utilizing  Nitrogen_fixer  Sucrose_utilizing  \
# sample131       3.453226e+05             0.0       37284.192454
# sample132       3.540932e+05             0.0       29128.487884
# sample133       8.593898e+05             0.0       13021.057422
# sample134       3.596015e+06             0.0       53650.227604
# sample135       2.276656e+06             0.0       33706.831248
#
#            Sulfur_reducer  Trehalose_utilizing  \
# sample131    2.232613e+06         32845.598115
# sample132    5.420630e+06         18205.304927
# sample133    1.758807e+06          9645.227720
# sample134    1.208145e+07         40600.172241
# sample135    5.455691e+06         33706.831248
#
#            Use_of_nitrate_as_electron_acceptor  Xylose_utilizing  \
# sample131                        123392.922647       4438.594340
# sample132                        147462.969912      16384.774435
# sample133                        141302.586099       6269.398018
# sample134                        503152.134557      21750.092272
# sample135                        495008.893184      13482.732499
#
#            IsAcetateProducer  IsButyrateProducer  IsPropionateProducer
# sample131       1.531493e+07        5.901555e+06          1.107607e+07
# sample132       2.040542e+07        9.247385e+06          1.540624e+07
# sample133       1.137221e+07        3.480963e+06          8.935339e+06
# sample134       7.006865e+07        2.158624e+07          5.474208e+07
# sample135       2.387888e+07        7.954812e+06          1.795418e+07
#
# [5 rows x 43 columns]
