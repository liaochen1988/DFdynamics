# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.interpolate import CubicSpline
from sklearn.metrics import mean_squared_error
import warnings
import itertools
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
import scipy.stats.kde as kde

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('./16S_relative_abundance.xlsx', index_col=0)
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#             Absiella_dash_argi  Absiella_dash_dolichum  Acetanaerobacterium  \
# SampleID
# SRR6444565                 0.0                     0.0                  0.0
# SRR6443884                 0.0                     0.0                  0.0
# SRR6444382                 0.0                     0.0                  0.0
# SRR6444917                 0.0                     0.0                  0.0
# SRR6443930                 0.0                     0.0                  0.0
#
#             Acetoanaerobium  Acetobacterium  Acidaminococcus_dash_intestini  \
# SampleID
# SRR6444565              0.0             0.0                             0.0
# SRR6443884              0.0             0.0                             0.0
# SRR6444382              0.0             0.0                             0.0
# SRR6444917              0.0             0.0                             0.0
# SRR6443930              0.0             0.0                             0.0
#
#             Acidaminococcus_dash_sp_dot__dash_Marseille_dash_P2828  \
# SampleID
# SRR6444565                                                0.0
# SRR6443884                                                0.0
# SRR6444382                                                0.0
# SRR6444917                                                0.0
# SRR6443930                                                0.0
#
#             Acinetobacter  Actinobacillus  Actinobacteria  ...  \
# SampleID                                                   ...
# SRR6444565            0.0             0.0             0.0  ...
# SRR6443884            0.0             0.0             0.0  ...
# SRR6444382            0.0             0.0             0.0  ...
# SRR6444917            0.0             0.0             0.0  ...
# SRR6443930            0.0             0.0             0.0  ...
#
#             human_dash_gut_dash_metagenome  \
# SampleID
# SRR6444565                        0.032972
# SRR6443884                        0.034554
# SRR6444382                        0.032344
# SRR6444917                        0.000000
# SRR6443930                        0.000000
#
#             iron_dash_reducing_dash_bacterium_dash_enrichment_dash_culture_dash_clone_dash_HN70  \
# SampleID
# SRR6444565                                                0.0
# SRR6443884                                                0.0
# SRR6444382                                                0.0
# SRR6444917                                                0.0
# SRR6443930                                                0.0
#
#             marine_dash_group  marine_dash_sediment_dash_metagenome  \
# SampleID
# SRR6444565                0.0                                   0.0
# SRR6443884                0.0                                   0.0
# SRR6444382                0.0                                   0.0
# SRR6444917                0.0                                   0.0
# SRR6443930                0.0                                   0.0
#
#             metagenome  rumen_dash_bacterium_dash_YS2  soil_dash_metagenome  \
# SampleID
# SRR6444565    0.009201                            0.0                   0.0
# SRR6443884    0.007985                            0.0                   0.0
# SRR6444382    0.008121                            0.0                   0.0
# SRR6444917    0.001194                            0.0                   0.0
# SRR6443930    0.000000                            0.0                   0.0
#
#             swine_dash_fecal_dash_bacterium_dash_SD_dash_Pec5  vadinBE97  \
# SampleID
# SRR6444565                                                0.0        0.0
# SRR6443884                                                0.0        0.0
# SRR6444382                                                0.0        0.0
# SRR6444917                                                0.0        0.0
# SRR6443930                                                0.0        0.0
#
#             wallaby_dash_gut_dash_metagenome
# SampleID
# SRR6444565                               0.0
# SRR6443884                               0.0
# SRR6444382                               0.0
# SRR6444917                               0.0
# SRR6443930                               0.0
#
# [5 rows x 533 columns]

# %% [markdown]
# # Add pseudocount for zeros

# %%
for sample_id in df_16S.index:
    sample = np.array(df_16S.loc[sample_id])
    minval = np.min(sample[np.nonzero(sample)]) # minimum non-zero value
    sample[sample==0] = minval
    df_16S.loc[sample_id] = sample
df_16S.head()
# Out:
#             Absiella_dash_argi  Absiella_dash_dolichum  Acetanaerobacterium  \
# SampleID
# SRR6444565            0.000215                0.000215             0.000215
# SRR6443884            0.000070                0.000070             0.000070
# SRR6444382            0.000167                0.000167             0.000167
# SRR6444917            0.000199                0.000199             0.000199
# SRR6443930            0.000181                0.000181             0.000181
#
#             Acetoanaerobium  Acetobacterium  Acidaminococcus_dash_intestini  \
# SampleID
# SRR6444565         0.000215        0.000215                        0.000215
# SRR6443884         0.000070        0.000070                        0.000070
# SRR6444382         0.000167        0.000167                        0.000167
# SRR6444917         0.000199        0.000199                        0.000199
# SRR6443930         0.000181        0.000181                        0.000181
#
#             Acidaminococcus_dash_sp_dot__dash_Marseille_dash_P2828  \
# SampleID
# SRR6444565                                           0.000215
# SRR6443884                                           0.000070
# SRR6444382                                           0.000167
# SRR6444917                                           0.000199
# SRR6443930                                           0.000181
#
#             Acinetobacter  Actinobacillus  Actinobacteria  ...  \
# SampleID                                                   ...
# SRR6444565       0.000215        0.000215        0.000215  ...
# SRR6443884       0.000070        0.000070        0.000070  ...
# SRR6444382       0.000167        0.000167        0.000167  ...
# SRR6444917       0.000199        0.000199        0.000199  ...
# SRR6443930       0.000181        0.000181        0.000181  ...
#
#             human_dash_gut_dash_metagenome  \
# SampleID
# SRR6444565                        0.032972
# SRR6443884                        0.034554
# SRR6444382                        0.032344
# SRR6444917                        0.000199
# SRR6443930                        0.000181
#
#             iron_dash_reducing_dash_bacterium_dash_enrichment_dash_culture_dash_clone_dash_HN70  \
# SampleID
# SRR6444565                                           0.000215
# SRR6443884                                           0.000070
# SRR6444382                                           0.000167
# SRR6444917                                           0.000199
# SRR6443930                                           0.000181
#
#             marine_dash_group  marine_dash_sediment_dash_metagenome  \
# SampleID
# SRR6444565           0.000215                              0.000215
# SRR6443884           0.000070                              0.000070
# SRR6444382           0.000167                              0.000167
# SRR6444917           0.000199                              0.000199
# SRR6443930           0.000181                              0.000181
#
#             metagenome  rumen_dash_bacterium_dash_YS2  soil_dash_metagenome  \
# SampleID
# SRR6444565    0.009201                       0.000215              0.000215
# SRR6443884    0.007985                       0.000070              0.000070
# SRR6444382    0.008121                       0.000167              0.000167
# SRR6444917    0.001194                       0.000199              0.000199
# SRR6443930    0.000181                       0.000181              0.000181
#
#             swine_dash_fecal_dash_bacterium_dash_SD_dash_Pec5  vadinBE97  \
# SampleID
# SRR6444565                                           0.000215   0.000215
# SRR6443884                                           0.000070   0.000070
# SRR6444382                                           0.000167   0.000167
# SRR6444917                                           0.000199   0.000199
# SRR6443930                                           0.000181   0.000181
#
#             wallaby_dash_gut_dash_metagenome
# SampleID
# SRR6444565                          0.000215
# SRR6443884                          0.000070
# SRR6444382                          0.000167
# SRR6444917                          0.000199
# SRR6443930                          0.000181
#
# [5 rows x 533 columns]

# %% [markdown]
# # Read metadata for inulin and control

# %%
df_meta = pd.read_csv('./metadata.txt', sep='\t', index_col=0)
df_meta = df_meta[['Group','Subject_ID','status']]
df_meta = df_meta[(df_meta.Group=='inulin') | (df_meta.Group=='accessible')]
df_meta['Day'] = [0 if s=='before' else 21 for s in df_meta.status]
df_meta['Diet'] = [1 if g=='inulin' else 0 for g in df_meta['Group']]
df_meta = df_meta.drop('Group', axis=1)
df_meta.head()
# Out:
#            Subject_ID  status  Day  Diet
# #SampleID
# SRR6444565       U222  before    0     0
# SRR6443884       U222  before    0     0
# SRR6444382       U222  before    0     0
# SRR6444917       U225  before    0     0
# SRR6443930       U225  before    0     0

# %% [markdown]
# # Select the 20 most abundant taxa

# %%
topX = 20
df_16S_T = df_16S.loc[df_meta.index].T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#             Bacteroides  Faecalibacterium  Lachnospiraceae  \
# #SampleID
# SRR6444565     0.197580          0.136827         0.024022
# SRR6443884     0.243131          0.099128         0.017050
# SRR6444382     0.214061          0.110743         0.028395
# SRR6444917     0.578520          0.063804         0.117987
# SRR6443930     0.610679          0.055143         0.050196
#
#             Trichuris_dash_trichiura_dash__leftroundbrackethuman_dash_whipworm_rightroundbracket_  \
# #SampleID
# SRR6444565                                           0.000215
# SRR6443884                                           0.000070
# SRR6444382                                           0.000167
# SRR6444917                                           0.000199
# SRR6443930                                           0.000181
#
#             Alistipes  Prevotella  \
# #SampleID
# SRR6444565   0.028962    0.000215
# SRR6443884   0.032008    0.000070
# SRR6444382   0.031565    0.000167
# SRR6444917   0.037393    0.000199
# SRR6443930   0.079698    0.000181
#
#             Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# #SampleID
# SRR6444565                                           0.037984
# SRR6443884                                           0.037064
# SRR6444382                                           0.037600
# SRR6444917                                           0.000630
# SRR6443930                                           0.000181
#
#             Parabacteroides  Bifidobacterium   Blautia  Anaerostipes  \
# #SampleID
# SRR6444565         0.007446         0.009165  0.018580      0.006158
# SRR6443884         0.006764         0.004916  0.014191      0.005230
# SRR6444382         0.006981         0.007370  0.020525      0.007231
# SRR6444917         0.003550         0.016358  0.014168      0.000299
# SRR6443930         0.004404         0.008386  0.006154      0.000181
#
#             Parasutterella_dash_excrementihominis  \
# #SampleID
# SRR6444565                               0.000215
# SRR6443884                               0.000070
# SRR6444382                               0.000167
# SRR6444917                               0.026942
# SRR6443930                               0.023409
#
#             Bacteroides_dash_plebeius_dash_DSM_dash_17135  Ruminococcus  \
# #SampleID
# SRR6444565                                       0.114631      0.006623
# SRR6443884                                       0.125837      0.005335
# SRR6444382                                       0.115360      0.006869
# SRR6444917                                       0.000199      0.003782
# SRR6443930                                       0.000181      0.000181
#
#             Fusicatenibacter  gut_dash_metagenome  Roseburia  \
# #SampleID
# SRR6444565          0.003508             0.036051   0.027852
# SRR6443884          0.002789             0.034100   0.022873
# SRR6444382          0.003560             0.032734   0.029730
# SRR6444917          0.000199             0.000630   0.000199
# SRR6443930          0.000181             0.000181   0.000181
#
#             Lachnospiraceae_dash_UCG_dash_004  metagenome  \
# #SampleID
# SRR6444565                           0.001539    0.009201
# SRR6443884                           0.003626    0.007985
# SRR6444382                           0.004533    0.008121
# SRR6444917                           0.000199    0.001194
# SRR6443930                           0.000181    0.000181
#
#             Bacteroides_dash_coprocola
# #SampleID
# SRR6444565                    0.000215
# SRR6443884                    0.000070
# SRR6444382                    0.000167
# SRR6444917                    0.000199
# SRR6443930                    0.000181

# %%
list(df_16S_topX.columns)
# Out:
# ['Bacteroides',
#  'Faecalibacterium',
#  'Lachnospiraceae',
#  'Trichuris_dash_trichiura_dash__leftroundbrackethuman_dash_whipworm_rightroundbracket_',
#  'Alistipes',
#  'Prevotella',
#  'Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57',
#  'Parabacteroides',
#  'Bifidobacterium',
#  'Blautia',
#  'Anaerostipes',
#  'Parasutterella_dash_excrementihominis',
#  'Bacteroides_dash_plebeius_dash_DSM_dash_17135',
#  'Ruminococcus',
#  'Fusicatenibacter',
#  'gut_dash_metagenome',
#  'Roseburia',
#  'Lachnospiraceae_dash_UCG_dash_004',
#  'metagenome',
#  'Bacteroides_dash_coprocola']

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX_w_meta = pd.merge(df_meta, df_16S_topX/df_16S_topX.max().max(), left_index=True, right_index=True, how='inner')
df_16S_topX_w_meta = df_16S_topX_w_meta.groupby(['Subject_ID','status']).agg(np.mean).reset_index()
df_16S_topX_w_meta.head()
# Out:
#   Subject_ID  status  Day  Diet  Bacteroides  Faecalibacterium  \
# 0       U042  before    0     1     0.444946          0.100588
# 1       U042  during   21     1     0.471585          0.037131
# 2       U068  before    0     1     0.045633          0.056045
# 3       U068  during   21     1     0.070620          0.093106
# 4       U075  before    0     1     0.227864          0.133095
#
#    Lachnospiraceae  \
# 0         0.080670
# 1         0.080455
# 2         0.043214
# 3         0.044719
# 4         0.049664
#
#    Trichuris_dash_trichiura_dash__leftroundbrackethuman_dash_whipworm_rightroundbracket_  \
# 0                                           0.000128
# 1                                           0.000254
# 2                                           0.177269
# 3                                           0.120436
# 4                                           0.013882
#
#    Alistipes  Prevotella  ...  Anaerostipes  \
# 0   0.027035    0.000128  ...      0.003644
# 1   0.038842    0.000406  ...      0.003687
# 2   0.000270    0.328534  ...      0.000425
# 3   0.000256    0.258661  ...      0.002214
# 4   0.017764    0.000785  ...      0.014899
#
#    Parasutterella_dash_excrementihominis  \
# 0                               0.000128
# 1                               0.000254
# 2                               0.000161
# 3                               0.000199
# 4                               0.016442
#
#    Bacteroides_dash_plebeius_dash_DSM_dash_17135  Ruminococcus  \
# 0                                       0.000128      0.009113
# 1                                       0.000254      0.010182
# 2                                       0.000161      0.021873
# 3                                       0.000153      0.008714
# 4                                       0.000179      0.014111
#
#    Fusicatenibacter  gut_dash_metagenome  Roseburia  \
# 0          0.022899             0.007670   0.025910
# 1          0.008189             0.016515   0.047139
# 2          0.004559             0.011077   0.002486
# 3          0.007876             0.017048   0.009354
# 4          0.045612             0.011263   0.018615
#
#    Lachnospiraceae_dash_UCG_dash_004  metagenome  Bacteroides_dash_coprocola
# 0                           0.007428    0.011713                    0.000128
# 1                           0.008635    0.009576                    0.000254
# 2                           0.006962    0.011519                    0.015651
# 3                           0.004645    0.018583                    0.004436
# 4                           0.002632    0.017789                    0.000179
#
# [5 rows x 24 columns]

# %% [markdown]
# # Calculate log-derivatives (dlog(B)/dt)

# %%
df_deriv = deepcopy(df_16S_topX_w_meta)
for curr_sub in set(df_deriv.Subject_ID):
    curr_df = df_deriv[df_deriv.Subject_ID==curr_sub].sort_values(by='Day')
    for taxon in bacterial_taxa:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[taxon])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_deriv.loc[df_deriv.Subject_ID==curr_sub, taxon] = ydata_d1
df_deriv.head()
# Out:
#   Subject_ID  status  Day  Diet  Bacteroides  Faecalibacterium  \
# 0       U042  before    0     1     0.001269         -0.003022
# 1       U042  during   21     1     0.001269         -0.003022
# 2       U068  before    0     1     0.001190          0.001765
# 3       U068  during   21     1     0.001190          0.001765
# 4       U075  before    0     1     0.005197         -0.003111
#
#    Lachnospiraceae  \
# 0        -0.000010
# 1        -0.000010
# 2         0.000072
# 3         0.000072
# 4        -0.000158
#
#    Trichuris_dash_trichiura_dash__leftroundbrackethuman_dash_whipworm_rightroundbracket_  \
# 0                                           0.000006
# 1                                           0.000006
# 2                                          -0.002706
# 3                                          -0.002706
# 4                                          -0.000459
#
#       Alistipes  Prevotella  ...  Anaerostipes  \
# 0  5.622348e-04    0.000013  ...      0.000002
# 1  5.622348e-04    0.000013  ...      0.000002
# 2 -7.087060e-07   -0.003327  ...      0.000085
# 3 -7.087060e-07   -0.003327  ...      0.000085
# 4  6.566401e-04   -0.000024  ...      0.000185
#
#    Parasutterella_dash_excrementihominis  \
# 0                               0.000006
# 1                               0.000006
# 2                               0.000002
# 3                               0.000002
# 4                               0.000248
#
#    Bacteroides_dash_plebeius_dash_DSM_dash_17135  Ruminococcus  \
# 0                                   5.970561e-06      0.000051
# 1                                   5.970561e-06      0.000051
# 2                                  -3.810299e-07     -0.000627
# 3                                  -3.810299e-07     -0.000627
# 4                                  -4.237658e-06      0.000450
#
#    Fusicatenibacter  gut_dash_metagenome  Roseburia  \
# 0         -0.000700             0.000421   0.001011
# 1         -0.000700             0.000421   0.001011
# 2          0.000158             0.000284   0.000327
# 3          0.000158             0.000284   0.000327
# 4         -0.000997             0.000204  -0.000491
#
#    Lachnospiraceae_dash_UCG_dash_004  metagenome  Bacteroides_dash_coprocola
# 0                           0.000057   -0.000102                    0.000006
# 1                           0.000057   -0.000102                    0.000006
# 2                          -0.000110    0.000336                   -0.000534
# 3                          -0.000110    0.000336                   -0.000534
# 4                           0.000112   -0.000448                   -0.000004
#
# [5 rows x 24 columns]

# %% [markdown]
# # Construct regression matrix

# %%
# Ymat should be samples by bacteria
Ymat = df_deriv[bacterial_taxa].values
Ymat = Ymat.flatten(order='F')
Ymat = StandardScaler().fit_transform(Ymat.reshape(-1,1)).reshape(1,-1)[0] # standardize
Ymat
# Out:
# array([ 0.89588099,  0.89588099,  0.83846764, ..., -2.43909054,
#        -0.01323803, -0.01323803])

# %%
len(Ymat)
# Out:
# 3560

# %%
Xmat = np.zeros(shape=(topX*len(df_deriv.index), (topX+2)*topX))
for k in np.arange(topX):
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)] = 1
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+1] = df_deriv.Diet.values
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+2:(k+1)*(topX+2)] = df_16S_topX_w_meta[bacterial_taxa].values
Xmat
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 4.44946301e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 4.71585345e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 4.56331153e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         9.46741789e-03, 6.74048698e-03, 6.98077419e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.20216398e-02, 3.61930501e-03, 2.97519882e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.50391700e-02, 4.41138219e-03, 7.73246735e-04]])

# %% [markdown]
# # Write stan program

# %% [markdown]
# ## write data

# %%
json_str = '{\n"N" : %d,\n'%(len(Ymat))

# y variable
json_str += '\"dlogX\" : [%s],\n'%(','.join(list(Ymat.astype(str))))

# x variable
for k1,c1 in enumerate(bacterial_taxa):
    # growth rate
    json_str += '\"growth_rate_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)].astype(str))))
    # diet response
    json_str += '\"inulin_response_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)+1].astype(str))))
    # bacterial interactions
    for k2,c2 in enumerate(bacterial_taxa):
        v = list(Xmat[:,k1*(topX+2)+2+k2].astype(str))
        json_str += '\"pairwise_interaction_%s_%s\" : [%s]'%(c1,c2,','.join(v))
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            json_str += '\n}'
        else:
            json_str += ',\n'
#print(json_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.data.json", "w")
text_file.write("%s" % json_str)
text_file.close()

# %% [markdown]
# ## write model

# %%
# data block
model_str = 'data {\n'
model_str += '\tint<lower=0> N;\n'
model_str += '\tvector[N] dlogX;\n'
for c1 in bacterial_taxa:
    model_str += '\tvector[N] growth_rate_%s;\n'%(c1)
    model_str += '\tvector[N] inulin_response_%s;\n'%(c1)
    for c2 in bacterial_taxa:
        model_str += '\tvector[N] pairwise_interaction_%s_%s;\n'%(c1,c2)
model_str += '}\n'

# parameter block
model_str += 'parameters {\n\treal<lower=0,upper=1> sigma;\n'
for c1 in bacterial_taxa:
    model_str += '\treal alpha__%s;\n'%(c1) # growth rate
    model_str += '\treal epsilon__%s;\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\treal beta__%s_%s;\n'%(c1,c2)
model_str += '}\n'       
        
# model block
model_str += 'model {\n\tsigma ~ uniform(0,1);\n'
for c1 in bacterial_taxa:
    model_str += '\talpha__%s ~ normal(0,1);\n'%(c1) # growth rate
    model_str += '\tepsilon__%s ~ normal(0,1);\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\tbeta__%s_%s ~ normal(0,1);\n'%(c1,c2)
model_str += '\tdlogX ~ normal('
for c1 in bacterial_taxa:
    model_str += 'alpha__%s*growth_rate_%s+'%(c1,c1) # growth rate
    model_str += 'epsilon__%s*inulin_response_%s+'%(c1,c1) # inulin response
    for c2 in bacterial_taxa:
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s'%(c1,c2,c1,c2)
        else:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s+'%(c1,c2,c1,c2)
model_str += ', sigma);\n}'
#print(model_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.stan", "w")
text_file.write("%s" % model_str)
text_file.close()

# %% [markdown]
# # Plot stan output

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d.csv"%(i) for i in np.arange(1,4)])

# %%
lines = []
    
# basal growth rate
for c in bacterial_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# inulin response
for c in bacterial_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['inulin_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])

# pairwise interactions
for c1 in bacterial_taxa:
    for c2 in bacterial_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.head()
# Out:
#                 Type                           Taxa  Left  Right  Middle  \
# 0  basal_growth_rate                 Muribaculaceae -0.16   0.15  -0.005
# 1  basal_growth_rate  Bacteroides_dash_acidifaciens -0.01   0.30   0.145
# 2  basal_growth_rate   Akkermansia_dash_muciniphila -0.27   0.04  -0.115
# 3  basal_growth_rate                 Faecalibaculum -0.20   0.12  -0.040
# 4  basal_growth_rate                 Parasutterella -0.20   0.12  -0.040
#
#         SNR  Significant
# 0 -0.044859        False
# 1  1.835619        False
# 2 -1.416896        False
# 3 -0.531562        False
# 4 -0.540205        False

# %%
df_stan_output_summary.to_excel('bayesian_regression_summary_top20.xlsx')

# %% [markdown]
# # Plot

# %%
df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True]
df_stan_output_summary
# Out:
#                      Type                                               Taxa  \
# 20        inulin_response                                     Muribaculaceae
# 21        inulin_response                      Bacteroides_dash_acidifaciens
# 23        inulin_response                                     Faecalibaculum
# 24        inulin_response                                     Parasutterella
# 25        inulin_response                                        Bacteroides
# 40   pairwise_interaction               ('Muribaculaceae', 'Muribaculaceae')
# 41   pairwise_interaction  ('Muribaculaceae', 'Bacteroides_dash_acidifaci...
# 51   pairwise_interaction          ('Muribaculaceae', 'Desulfovibrionaceae')
# 52   pairwise_interaction  ('Muribaculaceae', 'Clostridia_dash_UCG_dash_0...
# 60   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Muribaculac...
# 62   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Akkermansia...
# 63   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Faecalibacu...
# 64   pairwise_interaction  ('Bacteroides_dash_acidifaciens', 'Parasuttere...
# 65   pairwise_interaction   ('Bacteroides_dash_acidifaciens', 'Bacteroides')
# 81   pairwise_interaction  ('Akkermansia_dash_muciniphila', 'Bacteroides_...
# 100  pairwise_interaction               ('Faecalibaculum', 'Muribaculaceae')
# 376  pairwise_interaction  ('Escherichia_dash_Shigella', 'Escherichia_das...
#
#      Left  Right  Middle        SNR  Significant
# 20   1.08   1.62   1.350   9.958040         True
# 21   1.89   2.42   2.155  15.846923         True
# 23   0.48   1.01   0.745   5.506163         True
# 24   0.14   0.68   0.410   3.039780         True
# 25   0.04   0.58   0.310   2.265775         True
# 40  -1.59  -0.29  -0.940  -2.864951         True
# 41   0.23   2.31   1.270   2.392931         True
# 51   0.27   3.71   1.990   2.280134         True
# 52  -3.74  -0.06  -1.900  -2.016358         True
# 60  -3.81  -2.50  -3.155  -9.603366         True
# 62  -4.57  -1.77  -3.170  -4.472396         True
# 63  -4.31  -1.00  -2.655  -3.148145         True
# 64  -4.26  -0.57  -2.415  -2.600989         True
# 65  -5.89  -2.35  -4.120  -4.574359         True
# 81   0.01   2.09   1.050   1.970520         True
# 100 -1.77  -0.47  -1.120  -3.398489         True
# 376  0.60   3.69   2.145   2.731059         True
