# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.interpolate import CubicSpline
from sklearn.metrics import mean_squared_error
import warnings
import itertools
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
import scipy.stats.kde as kde

# %% [markdown]
# # Read MGS data

# %%
df_MGS = pd.read_excel('./MGS_relative_abundance.xlsx', index_col=0)
df_MGS.columns = [c.strip() for c in df_MGS.columns]
df_MGS.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_MGS.columns]
df_MGS.head()
# Out:
#             Bacteroides_space_uniformis  Bacteroides_space_xylanisolvens  \
# SampleID
# DBH1W00101                     0.103458                         0.108759
# DBH1W00102                     0.067379                         0.006621
# DBH1W00103                     0.000184                         0.000187
# DBH1W00104                     0.000215                         0.000156
# DBH1W00201                     0.009104                         0.004670
#
#             Bacteroides_space_stercoris  Bacteroides_space_ovatus  \
# SampleID
# DBH1W00101                     0.062066                  0.082845
# DBH1W00102                     0.018305                  0.049871
# DBH1W00103                     0.000215                  0.000281
# DBH1W00104                     0.000029                  0.000292
# DBH1W00201                     0.005764                  0.004424
#
#             Bacteroides_space_caccae  Bacteroides_space_thetaiotaomicron  \
# SampleID
# DBH1W00101                  0.021732                            0.020477
# DBH1W00102                  0.018404                            0.009712
# DBH1W00103                  0.000050                            0.000147
# DBH1W00104                  0.000034                            0.000089
# DBH1W00201                  0.000113                            0.004620
#
#             Bacteroides_space_fragilis  Bacteroides_space_intestinalis  \
# SampleID
# DBH1W00101                    0.006537                        0.004749
# DBH1W00102                    0.001669                        0.000106
# DBH1W00103                    0.005202                        0.000002
# DBH1W00104                    0.000054                        0.000000
# DBH1W00201                    0.001718                        0.000019
#
#             Bacteroides_space_eggerthii  Bacteroides_space_fragilis_A  ...  \
# SampleID                                                               ...
# DBH1W00101                     0.002593                      0.001340  ...
# DBH1W00102                     0.001615                      0.000187  ...
# DBH1W00103                     0.000031                      0.000021  ...
# DBH1W00104                     0.000052                      0.000004  ...
# DBH1W00201                     0.000044                      0.000100  ...
#
#             Pseudozobellia_space_thermophila  BACL21_space_sp002694465  \
# SampleID
# DBH1W00101                               0.0                       0.0
# DBH1W00102                               0.0                       0.0
# DBH1W00103                               0.0                       0.0
# DBH1W00104                               0.0                       0.0
# DBH1W00201                               0.0                       0.0
#
#             Pantoea_space_rodasii  Tachikawaea_space_gelatinosa  \
# SampleID
# DBH1W00101                    0.0                           0.0
# DBH1W00102                    0.0                           0.0
# DBH1W00103                    0.0                           0.0
# DBH1W00104                    0.0                           0.0
# DBH1W00201                    0.0                           0.0
#
#             AG_dash_426_dash_I14_space_sp003213175  Convivina_space_intestini  \
# SampleID
# DBH1W00101                                     0.0                        0.0
# DBH1W00102                                     0.0                        0.0
# DBH1W00103                                     0.0                        0.0
# DBH1W00104                                     0.0                        0.0
# DBH1W00201                                     0.0                        0.0
#
#             Parageobacillus_space_galactosidasius  \
# SampleID
# DBH1W00101                                    0.0
# DBH1W00102                                    0.0
# DBH1W00103                                    0.0
# DBH1W00104                                    0.0
# DBH1W00201                                    0.0
#
#             AG_dash_409_dash_J16_space_sp003215655  UBA5194_space_sp002412935  \
# SampleID
# DBH1W00101                                     0.0                        0.0
# DBH1W00102                                     0.0                        0.0
# DBH1W00103                                     0.0                        0.0
# DBH1W00104                                     0.0                        0.0
# DBH1W00201                                     0.0                        0.0
#
#             GCA_dash_2746535_space_sp002746535
# SampleID
# DBH1W00101                                 0.0
# DBH1W00102                                 0.0
# DBH1W00103                                 0.0
# DBH1W00104                                 0.0
# DBH1W00201                                 0.0
#
# [5 rows x 13510 columns]

# %% [markdown]
# # Add pseudocount for zeros

# %%
for sample_id in df_MGS.index:
    sample = np.array(df_MGS.loc[sample_id])
    minval = np.min(sample[np.nonzero(sample)]) # minimum non-zero value
    sample[sample==0] = minval
    df_MGS.loc[sample_id] = sample
df_MGS.head()
# Out:
#             Bacteroides_space_uniformis  Bacteroides_space_xylanisolvens  \
# SampleID
# DBH1W00101                     0.103458                         0.108759
# DBH1W00102                     0.067379                         0.006621
# DBH1W00103                     0.000184                         0.000187
# DBH1W00104                     0.000215                         0.000156
# DBH1W00201                     0.009104                         0.004670
#
#             Bacteroides_space_stercoris  Bacteroides_space_ovatus  \
# SampleID
# DBH1W00101                     0.062066                  0.082845
# DBH1W00102                     0.018305                  0.049871
# DBH1W00103                     0.000215                  0.000281
# DBH1W00104                     0.000029                  0.000292
# DBH1W00201                     0.005764                  0.004424
#
#             Bacteroides_space_caccae  Bacteroides_space_thetaiotaomicron  \
# SampleID
# DBH1W00101                  0.021732                            0.020477
# DBH1W00102                  0.018404                            0.009712
# DBH1W00103                  0.000050                            0.000147
# DBH1W00104                  0.000034                            0.000089
# DBH1W00201                  0.000113                            0.004620
#
#             Bacteroides_space_fragilis  Bacteroides_space_intestinalis  \
# SampleID
# DBH1W00101                    0.006537                    4.749233e-03
# DBH1W00102                    0.001669                    1.062671e-04
# DBH1W00103                    0.005202                    1.751363e-06
# DBH1W00104                    0.000054                    9.398365e-07
# DBH1W00201                    0.001718                    1.895403e-05
#
#             Bacteroides_space_eggerthii  Bacteroides_space_fragilis_A  ...  \
# SampleID                                                               ...
# DBH1W00101                     0.002593                      0.001340  ...
# DBH1W00102                     0.001615                      0.000187  ...
# DBH1W00103                     0.000031                      0.000021  ...
# DBH1W00104                     0.000052                      0.000004  ...
# DBH1W00201                     0.000044                      0.000100  ...
#
#             Pseudozobellia_space_thermophila  BACL21_space_sp002694465  \
# SampleID
# DBH1W00101                      1.145898e-06              1.145898e-06
# DBH1W00102                      7.782288e-07              7.782288e-07
# DBH1W00103                      9.866833e-07              9.866833e-07
# DBH1W00104                      9.398365e-07              9.398365e-07
# DBH1W00201                      1.037156e-06              1.037156e-06
#
#             Pantoea_space_rodasii  Tachikawaea_space_gelatinosa  \
# SampleID
# DBH1W00101           1.145898e-06                  1.145898e-06
# DBH1W00102           7.782288e-07                  7.782288e-07
# DBH1W00103           9.866833e-07                  9.866833e-07
# DBH1W00104           9.398365e-07                  9.398365e-07
# DBH1W00201           1.037156e-06                  1.037156e-06
#
#             AG_dash_426_dash_I14_space_sp003213175  Convivina_space_intestini  \
# SampleID
# DBH1W00101                            1.145898e-06               1.145898e-06
# DBH1W00102                            7.782288e-07               7.782288e-07
# DBH1W00103                            9.866833e-07               9.866833e-07
# DBH1W00104                            9.398365e-07               9.398365e-07
# DBH1W00201                            1.037156e-06               1.037156e-06
#
#             Parageobacillus_space_galactosidasius  \
# SampleID
# DBH1W00101                           1.145898e-06
# DBH1W00102                           7.782288e-07
# DBH1W00103                           9.866833e-07
# DBH1W00104                           9.398365e-07
# DBH1W00201                           1.037156e-06
#
#             AG_dash_409_dash_J16_space_sp003215655  UBA5194_space_sp002412935  \
# SampleID
# DBH1W00101                            1.145898e-06               1.145898e-06
# DBH1W00102                            7.782288e-07               7.782288e-07
# DBH1W00103                            9.866833e-07               9.866833e-07
# DBH1W00104                            9.398365e-07               9.398365e-07
# DBH1W00201                            1.037156e-06               1.037156e-06
#
#             GCA_dash_2746535_space_sp002746535
# SampleID
# DBH1W00101                        1.145898e-06
# DBH1W00102                        7.782288e-07
# DBH1W00103                        9.866833e-07
# DBH1W00104                        9.398365e-07
# DBH1W00201                        1.037156e-06
#
# [5 rows x 13510 columns]

# %% [markdown]
# # Read metadata for WTP diet

# %%
df_meta = pd.read_csv('./PathTable_meta.tsv', sep='\t', index_col=0)
df_meta = df_meta[['group','subject','day']]
df_meta.columns = ['Group','Subject','Day']
df_meta['Diet'] = [1 if g=='W' else 0 for g in df_meta['Group']]
df_meta = df_meta.drop('Group', axis=1)
df_meta.head()
# Out:
#            Subject  Day  Diet
# #SampleID
# DBH1W00101   1W001    0     1
# DBH1W00102   1W001   28     1
# DBH1W00103   1W001   56     1
# DBH1W00104   1W001   84     1
# DBH1W00201   1W002    0     1

# %% [markdown]
# # Select the 20 most abundant taxa

# %%
topX = 20
df_MGS_T = df_MGS.loc[df_meta.index].T
df_MGS_T['mean'] = df_MGS_T.mean(axis=1)
df_MGS_T = df_MGS_T.sort_values(by=['mean'],axis=0,ascending=False)
df_MGS_T = df_MGS_T.drop('mean', axis=1)
df_MGS_topX = df_MGS_T.iloc[0:topX].T
df_MGS_topX.head()
# Out:
#             Prevotella_space_copri  Bifidobacterium_space_pseudocatenulatum  \
# #SampleID
# DBH1W00101                0.000387                                 0.034076
# DBH1W00102                0.000927                                 0.081381
# DBH1W00103                0.156179                                 0.244621
# DBH1W00104                0.078140                                 0.295985
# DBH1W00201                0.052423                                 0.000204
#
#             Bifidobacterium_space_longum  Bacteroides_B_space_vulgatus  \
# #SampleID
# DBH1W00101                      0.021804                      0.128373
# DBH1W00102                      0.134484                      0.079870
# DBH1W00103                      0.296205                      0.000883
# DBH1W00104                      0.319400                      0.001793
# DBH1W00201                      0.000922                      0.010438
#
#             Agathobacter_space_rectale  Agathobacter_space_faecis  \
# #SampleID
# DBH1W00101                    0.000629                   0.000386
# DBH1W00102                    0.000762                   0.000382
# DBH1W00103                    0.000185                   0.000112
# DBH1W00104                    0.000437                   0.000083
# DBH1W00201                    0.023272                   0.010242
#
#             Fusicatenibacter_space_saccharivorans  \
# #SampleID
# DBH1W00101                               0.000217
# DBH1W00102                               0.000274
# DBH1W00103                               0.000152
# DBH1W00104                               0.018365
# DBH1W00201                               0.003838
#
#             Bacteroides_space_uniformis  Bifidobacterium_space_adolescentis  \
# #SampleID
# DBH1W00101                     0.103458                            0.000163
# DBH1W00102                     0.067379                            0.000381
# DBH1W00103                     0.000184                            0.001235
# DBH1W00104                     0.000215                            0.001333
# DBH1W00201                     0.009104                            0.000004
#
#             Faecalibacterium_space_prausnitzii_C  \
# #SampleID
# DBH1W00101                              0.001059
# DBH1W00102                              0.001126
# DBH1W00103                              0.000083
# DBH1W00104                              0.000154
# DBH1W00201                              0.004366
#
#             Parabacteroides_space_distasonis  Prevotella_space_copri_A  \
# #SampleID
# DBH1W00101                          0.030177                  0.000952
# DBH1W00102                          0.160462                  0.000792
# DBH1W00103                          0.000245                  0.003693
# DBH1W00104                          0.000351                  0.001898
# DBH1W00201                          0.005780                  0.093293
#
#             Faecalibacterium_space_prausnitzii_G  Bacteroides_space_stercoris  \
# #SampleID
# DBH1W00101                              0.032171                     0.062066
# DBH1W00102                              0.045500                     0.018305
# DBH1W00103                              0.000556                     0.000215
# DBH1W00104                              0.004688                     0.000029
# DBH1W00201                              0.007577                     0.005764
#
#             Ruminococcus_E_space_bromii_B  Bacteroides_A_space_plebeius_A  \
# #SampleID
# DBH1W00101                       0.000107                        0.000107
# DBH1W00102                       0.000137                        0.000048
# DBH1W00103                       0.000056                        0.000033
# DBH1W00104                       0.000040                        0.000002
# DBH1W00201                       0.000205                        0.000018
#
#             Faecalibacterium_space_prausnitzii_K  \
# #SampleID
# DBH1W00101                              0.001047
# DBH1W00102                              0.001175
# DBH1W00103                              0.000055
# DBH1W00104                              0.000147
# DBH1W00201                              0.011709
#
#             Faecalibacterium_space_prausnitzii_D  Blautia_A_space_wexlerae  \
# #SampleID
# DBH1W00101                              0.000782                  0.004583
# DBH1W00102                              0.000850                  0.009276
# DBH1W00103                              0.000109                  0.000139
# DBH1W00104                              0.000146                  0.009632
# DBH1W00201                              0.005752                  0.003655
#
#             Faecalicatena_space_faecis
# #SampleID
# DBH1W00101                    0.011079
# DBH1W00102                    0.003040
# DBH1W00103                    0.003608
# DBH1W00104                    0.002114
# DBH1W00201                    0.000301

# %%
list(df_MGS_topX.columns)
# Out:
# ['Prevotella_space_copri',
#  'Bifidobacterium_space_pseudocatenulatum',
#  'Bifidobacterium_space_longum',
#  'Bacteroides_B_space_vulgatus',
#  'Agathobacter_space_rectale',
#  'Agathobacter_space_faecis',
#  'Fusicatenibacter_space_saccharivorans',
#  'Bacteroides_space_uniformis',
#  'Bifidobacterium_space_adolescentis',
#  'Faecalibacterium_space_prausnitzii_C',
#  'Parabacteroides_space_distasonis',
#  'Prevotella_space_copri_A',
#  'Faecalibacterium_space_prausnitzii_G',
#  'Bacteroides_space_stercoris',
#  'Ruminococcus_E_space_bromii_B',
#  'Bacteroides_A_space_plebeius_A',
#  'Faecalibacterium_space_prausnitzii_K',
#  'Faecalibacterium_space_prausnitzii_D',
#  'Blautia_A_space_wexlerae',
#  'Faecalicatena_space_faecis']

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
bacterial_taxa = list(df_MGS_topX.columns)
df_MGS_topX_w_meta = pd.merge(df_meta, df_MGS_topX/df_MGS_topX.max().max(), left_index=True, right_index=True, how='inner')
df_MGS_topX_w_meta.head()
# Out:
#            Subject  Day  Diet  Prevotella_space_copri  \
# #SampleID
# DBH1W00101   1W001    0     1                0.000561
# DBH1W00102   1W001   28     1                0.001343
# DBH1W00103   1W001   56     1                0.226360
# DBH1W00104   1W001   84     1                0.113254
# DBH1W00201   1W002    0     1                0.075980
#
#             Bifidobacterium_space_pseudocatenulatum  \
# #SampleID
# DBH1W00101                                 0.049389
# DBH1W00102                                 0.117951
# DBH1W00103                                 0.354545
# DBH1W00104                                 0.428990
# DBH1W00201                                 0.000296
#
#             Bifidobacterium_space_longum  Bacteroides_B_space_vulgatus  \
# #SampleID
# DBH1W00101                      0.031602                      0.186060
# DBH1W00102                      0.194917                      0.115761
# DBH1W00103                      0.429308                      0.001280
# DBH1W00104                      0.462926                      0.002598
# DBH1W00201                      0.001337                      0.015129
#
#             Agathobacter_space_rectale  Agathobacter_space_faecis  \
# #SampleID
# DBH1W00101                    0.000912                   0.000559
# DBH1W00102                    0.001105                   0.000554
# DBH1W00103                    0.000268                   0.000163
# DBH1W00104                    0.000633                   0.000120
# DBH1W00201                    0.033730                   0.014844
#
#             Fusicatenibacter_space_saccharivorans  ...  \
# #SampleID                                          ...
# DBH1W00101                               0.000314  ...
# DBH1W00102                               0.000397  ...
# DBH1W00103                               0.000220  ...
# DBH1W00104                               0.026617  ...
# DBH1W00201                               0.005563  ...
#
#             Parabacteroides_space_distasonis  Prevotella_space_copri_A  \
# #SampleID
# DBH1W00101                          0.043737                  0.001380
# DBH1W00102                          0.232567                  0.001148
# DBH1W00103                          0.000355                  0.005352
# DBH1W00104                          0.000509                  0.002751
# DBH1W00201                          0.008377                  0.135216
#
#             Faecalibacterium_space_prausnitzii_G  Bacteroides_space_stercoris  \
# #SampleID
# DBH1W00101                              0.046628                     0.089956
# DBH1W00102                              0.065947                     0.026531
# DBH1W00103                              0.000806                     0.000312
# DBH1W00104                              0.006795                     0.000042
# DBH1W00201                              0.010982                     0.008354
#
#             Ruminococcus_E_space_bromii_B  Bacteroides_A_space_plebeius_A  \
# #SampleID
# DBH1W00101                       0.000155                        0.000154
# DBH1W00102                       0.000199                        0.000069
# DBH1W00103                       0.000081                        0.000048
# DBH1W00104                       0.000057                        0.000003
# DBH1W00201                       0.000297                        0.000025
#
#             Faecalibacterium_space_prausnitzii_K  \
# #SampleID
# DBH1W00101                              0.001517
# DBH1W00102                              0.001703
# DBH1W00103                              0.000080
# DBH1W00104                              0.000212
# DBH1W00201                              0.016971
#
#             Faecalibacterium_space_prausnitzii_D  Blautia_A_space_wexlerae  \
# #SampleID
# DBH1W00101                              0.001133                  0.006642
# DBH1W00102                              0.001232                  0.013444
# DBH1W00103                              0.000158                  0.000201
# DBH1W00104                              0.000211                  0.013960
# DBH1W00201                              0.008336                  0.005298
#
#             Faecalicatena_space_faecis
# #SampleID
# DBH1W00101                    0.016057
# DBH1W00102                    0.004406
# DBH1W00103                    0.005229
# DBH1W00104                    0.003064
# DBH1W00201                    0.000436
#
# [5 rows x 23 columns]

# %% [markdown]
# # Calculate log-derivatives (dlog(B)/dt)

# %%
df_deriv = deepcopy(df_MGS_topX_w_meta)
for curr_sub in set(df_deriv.Subject):
    curr_df = df_deriv[df_deriv.Subject==curr_sub].sort_values(by='Day')
    for taxon in bacterial_taxa:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[taxon])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_deriv.loc[df_deriv.Subject==curr_sub, taxon] = ydata_d1
df_deriv.head()
# Out:
#            Subject  Day  Diet  Prevotella_space_copri  \
# #SampleID
# DBH1W00101   1W001    0     1               -0.010671
# DBH1W00102   1W001   28     1                0.007379
# DBH1W00103   1W001   56     1                0.005346
# DBH1W00104   1W001   84     1               -0.016772
# DBH1W00201   1W002    0     1                0.001357
#
#             Bifidobacterium_space_pseudocatenulatum  \
# #SampleID
# DBH1W00101                                -0.004483
# DBH1W00102                                 0.007415
# DBH1W00103                                 0.007520
# DBH1W00104                                -0.004167
# DBH1W00201                                 0.000115
#
#             Bifidobacterium_space_longum  Bacteroides_B_space_vulgatus  \
# #SampleID
# DBH1W00101                      0.001327                      0.000183
# DBH1W00102                      0.008720                     -0.004252
# DBH1W00103                      0.006404                     -0.002973
# DBH1W00104                     -0.005621                      0.004019
# DBH1W00201                      0.001210                     -0.000838
#
#             Agathobacter_space_rectale  Agathobacter_space_faecis  \
# #SampleID
# DBH1W00101                    0.000052                   0.000015
# DBH1W00102                   -0.000025                  -0.000011
# DBH1W00103                   -0.000022                  -0.000012
# DBH1W00104                    0.000061                   0.000013
# DBH1W00201                    0.002033                   0.001039
#
#             Fusicatenibacter_space_saccharivorans  ...  \
# #SampleID                                          ...
# DBH1W00101                               0.000327  ...
# DBH1W00102                              -0.000161  ...
# DBH1W00103                               0.000308  ...
# DBH1W00104                               0.001737  ...
# DBH1W00201                               0.001812  ...
#
#             Parabacteroides_space_distasonis  Prevotella_space_copri_A  \
# #SampleID
# DBH1W00101                          0.022041                 -0.000221
# DBH1W00102                         -0.004664                  0.000138
# DBH1W00103                         -0.008033                  0.000096
# DBH1W00104                          0.011934                 -0.000348
# DBH1W00201                         -0.000462                  0.013164
#
#             Faecalibacterium_space_prausnitzii_G  Bacteroides_space_stercoris  \
# #SampleID
# DBH1W00101                              0.004050                    -0.003064
# DBH1W00102                             -0.001744                    -0.001534
# DBH1W00103                             -0.001982                    -0.000406
# DBH1W00104                              0.003336                     0.000320
# DBH1W00201                             -0.000486                    -0.000491
#
#             Ruminococcus_E_space_bromii_B  Bacteroides_A_space_plebeius_A  \
# #SampleID
# DBH1W00101                       0.000008                   -5.255467e-06
# DBH1W00102                      -0.000003                   -1.363675e-06
# DBH1W00103                      -0.000004                   -6.598660e-07
# DBH1W00104                       0.000004                   -3.144040e-06
# DBH1W00201                      -0.000002                   -9.377800e-07
#
#             Faecalibacterium_space_prausnitzii_K  \
# #SampleID
# DBH1W00101                              0.000081
# DBH1W00102                             -0.000047
# DBH1W00103                             -0.000048
# DBH1W00104                              0.000079
# DBH1W00201                             -0.001853
#
#             Faecalibacterium_space_prausnitzii_D  Blautia_A_space_wexlerae  \
# #SampleID
# DBH1W00101                              0.000052                  0.001161
# DBH1W00102                             -0.000031                 -0.000395
# DBH1W00103                             -0.000032                 -0.000271
# DBH1W00104                              0.000049                  0.001534
# DBH1W00201                              0.000744                 -0.000665
#
#             Faecalicatena_space_faecis
# #SampleID
# DBH1W00101                   -0.000823
# DBH1W00102                   -0.000101
# DBH1W00103                    0.000068
# DBH1W00104                   -0.000315
# DBH1W00201                   -0.000006
#
# [5 rows x 23 columns]

# %% [markdown]
# # Construct regression matrix

# %%
# Ymat should be samples by bacteria
Ymat = df_deriv[bacterial_taxa].values
Ymat = Ymat.flatten(order='F')
Ymat = StandardScaler().fit_transform(Ymat.reshape(-1,1)).reshape(1,-1)[0] # standardize
Ymat
# Out:
# array([-2.31533691,  1.54749912,  1.11227838, ..., -0.03658428,
#        -0.02950455, -0.03871735])

# %%
len(Ymat)
# Out:
# 3440

# %%
Xmat = np.zeros(shape=(topX*len(df_deriv.index), (topX+2)*topX))
for k in np.arange(topX):
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)] = 1
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+1] = df_deriv.Diet.values
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+2:(k+1)*(topX+2)] = df_MGS_topX_w_meta[bacterial_taxa].values
Xmat
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 5.61066896e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 1.34328594e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 2.26359995e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.55402090e-03, 7.15754593e-03, 1.49282085e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         5.31645540e-03, 9.31837282e-03, 1.49795390e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         5.61535116e-03, 8.68676760e-03, 1.36354141e-03]])

# %% [markdown]
# # Write stan program

# %% [markdown]
# ## write data

# %%
json_str = '{\n"N" : %d,\n'%(len(Ymat))

# y variable
json_str += '\"dlogX\" : [%s],\n'%(','.join(list(Ymat.astype(str))))

# x variable
for k1,c1 in enumerate(bacterial_taxa):
    # growth rate
    json_str += '\"growth_rate_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)].astype(str))))
    # diet response
    json_str += '\"WTP_response_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)+1].astype(str))))
    # bacterial interactions
    for k2,c2 in enumerate(bacterial_taxa):
        v = list(Xmat[:,k1*(topX+2)+2+k2].astype(str))
        json_str += '\"pairwise_interaction_%s_%s\" : [%s]'%(c1,c2,','.join(v))
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            json_str += '\n}'
        else:
            json_str += ',\n'
#print(json_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.data.json", "w")
text_file.write("%s" % json_str)
text_file.close()

# %% [markdown]
# ## write model

# %%
# data block
model_str = 'data {\n'
model_str += '\tint<lower=0> N;\n'
model_str += '\tvector[N] dlogX;\n'
for c1 in bacterial_taxa:
    model_str += '\tvector[N] growth_rate_%s;\n'%(c1)
    model_str += '\tvector[N] WTP_response_%s;\n'%(c1)
    for c2 in bacterial_taxa:
        model_str += '\tvector[N] pairwise_interaction_%s_%s;\n'%(c1,c2)
model_str += '}\n'

# parameter block
model_str += 'parameters {\n\treal<lower=0,upper=1> sigma;\n'
for c1 in bacterial_taxa:
    model_str += '\treal alpha__%s;\n'%(c1) # growth rate
    model_str += '\treal epsilon__%s;\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\treal beta__%s_%s;\n'%(c1,c2)
model_str += '}\n'       
        
# model block
model_str += 'model {\n\tsigma ~ uniform(0,1);\n'
for c1 in bacterial_taxa:
    model_str += '\talpha__%s ~ normal(0,1);\n'%(c1) # growth rate
    model_str += '\tepsilon__%s ~ normal(0,1);\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\tbeta__%s_%s ~ normal(0,1);\n'%(c1,c2)
model_str += '\tdlogX ~ normal('
for c1 in bacterial_taxa:
    model_str += 'alpha__%s*growth_rate_%s+'%(c1,c1) # growth rate
    model_str += 'epsilon__%s*WTP_response_%s+'%(c1,c1) # inulin response
    for c2 in bacterial_taxa:
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s'%(c1,c2,c1,c2)
        else:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s+'%(c1,c2,c1,c2)
model_str += ', sigma);\n}'
#print(model_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.stan", "w")
text_file.write("%s" % model_str)
text_file.close()

# %% [markdown]
# # Plot stan output

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d_inulin.csv"%(i) for i in np.arange(1,4)])

# %%
lines = []
    
# basal growth rate
for c in bacterial_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# inulin response
for c in bacterial_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['WTP_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])

# pairwise interactions
for c1 in bacterial_taxa:
    for c2 in bacterial_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.head()
# Out:
#                 Type                                               Taxa  Left  \
# 0  basal_growth_rate                                        Bacteroides -0.36
# 1  basal_growth_rate                                   Faecalibacterium -0.92
# 2  basal_growth_rate                                    Lachnospiraceae -0.72
# 3  basal_growth_rate  Trichuris_dash_trichiura_dash__leftroundbracke... -0.48
# 4  basal_growth_rate                                          Alistipes -0.35
#
#    Right  Middle       SNR  Significant
# 0   0.66   0.150  0.584667        False
# 1   0.09  -0.415 -1.623619        False
# 2   0.31  -0.205 -0.761524        False
# 3   0.52   0.020  0.067067        False
# 4   0.66   0.155  0.600150        False

# %%
df_stan_output_summary.to_excel('bayesian_regression_summary_top20_WTP.xlsx')

# %% [markdown]
# # Plot

# %%
df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20_WTP.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True]
df_stan_output_summary
# Out:
#                      Type                                               Taxa  \
# 8       basal_growth_rate                                    Bifidobacterium
# 21        inulin_response                                   Faecalibacterium
# 23        inulin_response  Trichuris_dash_trichiura_dash__leftroundbracke...
# 26        inulin_response  Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_das...
# 28        inulin_response                                    Bifidobacterium
# 30        inulin_response                                       Anaerostipes
# 42   pairwise_interaction                 ('Bacteroides', 'Lachnospiraceae')
# 43   pairwise_interaction  ('Bacteroides', 'Trichuris_dash_trichiura_dash...
# 48   pairwise_interaction                 ('Bacteroides', 'Bifidobacterium')
# 61   pairwise_interaction           ('Faecalibacterium', 'Faecalibacterium')
# 112  pairwise_interaction  ('Trichuris_dash_trichiura_dash__leftroundbrac...
# 145  pairwise_interaction                       ('Prevotella', 'Prevotella')
# 200  pairwise_interaction                 ('Bifidobacterium', 'Bacteroides')
# 208  pairwise_interaction             ('Bifidobacterium', 'Bifidobacterium')
#
#      Left  Right  Middle       SNR  Significant
# 8    0.03   1.06   0.545  2.116647         True
# 21   0.26   0.85   0.555  3.799384         True
# 23   0.13   0.70   0.415  2.871528         True
# 26  -0.64  -0.08  -0.360 -2.507589         True
# 28   0.48   1.05   0.765  5.313565         True
# 30   0.13   0.71   0.420  2.886729         True
# 42  -4.73  -1.15  -2.940 -3.240980         True
# 43  -3.53  -0.67  -2.100 -2.880639         True
# 48  -4.12  -0.62  -2.370 -2.633815         True
# 61   0.59   3.96   2.275  2.663886         True
# 112 -3.45  -0.36  -1.905 -2.409717         True
# 145  0.73   3.76   2.245  2.915239         True
# 200 -1.74  -0.17  -0.955 -2.416430         True
# 208  4.48   8.04   6.260  6.932907         True
