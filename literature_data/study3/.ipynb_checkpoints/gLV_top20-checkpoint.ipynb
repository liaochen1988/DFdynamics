# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.interpolate import CubicSpline
from sklearn.metrics import mean_squared_error
import warnings
import itertools
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
import scipy.stats.kde as kde

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('./16S_relative_abundance.xlsx', index_col=0)
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#             A2    ASF356  Acetatifactor  Acinetobacter  \
# SampleID
# sample1    0.0  0.000000       0.000000            0.0
# sample10   0.0  0.000000       0.007693            0.0
# sample100  0.0  0.000000       0.000000            0.0
# sample101  0.0  0.000309       0.000000            0.0
# sample102  0.0  0.001437       0.000000            0.0
#
#            Akkermansia_dash_muciniphila  Alistipes  Alloprevotella  \
# SampleID
# sample1                             0.0   0.000000        0.003163
# sample10                            0.0   0.153254        0.031291
# sample100                           0.0   0.005143        0.012320
# sample101                           0.0   0.006024        0.003967
# sample102                           0.0   0.025687        0.011724
#
#            Anaerotruncus  Aquimarina  Aquimarina_dash_muelleri  ...  \
# SampleID                                                        ...
# sample1         0.000000         0.0                       0.0  ...
# sample10        0.031291         0.0                       0.0  ...
# sample100       0.000000         0.0                       0.0  ...
# sample101       0.000000         0.0                       0.0  ...
# sample102       0.000000         0.0                       0.0  ...
#
#            _leftsquarebracket_Clostridium_rightsquarebracket__dash_cocleatum  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Clostridium_rightsquarebracket__dash_innocuum_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_brachy_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_coprostanoligenes_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_fissicatena_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_nodatum_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample1                                                  0.0
# sample10                                                 0.0
# sample100                                                0.0
# sample101                                                0.0
# sample102                                                0.0
#
#            gut_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample1               0.000000         0.0                        0.000000
# sample10              0.000000         0.0                        0.000000
# sample100             0.003843         0.0                        0.000000
# sample101             0.000000         0.0                        0.001019
# sample102             0.003244         0.0                        0.000000
#
# [5 rows x 116 columns]

# %% [markdown]
# # Add pseudocount for zeros

# %%
for sample_id in df_16S.index:
    sample = np.array(df_16S.loc[sample_id])
    minval = np.min(sample[np.nonzero(sample)]) # minimum non-zero value
    sample[sample==0] = minval
    df_16S.loc[sample_id] = sample
df_16S.head()
# Out:
#                  A2    ASF356  Acetatifactor  Acinetobacter  \
# SampleID
# sample1    0.000791  0.000791       0.000791       0.000791
# sample10   0.000432  0.000432       0.007693       0.000432
# sample100  0.000085  0.000085       0.000085       0.000085
# sample101  0.000055  0.000309       0.000055       0.000055
# sample102  0.000082  0.001437       0.000082       0.000082
#
#            Akkermansia_dash_muciniphila  Alistipes  Alloprevotella  \
# SampleID
# sample1                        0.000791   0.000791        0.003163
# sample10                       0.000432   0.153254        0.031291
# sample100                      0.000085   0.005143        0.012320
# sample101                      0.000055   0.006024        0.003967
# sample102                      0.000082   0.025687        0.011724
#
#            Anaerotruncus  Aquimarina  Aquimarina_dash_muelleri  ...  \
# SampleID                                                        ...
# sample1         0.000791    0.000791                  0.000791  ...
# sample10        0.031291    0.000432                  0.000432  ...
# sample100       0.000085    0.000085                  0.000085  ...
# sample101       0.000055    0.000055                  0.000055  ...
# sample102       0.000082    0.000082                  0.000082  ...
#
#            _leftsquarebracket_Clostridium_rightsquarebracket__dash_cocleatum  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Clostridium_rightsquarebracket__dash_innocuum_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_brachy_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_coprostanoligenes_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_fissicatena_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_nodatum_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample1                                             0.000791
# sample10                                            0.000432
# sample100                                           0.000085
# sample101                                           0.000055
# sample102                                           0.000082
#
#            gut_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample1               0.000791    0.000791                        0.000791
# sample10              0.000432    0.000432                        0.000432
# sample100             0.003843    0.000085                        0.000085
# sample101             0.000055    0.000055                        0.001019
# sample102             0.003244    0.000082                        0.000082
#
# [5 rows x 116 columns]

# %% [markdown]
# # Read metadata for inulin and control

# %%
df_meta = pd.read_csv('metadata.txt', sep='\t').set_index('#SampleID')
df_meta = df_meta.drop('#q2:types')

# remove inulin in non-longitudinal study
df_meta = df_meta[~((df_meta.If_longitudinal=='No') & (df_meta.Group=='Inulin'))]

# correct days: add 0.5 day to evening samples
new_days = []
for d,t in zip(df_meta.Day,df_meta.Time):
    if t=='Evening':
        new_days.append(float(d)+0.5)
    else:
        new_days.append(float(d))
df_meta['Day'] = new_days

# Correct for mice ID
new_miceid = []
for m in df_meta.Mice_ID:
    if '_' in m:
        new_miceid.append(1000000)
    else:
        new_miceid.append(m)
df_meta['Mice_ID'] = new_miceid

# change before to cellulose
df_meta.loc[df_meta.Group=='Before', 'Group'] = 'Cellulose'
        
df_meta = df_meta[['Mice_ID','Day','Group']]
df_meta['Diet'] = [1 if g=='Inulin' else 0 for g in df_meta['Group']]

df_meta.head()
# Out:
#            Mice_ID  Day      Group  Diet
# #SampleID
# sample1    1000000  0.0  Cellulose     0
# sample2    1000000  0.0  Cellulose     0
# sample3    1000000  0.0  Cellulose     0
# sample4    1000000  0.0  Cellulose     0
# sample5    1000000  0.0  Cellulose     0

# %% [markdown]
# # Sample average

# %%
df_16S_meta = pd.merge(df_meta, df_16S, left_index=True, right_index=True, how='inner')
df_16S_meta = df_16S_meta.groupby(['Mice_ID','Day','Group','Diet']).agg(np.mean).reset_index()
df_16S_meta.head()
# Out:
#    Mice_ID   Day      Group  Diet        A2    ASF356  Acetatifactor  \
# 0  1000000   0.0  Cellulose     0  0.000696  0.000696       0.002132
# 1  1000000   0.5  Cellulose     0  0.000669  0.000513       0.002674
# 2  1000000  14.0  Cellulose     0  0.000600  0.000536       0.000536
# 3  1000000  14.5  Cellulose     0  0.001340  0.001340       0.008515
# 4        1   0.0     Inulin     1  0.000266  0.000349       0.001081
#
#    Acinetobacter  Akkermansia_dash_muciniphila  Alistipes  ...  \
# 0       0.000696                      0.000696   0.013110  ...
# 1       0.000513                      0.000513   0.101401  ...
# 2       0.000536                      0.000536   0.000536  ...
# 3       0.001340                      0.001340   0.030853  ...
# 4       0.000017                      0.000017   0.036614  ...
#
#    _leftsquarebracket_Clostridium_rightsquarebracket__dash_cocleatum  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000017
#
#    _leftsquarebracket_Clostridium_rightsquarebracket__dash_innocuum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000166
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_brachy_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.002529
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_coprostanoligenes_dash_group  \
# 0                                           0.000696
# 1                                           0.000537
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000017
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_fissicatena_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.002369
# 4                                           0.000017
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_nodatum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.002578
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000183
#
#    gut_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# 0             0.000696    0.000696                        0.001798
# 1             0.000513    0.000513                        0.000513
# 2             0.000536    0.000536                        0.001202
# 3             0.001340    0.001340                        0.001815
# 4             0.045397    0.000017                        0.000491
#
# [5 rows x 120 columns]

# %%
df_16S = df_16S_meta.iloc[:,4:]
df_16S.head()
# Out:
#          A2    ASF356  Acetatifactor  Acinetobacter  \
# 0  0.000696  0.000696       0.002132       0.000696
# 1  0.000669  0.000513       0.002674       0.000513
# 2  0.000600  0.000536       0.000536       0.000536
# 3  0.001340  0.001340       0.008515       0.001340
# 4  0.000266  0.000349       0.001081       0.000017
#
#    Akkermansia_dash_muciniphila  Alistipes  Alloprevotella  Anaerotruncus  \
# 0                      0.000696   0.013110        0.010021       0.005460
# 1                      0.000513   0.101401        0.022954       0.014820
# 2                      0.000536   0.000536        0.003964       0.000557
# 3                      0.001340   0.030853        0.014149       0.002125
# 4                      0.000017   0.036614        0.005797       0.008742
#
#    Aquimarina  Aquimarina_dash_muelleri  ...  \
# 0    0.000696                  0.000696  ...
# 1    0.000513                  0.000513  ...
# 2    0.000536                  0.000536  ...
# 3    0.001340                  0.001340  ...
# 4    0.000017                  0.000017  ...
#
#    _leftsquarebracket_Clostridium_rightsquarebracket__dash_cocleatum  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000017
#
#    _leftsquarebracket_Clostridium_rightsquarebracket__dash_innocuum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000166
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_brachy_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.002529
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_coprostanoligenes_dash_group  \
# 0                                           0.000696
# 1                                           0.000537
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000017
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_fissicatena_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.002369
# 4                                           0.000017
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_nodatum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.002578
#
#    _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# 0                                           0.000696
# 1                                           0.000513
# 2                                           0.000536
# 3                                           0.001340
# 4                                           0.000183
#
#    gut_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# 0             0.000696    0.000696                        0.001798
# 1             0.000513    0.000513                        0.000513
# 2             0.000536    0.000536                        0.001202
# 3             0.001340    0.001340                        0.001815
# 4             0.045397    0.000017                        0.000491
#
# [5 rows x 116 columns]

# %%
df_meta = df_16S_meta.iloc[:,0:4]
df_meta.head()
# Out:
#    Mice_ID   Day      Group  Diet
# 0  1000000   0.0  Cellulose     0
# 1  1000000   0.5  Cellulose     0
# 2  1000000  14.0  Cellulose     0
# 3  1000000  14.5  Cellulose     0
# 4        1   0.0     Inulin     1

# %% [markdown]
# # Select the 20 most abundant taxa

# %%
topX = 20
df_16S_T = df_16S.loc[df_meta.index].T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#    Bacteroides_dash_acidifaciens  Lactobacillus_dash_murinus  Lachnospiraceae  \
# 0                       0.082238                    0.093941         0.130191
# 1                       0.136595                    0.052288         0.088203
# 2                       0.016578                    0.094240         0.198157
# 3                       0.030272                    0.036707         0.171329
# 4                       0.100459                    0.024029         0.242913
#
#    Lactococcus  Lactobacillus  Bifidobacterium  Alloprevotella  \
# 0     0.336076       0.110858         0.000696        0.010021
# 1     0.099270       0.126145         0.000513        0.022954
# 2     0.284627       0.051968         0.000536        0.003964
# 3     0.409598       0.001340         0.001340        0.014149
# 4     0.132299       0.000025         0.000017        0.005797
#
#    Muribaculaceae  Bacteroides  Roseburia  \
# 0        0.036473     0.022997   0.001791
# 1        0.051103     0.169260   0.003593
# 2        0.005535     0.030283   0.024240
# 3        0.020814     0.042389   0.010794
# 4        0.052475     0.051777   0.000524
#
#    Lachnospiraceae_dash_NK4A136_dash_group  Erysipelatoclostridium  Alistipes  \
# 0                                 0.022697                0.001662   0.013110
# 1                                 0.041329                0.005125   0.101401
# 2                                 0.025531                0.000791   0.000536
# 3                                 0.024606                0.002764   0.030853
# 4                                 0.025668                0.031690   0.036614
#
#    Clostridia_dash_UCG_dash_014  Akkermansia_dash_muciniphila   Blautia  \
# 0                      0.000740                      0.000696  0.051865
# 1                      0.000513                      0.000513  0.030730
# 2                      0.000536                      0.000536  0.013312
# 3                      0.001340                      0.001340  0.015936
# 4                      0.071223                      0.000017  0.005889
#
#    Lachnoclostridium  GCA_dash_900066575  Oscillospiraceae  \
# 0           0.019862            0.009577          0.006595
# 1           0.005609            0.020897          0.006503
# 2           0.004023            0.008377          0.001240
# 3           0.004183            0.018003          0.013521
# 4           0.013874            0.015279          0.024778
#
#    Dorea_dash_sp_dot__dash_5_dash_2
# 0                          0.006772
# 1                          0.002247
# 2                          0.000901
# 3                          0.002097
# 4                          0.007378

# %%
list(df_16S_topX.columns)
# Out:
# ['Bacteroides_dash_acidifaciens',
#  'Lactobacillus_dash_murinus',
#  'Lachnospiraceae',
#  'Lactococcus',
#  'Lactobacillus',
#  'Bifidobacterium',
#  'Alloprevotella',
#  'Muribaculaceae',
#  'Bacteroides',
#  'Roseburia',
#  'Lachnospiraceae_dash_NK4A136_dash_group',
#  'Erysipelatoclostridium',
#  'Alistipes',
#  'Clostridia_dash_UCG_dash_014',
#  'Akkermansia_dash_muciniphila',
#  'Blautia',
#  'Lachnoclostridium',
#  'GCA_dash_900066575',
#  'Oscillospiraceae',
#  'Dorea_dash_sp_dot__dash_5_dash_2']

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX_w_meta = pd.merge(df_meta, df_16S_topX/df_16S_topX.max().max(), left_index=True, right_index=True, how='inner')
df_16S_topX_w_meta.head()
# Out:
#    Mice_ID   Day      Group  Diet  Bacteroides_dash_acidifaciens  \
# 0  1000000   0.0  Cellulose     0                       0.090023
# 1  1000000   0.5  Cellulose     0                       0.149527
# 2  1000000  14.0  Cellulose     0                       0.018148
# 3  1000000  14.5  Cellulose     0                       0.033137
# 4        1   0.0     Inulin     1                       0.109970
#
#    Lactobacillus_dash_murinus  Lachnospiraceae  Lactococcus  Lactobacillus  \
# 0                    0.102835         0.142516     0.367892       0.121352
# 1                    0.057238         0.096553     0.108668       0.138087
# 2                    0.103162         0.216917     0.311573       0.056888
# 3                    0.040182         0.187549     0.448375       0.001467
# 4                    0.026304         0.265910     0.144823       0.000027
#
#    Bifidobacterium  ...  Lachnospiraceae_dash_NK4A136_dash_group  \
# 0         0.000762  ...                                 0.024846
# 1         0.000561  ...                                 0.045242
# 2         0.000586  ...                                 0.027948
# 3         0.001467  ...                                 0.026936
# 4         0.000018  ...                                 0.028098
#
#    Erysipelatoclostridium  Alistipes  Clostridia_dash_UCG_dash_014  \
# 0                0.001820   0.014351                      0.000810
# 1                0.005610   0.111001                      0.000561
# 2                0.000866   0.000586                      0.000586
# 3                0.003026   0.033774                      0.001467
# 4                0.034690   0.040080                      0.077966
#
#    Akkermansia_dash_muciniphila   Blautia  Lachnoclostridium  \
# 0                      0.000762  0.056775           0.021742
# 1                      0.000561  0.033639           0.006140
# 2                      0.000586  0.014572           0.004404
# 3                      0.001467  0.017444           0.004579
# 4                      0.000018  0.006446           0.015187
#
#    GCA_dash_900066575  Oscillospiraceae  Dorea_dash_sp_dot__dash_5_dash_2
# 0            0.010483          0.007219                          0.007413
# 1            0.022875          0.007119                          0.002459
# 2            0.009170          0.001357                          0.000986
# 3            0.019707          0.014801                          0.002295
# 4            0.016726          0.027124                          0.008076
#
# [5 rows x 24 columns]

# %% [markdown]
# # Calculate log-derivatives (dlog(B)/dt)

# %%
df_deriv = deepcopy(df_16S_topX_w_meta)
for curr_sub in set(df_deriv.Mice_ID):
    curr_df = df_deriv[df_deriv.Mice_ID==curr_sub].sort_values(by='Day')
    if len(curr_df.index) == 0:
        continue
    for taxon in bacterial_taxa:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[taxon])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_deriv.loc[df_deriv.Mice_ID==curr_sub, taxon] = ydata_d1
df_deriv.head()
# Out:
#    Mice_ID   Day      Group  Diet  Bacteroides_dash_acidifaciens  \
# 0  1000000   0.0  Cellulose     0                       0.129414
# 1  1000000   0.5  Cellulose     0                       0.108808
# 2  1000000  14.0  Cellulose     0                       0.022960
# 3  1000000  14.5  Cellulose     0                       0.037206
# 4        1   0.0     Inulin     1                       0.091203
#
#    Lactobacillus_dash_murinus  Lachnospiraceae  Lactococcus  Lactobacillus  \
# 0                   -0.102296        -0.101337    -0.546981       0.032627
# 1                   -0.080369        -0.082721    -0.490255       0.034232
# 2                   -0.113892        -0.050717     0.273510      -0.104924
# 3                   -0.138302        -0.066962     0.273359      -0.116838
# 4                   -0.017080        -0.213750    -0.143701       0.001755
#
#    Bifidobacterium  ...  Lachnospiraceae_dash_NK4A136_dash_group  \
# 0        -0.000370  ...                                 0.043720
# 1        -0.000433  ...                                 0.037915
# 2         0.001654  ...                                -0.003373
# 3         0.001871  ...                                -0.000627
# 4        -0.000178  ...                                -0.004772
#
#    Erysipelatoclostridium  Alistipes  Clostridia_dash_UCG_dash_014  \
# 0                0.008298   0.210013                     -0.000472
# 1                0.006878   0.176925                     -0.000522
# 2                0.003735   0.054534                      0.001657
# 3                0.004922   0.078556                      0.001868
# 4                0.130338   0.014126                     -0.122993
#
#    Akkermansia_dash_muciniphila   Blautia  Lachnoclostridium  \
# 0                     -0.000370 -0.049174          -0.033371
# 1                     -0.000433 -0.043416          -0.029079
# 2                      0.001654  0.006743           0.001350
# 3                      0.001871  0.004700          -0.000689
# 4                      0.000176  0.035987          -0.016806
#
#    GCA_dash_900066575  Oscillospiraceae  Dorea_dash_sp_dot__dash_5_dash_2
# 0            0.027355          0.000758                         -0.010502
# 1            0.022269         -0.001123                         -0.009323
# 2            0.018692          0.024997                          0.002756
# 3            0.023514          0.028813                          0.002472
# 4            0.014997         -0.036714                         -0.003546
#
# [5 rows x 24 columns]

# %% [markdown]
# # Construct regression matrix

# %%
# Ymat should be samples by bacteria
Ymat = df_deriv[bacterial_taxa].values
Ymat = Ymat.flatten(order='F')
Ymat = StandardScaler().fit_transform(Ymat.reshape(-1,1)).reshape(1,-1)[0] # standardize
Ymat
# Out:
# array([ 1.25848493,  1.05551206,  0.20986347, ..., -0.02867623,
#        -0.00316822, -0.0143775 ])

# %%
len(Ymat)
# Out:
# 1700

# %%
Xmat = np.zeros(shape=(topX*len(df_deriv.index), (topX+2)*topX))
for k in np.arange(topX):
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)] = 1
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+1] = df_deriv.Diet.values
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+2:(k+1)*(topX+2)] = df_16S_topX_w_meta[bacterial_taxa].values
Xmat
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 9.00231553e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.49526782e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.81479355e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.12075336e-03, 4.03471209e-03, 2.03773338e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.73072191e-03, 8.76599410e-04, 1.05641467e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.38165644e-03, 7.32692229e-04, 5.86153784e-03]])

# %% [markdown]
# # Write stan program

# %% [markdown]
# ## write data

# %%
json_str = '{\n"N" : %d,\n'%(len(Ymat))

# y variable
json_str += '\"dlogX\" : [%s],\n'%(','.join(list(Ymat.astype(str))))

# x variable
for k1,c1 in enumerate(bacterial_taxa):
    # growth rate
    json_str += '\"growth_rate_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)].astype(str))))
    # diet response
    json_str += '\"inulin_response_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)+1].astype(str))))
    # bacterial interactions
    for k2,c2 in enumerate(bacterial_taxa):
        v = list(Xmat[:,k1*(topX+2)+2+k2].astype(str))
        json_str += '\"pairwise_interaction_%s_%s\" : [%s]'%(c1,c2,','.join(v))
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            json_str += '\n}'
        else:
            json_str += ',\n'
#print(json_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.data.json", "w")
text_file.write("%s" % json_str)
text_file.close()

# %% [markdown]
# ## write model

# %%
# data block
model_str = 'data {\n'
model_str += '\tint<lower=0> N;\n'
model_str += '\tvector[N] dlogX;\n'
for c1 in bacterial_taxa:
    model_str += '\tvector[N] growth_rate_%s;\n'%(c1)
    model_str += '\tvector[N] inulin_response_%s;\n'%(c1)
    for c2 in bacterial_taxa:
        model_str += '\tvector[N] pairwise_interaction_%s_%s;\n'%(c1,c2)
model_str += '}\n'

# parameter block
model_str += 'parameters {\n\treal<lower=0,upper=1> sigma;\n'
for c1 in bacterial_taxa:
    model_str += '\treal alpha__%s;\n'%(c1) # growth rate
    model_str += '\treal epsilon__%s;\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\treal beta__%s_%s;\n'%(c1,c2)
model_str += '}\n'       
        
# model block
model_str += 'model {\n\tsigma ~ uniform(0,1);\n'
for c1 in bacterial_taxa:
    model_str += '\talpha__%s ~ normal(0,1);\n'%(c1) # growth rate
    model_str += '\tepsilon__%s ~ normal(0,1);\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\tbeta__%s_%s ~ normal(0,1);\n'%(c1,c2)
model_str += '\tdlogX ~ normal('
for c1 in bacterial_taxa:
    model_str += 'alpha__%s*growth_rate_%s+'%(c1,c1) # growth rate
    model_str += 'epsilon__%s*inulin_response_%s+'%(c1,c1) # inulin response
    for c2 in bacterial_taxa:
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s'%(c1,c2,c1,c2)
        else:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s+'%(c1,c2,c1,c2)
model_str += ', sigma);\n}'
#print(model_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.stan", "w")
text_file.write("%s" % model_str)
text_file.close()

# %% [markdown]
# # Plot stan output

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d.csv"%(i) for i in np.arange(1,4)])

# %%
lines = []
    
# basal growth rate
for c in bacterial_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# inulin response
for c in bacterial_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['inulin_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])

# pairwise interactions
for c1 in bacterial_taxa:
    for c2 in bacterial_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.head()
# Out:
#                 Type                           Taxa  Left  Right  Middle  \
# 0  basal_growth_rate                 Muribaculaceae -0.16   0.15  -0.005
# 1  basal_growth_rate  Bacteroides_dash_acidifaciens -0.01   0.30   0.145
# 2  basal_growth_rate   Akkermansia_dash_muciniphila -0.27   0.04  -0.115
# 3  basal_growth_rate                 Faecalibaculum -0.20   0.12  -0.040
# 4  basal_growth_rate                 Parasutterella -0.20   0.12  -0.040
#
#         SNR  Significant
# 0 -0.044859        False
# 1  1.835619        False
# 2 -1.416896        False
# 3 -0.531562        False
# 4 -0.540205        False

# %%
df_stan_output_summary.to_excel('bayesian_regression_summary_top20.xlsx')

# %% [markdown]
# # Plot

# %%
df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True]
df_stan_output_summary
# Out:
#                      Type                                    Taxa  Left  \
# 6       basal_growth_rate                              Prevotella -0.99
# 22        inulin_response                         Bifidobacterium  1.57
# 24        inulin_response                            Anaerostipes  0.94
# 26        inulin_response                              Prevotella  0.12
# 28        inulin_response                             Bacteroides -0.66
# 33        inulin_response                             Coprococcus -0.65
# 40   pairwise_interaction                  ('Blautia', 'Blautia') -3.91
# 41   pairwise_interaction         ('Blautia', 'Faecalibacterium') -3.30
# 42   pairwise_interaction          ('Blautia', 'Bifidobacterium') -3.51
# 82   pairwise_interaction  ('Bifidobacterium', 'Bifidobacterium')  1.35
# 161  pairwise_interaction      ('Prevotella', 'Faecalibacterium')  0.23
# 166  pairwise_interaction            ('Prevotella', 'Prevotella') -6.48
#
#      Right  Middle        SNR  Significant
# 6    -0.02  -0.505  -2.050357         True
# 22    2.19   1.880  12.046869         True
# 24    1.56   1.250   7.995026         True
# 26    0.73   0.425   2.720541         True
# 28   -0.04  -0.350  -2.239965         True
# 33   -0.03  -0.340  -2.163012         True
# 40   -1.19  -2.550  -3.696627         True
# 41   -0.11  -1.705  -2.138517         True
# 42   -0.87  -2.190  -3.272662         True
# 82    3.97   2.660   3.995891         True
# 161   3.40   1.815   2.260957         True
# 166  -4.34  -5.410  -9.988830         True
