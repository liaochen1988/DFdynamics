# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from collections import Counter
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data

# %%
df_meta_all = pd.read_csv('study1_metadata.tsv', sep='\t', index_col=0)
df_meta_all = df_meta_all.drop('#q2:types')
df_meta_all['Day'] = [0 if s=='pre' else 21 for s in df_meta_all.status]
df_meta_all = df_meta_all[df_meta_all.Group=='Prebiotic']
df_meta_all = df_meta_all[['Subject_ID','Day','Acetate','Butyrate','Propionate']]
df_meta_all.head()
# Out:
#            Subject_ID  Day Acetate Butyrate Propionate
# #SampleID
# SRR6185180    ADAPT02   21   16.77     3.74       4.64
# SRR6185211    ADAPT02    0   23.65     6.11       6.67
# SRR6185259    ADAPT03   21   27.01     5.15       5.51
# SRR6185224    ADAPT03    0   13.92     3.36       3.71
# SRR6185178    ADAPT04   21   52.04    12.01      10.79

# %%
df_meta = df_meta_all[['Subject_ID','Day']]

# %% [markdown]
# # Read SCFA

# %%
df_scfa = df_meta_all[['Acetate','Butyrate','Propionate']]
df_scfa.head()
# Out:
#            Acetate Butyrate Propionate
# #SampleID
# SRR6185180   16.77     3.74       4.64
# SRR6185211   23.65     6.11       6.67
# SRR6185259   27.01     5.15       5.51
# SRR6185224   13.92     3.36       3.71
# SRR6185178   52.04    12.01      10.79

# %%
df_scfa.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Read 16S data (relative abundance)

# %%
df_16S = pd.read_excel('16S_relative_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_meta.index]
df_16S.head()
# Out:
#             Abiotrophia  Acetanaerobacterium  Acidaminococcus  \
# #SampleID
# SRR6185180          0.0                  0.0         0.000677
# SRR6185211          0.0                  0.0         0.003713
# SRR6185259          0.0                  0.0         0.000000
# SRR6185224          0.0                  0.0         0.000000
# SRR6185178          0.0                  0.0         0.000000
#
#             Actinidia-chinensis  Actinomyces  Actinomyces-massiliensis  \
# #SampleID
# SRR6185180                  0.0          0.0                       0.0
# SRR6185211                  0.0          0.0                       0.0
# SRR6185259                  0.0          0.0                       0.0
# SRR6185224                  0.0          0.0                       0.0
# SRR6185178                  0.0          0.0                       0.0
#
#             Adlercreutzia  Agathobacter  Akkermansia  Akkermansia-muciniphila  \
# #SampleID
# SRR6185180            0.0      0.007623     0.000857                 0.000000
# SRR6185211            0.0      0.020102     0.000000                 0.000000
# SRR6185259            0.0      0.008313     0.000000                 0.001122
# SRR6185224            0.0      0.007017     0.000000                 0.000337
# SRR6185178            0.0      0.115510     0.000448                 0.000000
#
#             ...  [Ruminococcus]-torques-group  bacterium-YE57  \
# #SampleID   ...
# SRR6185180  ...                      0.006240        0.000226
# SRR6185211  ...                      0.017335        0.000232
# SRR6185259  ...                      0.023107        0.000313
# SRR6185224  ...                      0.030629        0.000628
# SRR6185178  ...                      0.000000        0.000000
#
#             bacterium-enrichment-culture-clone-BBMC-9  \
# #SampleID
# SRR6185180                                        0.0
# SRR6185211                                        0.0
# SRR6185259                                        0.0
# SRR6185224                                        0.0
# SRR6185178                                        0.0
#
#             bacterium-enrichment-culture-clone-Ecwsrb026  \
# #SampleID
# SRR6185180                                      0.000000
# SRR6185211                                      0.000000
# SRR6185259                                      0.000181
# SRR6185224                                      0.000221
# SRR6185178                                      0.000000
#
#             bacterium-enrichment-culture-clone-RB7c  \
# #SampleID
# SRR6185180                                      0.0
# SRR6185211                                      0.0
# SRR6185259                                      0.0
# SRR6185224                                      0.0
# SRR6185178                                      0.0
#
#             butyrate-producing-bacterium-L2-10  gut-metagenome  \
# #SampleID
# SRR6185180                                 0.0        0.001564
# SRR6185211                                 0.0        0.006677
# SRR6185259                                 0.0        0.021788
# SRR6185224                                 0.0        0.038717
# SRR6185178                                 0.0        0.012032
#
#             human-gut-metagenome  metagenome  vadinBE97
# #SampleID
# SRR6185180              0.000271    0.014629        0.0
# SRR6185211              0.000304    0.042080        0.0
# SRR6185259              0.001451    0.069750        0.0
# SRR6185224              0.001327    0.044047        0.0
# SRR6185178              0.000563    0.030853        0.0
#
# [5 rows x 469 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#              Blautia  Bifidobacterium  Faecalibacterium  metagenome  \
# #SampleID
# SRR6185180  0.063765         0.233980          0.010314    0.014629
# SRR6185211  0.092586         0.108939          0.021995    0.042080
# SRR6185259  0.066649         0.101466          0.040161    0.069750
# SRR6185224  0.094739         0.003189          0.034865    0.044047
# SRR6185178  0.080373         0.059123          0.129996    0.030853
#
#             Anaerostipes  Agathobacter  Prevotella  Bacteroides  \
# #SampleID
# SRR6185180      0.106390      0.007623    0.000000     0.007503
# SRR6185211      0.028440      0.020102    0.000000     0.022566
# SRR6185259      0.076858      0.008313    0.000033     0.030776
# SRR6185224      0.025218      0.007017    0.000326     0.037309
# SRR6185178      0.048945      0.115510    0.000000     0.023731
#
#             Fusicatenibacter  Ruminococcus-sp.-N15.MGS-57  ...  \
# #SampleID                                                  ...
# SRR6185180          0.002767                     0.129620  ...
# SRR6185211          0.009176                     0.096870  ...
# SRR6185259          0.025531                     0.000000  ...
# SRR6185224          0.004085                     0.000000  ...
# SRR6185178          0.068700                     0.059673  ...
#
#             Ruminococcus-bicirculans  WPS-2  Roseburia  \
# #SampleID
# SRR6185180                  0.001774    0.0   0.000000
# SRR6185211                  0.000857    0.0   0.000411
# SRR6185259                  0.000907    0.0   0.001352
# SRR6185224                  0.000372    0.0   0.001280
# SRR6185178                  0.028833    0.0   0.000486
#
#             Dorea-formicigenerans-ATCC-27755  [Eubacterium]-eligens-group  \
# #SampleID
# SRR6185180                          0.004571                     0.000692
# SRR6185211                          0.008123                     0.000000
# SRR6185259                          0.003991                     0.012865
# SRR6185224                          0.006924                     0.017758
# SRR6185178                          0.002928                     0.016980
#
#             Holdemanella   UCG-005  Lactobacillus  Monoglobus  Megamonas
# #SampleID
# SRR6185180      0.000000  0.003608        0.00003    0.000075        0.0
# SRR6185211      0.000000  0.005713        0.00000    0.000714        0.0
# SRR6185259      0.000000  0.002260        0.00000    0.004602        0.0
# SRR6185224      0.000000  0.003631        0.00000    0.008437        0.0
# SRR6185178      0.004143  0.002506        0.00000    0.002915        0.0
#
# [5 rows x 40 columns]

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.5899736797549601

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.Subject_ID):
    curr_df = df_scfa_meta[df_scfa_meta.Subject_ID==curr_mice].sort_values(by='Day')
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.Subject_ID==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#              Acetate   Butyrate Propionate
# #SampleID
# SRR6185180 -0.327619  -0.112857 -0.0966667
# SRR6185211 -0.327619  -0.112857 -0.0966667
# SRR6185259  0.623333  0.0852381  0.0857143
# SRR6185224  0.623333  0.0852381  0.0857143
# SRR6185178  0.810952   0.082381 -0.0447619

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#              Blautia  Bifidobacterium  Faecalibacterium  metagenome  \
# #SampleID
# SRR6185180  0.215450         0.790576          0.034850    0.049430
# SRR6185211  0.312830         0.368085          0.074317    0.142179
# SRR6185259  0.225195         0.342836          0.135697    0.235672
# SRR6185224  0.320105         0.010774          0.117803    0.148827
# SRR6185178  0.271567         0.199766          0.439234    0.104246
#
#             Anaerostipes  Agathobacter  Prevotella  Bacteroides  \
# #SampleID
# SRR6185180      0.359473      0.025756    0.000000     0.025350
# SRR6185211      0.096093      0.067923    0.000000     0.076247
# SRR6185259      0.259691      0.028087    0.000111     0.103988
# SRR6185224      0.085207      0.023710    0.001101     0.126060
# SRR6185178      0.165377      0.390286    0.000000     0.080183
#
#             Fusicatenibacter  Ruminococcus-sp.-N15.MGS-57  ...  \
# #SampleID                                                  ...
# SRR6185180          0.009348                     0.437961  ...
# SRR6185211          0.031006                     0.327307  ...
# SRR6185259          0.086266                     0.000000  ...
# SRR6185224          0.013801                     0.000000  ...
# SRR6185178          0.232124                     0.201623  ...
#
#             Ruminococcus-bicirculans  WPS-2  Roseburia  \
# #SampleID
# SRR6185180                  0.005995    0.0   0.000000
# SRR6185211                  0.002895    0.0   0.001387
# SRR6185259                  0.003065    0.0   0.004570
# SRR6185224                  0.001258    0.0   0.004325
# SRR6185178                  0.097420    0.0   0.001642
#
#             Dorea-formicigenerans-ATCC-27755  [Eubacterium]-eligens-group  \
# #SampleID
# SRR6185180                          0.015444                     0.002337
# SRR6185211                          0.027447                     0.000000
# SRR6185259                          0.013486                     0.043468
# SRR6185224                          0.023395                     0.060003
# SRR6185178                          0.009893                     0.057372
#
#             Holdemanella   UCG-005  Lactobacillus  Monoglobus  Megamonas
# #SampleID
# SRR6185180      0.000000  0.012192       0.000102    0.000254        0.0
# SRR6185211      0.000000  0.019303       0.000000    0.002413        0.0
# SRR6185259      0.000000  0.007635       0.000000    0.015548        0.0
# SRR6185224      0.000000  0.012268       0.000000    0.028507        0.0
# SRR6185178      0.013997  0.008468       0.000000    0.009850        0.0
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA          Variable   Pearson  Spearman
# 0  Acetate           Blautia  0.262354  0.263933
# 1  Acetate   Bifidobacterium  0.031087 -0.035971
# 2  Acetate  Faecalibacterium -0.016101 -0.007942
# 3  Acetate        metagenome -0.131985 -0.104168
# 4  Acetate      Anaerostipes  0.172967  0.169540

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
#df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasticnet.head()
# Out:
#             BestAlpha  L1Ratio        R2   Blautia  Bifidobacterium  \
# SCFA
# Acetate      0.109552   0.1000  0.044700  0.222914         0.000000
# Butyrate     0.009493   0.5000  0.111255  0.176532        -0.000000
# Propionate   0.210249   0.0001  0.052266  0.044578         0.007734
#
#             Faecalibacterium  metagenome  Anaerostipes  Agathobacter  \
# SCFA
# Acetate            -0.000000   -0.023608      0.048966      0.201496
# Butyrate           -0.000000   -0.000000      0.033816      0.276872
# Propionate          0.007931    0.004511      0.031915      0.046317
#
#             Prevotella  ...  Ruminococcus-bicirculans    WPS-2  Roseburia  \
# SCFA                    ...
# Acetate      -0.093091  ...                  0.000000 -0.00000       -0.0
# Butyrate      0.000000  ...                  0.000000  0.01701       -0.0
# Propionate   -0.030508  ...                  0.009962 -0.01604        0.0
#
#             Dorea-formicigenerans-ATCC-27755  [Eubacterium]-eligens-group  \
# SCFA
# Acetate                             0.000000                    -0.000000
# Butyrate                           -0.000000                    -0.000000
# Propionate                          0.003815                    -0.004364
#
#             Holdemanella  UCG-005  Lactobacillus  Monoglobus  Megamonas
# SCFA
# Acetate         0.000000 -0.00000        0.00000   -0.000000    -0.0000
# Butyrate        0.000000 -0.00000        0.00000   -0.000000    -0.0000
# Propionate      0.002599 -0.00838        0.00004   -0.002601    -0.0047
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 16.1min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 16.5min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 16.7min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt        NaN                  2
# 1    Butyrate           200         sqrt       10.0                  2
# 2  Propionate           200         sqrt       30.0                  5
#
#    min_samples_leaf  bootstrap
# 0                 1       True
# 1                 2       True
# 2                 1      False

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2   Blautia  Bifidobacterium  Faecalibacterium  \
# 0     Acetate  0.882434  0.024684         0.024181          0.021981
# 1    Butyrate  0.815426  0.022150         0.028244          0.029848
# 2  Propionate  0.991440  0.013160         0.012015          0.009055
#
#    metagenome  Anaerostipes  Agathobacter  Prevotella  Bacteroides  ...  \
# 0    0.037242      0.031986      0.037544    0.007825     0.016369  ...
# 1    0.042806      0.026290      0.033750    0.008259     0.022702  ...
# 2    0.029737      0.024034      0.053257    0.020810     0.018293  ...
#
#    Ruminococcus-bicirculans     WPS-2  Roseburia  \
# 0                  0.029739  0.000344   0.012450
# 1                  0.019045  0.001820   0.014855
# 2                  0.023262  0.000143   0.014230
#
#    Dorea-formicigenerans-ATCC-27755  [Eubacterium]-eligens-group  \
# 0                          0.016672                     0.050320
# 1                          0.026514                     0.057389
# 2                          0.059129                     0.022377
#
#    Holdemanella   UCG-005  Lactobacillus  Monoglobus  Megamonas
# 0      0.013977  0.103863       0.008202    0.029782   0.011641
# 1      0.012020  0.088081       0.004917    0.022378   0.009329
# 2      0.006111  0.087067       0.004808    0.019133   0.045894
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA          Variable   Pearson
# 0  Acetate           Blautia  0.262354
# 1  Acetate   Bifidobacterium  0.031087
# 2  Acetate  Faecalibacterium -0.016101
# 3  Acetate        metagenome -0.131985
# 4  Acetate      Anaerostipes  0.172967

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasnet.head()
# Out:
#       SCFA          Variable  Coefficient
# 0  Acetate           Blautia     0.222914
# 1  Acetate   Bifidobacterium     0.000000
# 2  Acetate  Faecalibacterium     0.000000
# 3  Acetate        metagenome    -0.023608
# 4  Acetate      Anaerostipes     0.048966

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA          Variable      Gini
# 0  Acetate           Blautia  0.024684
# 1  Acetate   Bifidobacterium  0.024181
# 2  Acetate  Faecalibacterium  0.021981
# 3  Acetate        metagenome  0.037242
# 4  Acetate      Anaerostipes  0.031986

# %%
df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_joined, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','Pearson','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA             Taxon  RandomForest   Pearson  ElasticNet
# 0  Acetate           Blautia      0.024684  0.262354    0.222914
# 1  Acetate   Bifidobacterium      0.024181  0.031087    0.000000
# 2  Acetate  Faecalibacterium      0.021981 -0.016101    0.000000
# 3  Acetate        metagenome      0.037242 -0.131985   -0.023608
# 4  Acetate      Anaerostipes      0.031986  0.172967    0.048966

# %%
df_joined[(df_joined.SCFA=='Acetate') & (df_joined.ElasticNet>0)].sort_values(by='RandomForest', ascending=False)
# Out:
#        SCFA             Taxon  RandomForest   Pearson  ElasticNet
# 19  Acetate       Collinsella      0.038862  0.241633    0.022507
# 5   Acetate      Agathobacter      0.037544  0.298847    0.201496
# 8   Acetate  Fusicatenibacter      0.032174  0.254799    0.088758
# 4   Acetate      Anaerostipes      0.031986  0.172967    0.048966
# 0   Acetate           Blautia      0.024684  0.262354    0.222914

# %%
fig, ax = plt.subplots(figsize=(14, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df.iloc[0:10, :]
     
    # normalize to -1 and 1
    for c in ['ElasticNet','Pearson','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','Pearson','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
