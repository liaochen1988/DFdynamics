# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read taxonomy table

# %%
df_tax = pd.read_csv('taxonomy.tsv', sep='\t')
taxonomy = []
for idx in df_tax.index:
    taxon = df_tax.loc[idx,'Taxon']
    taxon = taxon.split(';')
    res = [df_tax.loc[idx,'Feature ID']]
    lowest_classified_taxon = 'unclassified'
    for i in np.arange(7):
        if i < len(taxon):
            res.append(taxon[i])
            if 'unclassified' not in taxon[i] and 'uncultured' not in taxon[i] and 'unidentified' not in taxon[i]:
                lowest_classified_taxon = taxon[i]
        else:
            res.append('unclassified')
    res.append(lowest_classified_taxon)
    taxonomy.append(res)
    
df_tax = pd.merge(df_tax, pd.DataFrame(taxonomy, columns=['Feature ID','Kingdom','Phylum','Class','Order','Family','Genus','Species','LowestClassifiedTaxon']), left_on='Feature ID', right_on='Feature ID', how='left')
df_tax = df_tax[['Feature ID','Confidence','Kingdom','Phylum','Class','Order','Family','Genus','Species','LowestClassifiedTaxon']]
df_tax = df_tax.rename({'Feature ID':'ASV'}, axis=1).set_index('ASV')

# remove genus tag in species
df_tax['Species'] = [y.replace(x+'-','') for x,y in zip(df_tax['Genus'], df_tax['Species'])]
#df_tax['LowestTaxon'] = [y.replace(x+'-','') for x,y in zip(df_tax['Genus'], df_tax['LowestTaxon'])]

# # select only bacteria
# df_tax = df_tax[df_tax.Kingdom=='Bacteria']

df_tax.head()
# Out:
#                                   Confidence   Kingdom        Phylum  \
# ASV
# 859f0168170ec9c159ad152f7211fdb7    0.999977  Bacteria    Firmicutes
# 668e61d416e2c60c21e75cd217d81c61    0.999976  Bacteria    Firmicutes
# 22f2ec8255674bc762b7d9f896c584fa    0.998850  Bacteria    Firmicutes
# e6c70754ab852a46b4ba77d0e35d4935    1.000000  Bacteria  Bacteroidota
# 4d87e6fd770bdc8cfae308448dfc77b3    1.000000  Bacteria  Bacteroidota
#
#                                         Class           Order  \
# ASV
# 859f0168170ec9c159ad152f7211fdb7   Clostridia  Lachnospirales
# 668e61d416e2c60c21e75cd217d81c61   Clostridia  Lachnospirales
# 22f2ec8255674bc762b7d9f896c584fa   Clostridia  Lachnospirales
# e6c70754ab852a46b4ba77d0e35d4935  Bacteroidia   Bacteroidales
# 4d87e6fd770bdc8cfae308448dfc77b3  Bacteroidia   Bacteroidales
#
#                                            Family             Genus  \
# ASV
# 859f0168170ec9c159ad152f7211fdb7  Lachnospiraceae      Agathobacter
# 668e61d416e2c60c21e75cd217d81c61  Lachnospiraceae      Agathobacter
# 22f2ec8255674bc762b7d9f896c584fa  Lachnospiraceae  Fusicatenibacter
# e6c70754ab852a46b4ba77d0e35d4935   Bacteroidaceae       Bacteroides
# 4d87e6fd770bdc8cfae308448dfc77b3   Bacteroidaceae       Bacteroides
#
#                                        Species LowestClassifiedTaxon
# ASV
# 859f0168170ec9c159ad152f7211fdb7  unclassified          Agathobacter
# 668e61d416e2c60c21e75cd217d81c61  unclassified          Agathobacter
# 22f2ec8255674bc762b7d9f896c584fa  unclassified      Fusicatenibacter
# e6c70754ab852a46b4ba77d0e35d4935  unclassified           Bacteroides
# 4d87e6fd770bdc8cfae308448dfc77b3  unclassified           Bacteroides

# %% [markdown]
# # Read metadata

# %%
df_meta = pd.read_csv('metadata.tsv', sep='\t').set_index('sample-id')
df_meta = df_meta.drop('#q2:types')
df_meta.Subject = [s.strip() for s in df_meta.Subject]
df_meta.head()
# Out:
#             Sample_type NCBI_Sample_Name         Diet Treatment Subject  \
# sample-id
# SRR10022259       feces            F01W0  Corn Starch   Control     F01
# SRR10022258       feces            F01W1  Corn Starch   Control     F01
# SRR10022120       feces            F01W2  Corn Starch   Control     F01
# SRR10022238       feces            F01W3  Corn Starch   Control     F01
# SRR10022162       feces            F01W4  Corn Starch   Control     F01
#
#             Timepoint      Dose week acetate propionate butyrate Valeric_Acid  \
# sample-id
# SRR10022259        BL  baseline    0  28.804      4.916    5.032        1.268
# SRR10022258        W1       10g    1  47.576       9.76    8.968        1.184
# SRR10022120        W2       20g    2  27.468      6.136    5.784        1.052
# SRR10022238        W3       35g    3   22.48      3.724    3.152        0.704
# SRR10022162        W4       50g    4  34.692      6.624    6.992        1.164
#
#             iso_butyrate iso_Valeric_Acid
# sample-id
# SRR10022259        0.872            1.316
# SRR10022258        0.752            1.044
# SRR10022120        1.392             2.06
# SRR10022238        1.004            1.596
# SRR10022162        1.024              1.6

# %% [markdown]
# # Prepare relative abundance table

# %%
df_count = pd.read_csv('otu.txt', sep='\t')
df_count = df_count.rename({'#OTU ID':'ASV'}, axis=1).set_index('ASV')
df_count = df_count[list(df_meta.index)]
df_count = df_count.div(df_count.sum(axis=0), axis=1)
df_count = df_count[(df_count.T != 0).any()]

# merge tax and absolute abundance
df_count = pd.merge(df_tax[['LowestClassifiedTaxon']], df_count, left_index=True, right_index=True, how='inner').set_index('LowestClassifiedTaxon', drop=True)

# merge index (row sum for the same index)
df_count = df_count.groupby(df_count.index).sum()

df_count.head()
# Out:
#                                                    SRR10022259  SRR10022258  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022120  SRR10022238  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022162  SRR10022167  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022172  SRR10022177  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022236  SRR10022188  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    ...  SRR10022110  \
# LowestClassifiedTaxon                              ...
# Abiotrophia-defectiva                              ...          0.0
# Absiella-argi                                      ...          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316  ...          0.0
# Acidaminococcus                                    ...          0.0
# Acidaminococcus-sp.-Marseille-P2764                ...          0.0
#
#                                                    SRR10022111  SRR10022112  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022113  SRR10022114  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022115  SRR10022116  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022117  SRR10022118  \
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0          0.0
# Absiella-argi                                              0.0          0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0          0.0
# Acidaminococcus                                            0.0          0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0          0.0
#
#                                                    SRR10022119
# LowestClassifiedTaxon
# Abiotrophia-defectiva                                      0.0
# Absiella-argi                                              0.0
# Acholeplasmatales-bacterium-canine-oral-taxon-316          0.0
# Acidaminococcus                                            0.0
# Acidaminococcus-sp.-Marseille-P2764                        0.0
#
# [5 rows x 200 columns]

# %%
df_count_T = df_count.T
df_count_T.index.name = 'SampleID'

# %%
df_count_T.to_excel('16S_relative_abundance.xlsx')
