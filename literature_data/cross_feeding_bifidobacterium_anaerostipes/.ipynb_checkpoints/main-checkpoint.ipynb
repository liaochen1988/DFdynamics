# %%
import pandas as pd
import numpy as np
import cobra
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
# %run -i 'metabolic_modeling.py'

# %% [markdown]
# # Models to include

# %%
models = {}
for filename in os.listdir('./'):
    if filename.endswith(".xml"):
        print(filename)
        model = cobra.io.read_sbml_model(filename)
        model.solver = 'cplex'
        models[key] = model
# Out:
# Bifidobacterium_animalis_lactis_V9.xml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/cobra/core/model.py in solver(self, value)
#     155             try:
# --> 156                 interface = solvers[interface_to_str(value)]
#     157             except KeyError:
#
# KeyError: 'cplex'
#
# During handling of the above exception, another exception occurred:
#
# SolverNotFound                            Traceback (most recent call last)
# ~/GoogleDrive/Source_code_for_SCFA_dynamics_project/literature_data/cross_feeding_bifidobacterium_anaerostipes/metabolic_modeling.py in <module>
#       4         print(filename)
#       5         model = cobra.io.read_sbml_model(filename)
# ----> 6         model.solver = 'cplex'
#       7         models[key] = model
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cobra/util/context.py in wrapper(self, new_value)
#     109             context(partial(func, self, old_value))
#     110
# --> 111         func(self, new_value)
#     112
#     113     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cobra/core/model.py in solver(self, value)
#     156                 interface = solvers[interface_to_str(value)]
#     157             except KeyError:
# --> 158                 raise not_valid_interface
#     159         elif isinstance(value, types.ModuleType) and hasattr(value, "Model"):
#     160             interface = value
#
# SolverNotFound: cplex is not a valid solver interface. Pick from ['glpk_exact', 'glpk', 'scipy'].

# %% [markdown]
# # Essential nutrients

# %%
essential_nutrients = []
for name, curr_model in models.items():
    curr_model_copy = deepcopy(curr_model)
    for rxn in curr_model_copy.exchanges:
        rxn.lower_bound = -1000
    res = cobra.flux_analysis.single_reaction_deletion(curr_model_copy, curr_model_copy.exchanges)
    res = res[res['growth'] == 0.0]
    for k in res.index:       
        essential_nutrients.append([name, curr_model_copy.metabolites.get_by_id(list(k)[0].replace('EX_','').replace('(e)','[e]')).name])
df_essential_nutrients = pd.DataFrame(essential_nutrients, columns=['model','nutrient'])
df_essential_nutrients['essential'] = [int(1) for index in df_essential_nutrients.index]
df_essential_nutrients = pd.pivot_table(df_essential_nutrients, values='essential', index='model', columns='nutrient').fillna(int(0))
df_essential_nutrients.head()
# Out:
# nutrient                                        Chloride  Co2+  Cu2+  Fe2+  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)           1.0   1.0   1.0   0.0
# Enterobacter_asburiae_LF7a (ASV_568)                 1.0   1.0   1.0   0.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)       1.0   1.0   1.0   1.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)        1.0   1.0   1.0   0.0
# Enterobacter_hormaechei_YT2 (ASV_568)                1.0   1.0   1.0   0.0
#
# nutrient                                        Folate  Menaquinone 7  Mn2+  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)         0.0            0.0   1.0
# Enterobacter_asburiae_LF7a (ASV_568)               0.0            0.0   1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)     0.0            0.0   1.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)      0.0            0.0   1.0
# Enterobacter_hormaechei_YT2 (ASV_568)              1.0            0.0   1.0
#
# nutrient                                        Riboflavin  Siroheme  Thiamin  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)             0.0       0.0      0.0
# Enterobacter_asburiae_LF7a (ASV_568)                   0.0       0.0      1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)         0.0       0.0      0.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)          0.0       0.0      0.0
# Enterobacter_hormaechei_YT2 (ASV_568)                  0.0       0.0      1.0
#
# nutrient                                        Zinc  calcium(2+)  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)       1.0          1.0
# Enterobacter_asburiae_LF7a (ASV_568)             1.0          1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)   1.0          1.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)    1.0          1.0
# Enterobacter_hormaechei_YT2 (ASV_568)            1.0          1.0
#
# nutrient                                        glycolaldehyde  magnesium  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)                 0.0        1.0
# Enterobacter_asburiae_LF7a (ASV_568)                       0.0        1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)             0.0        1.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)              0.0        1.0
# Enterobacter_hormaechei_YT2 (ASV_568)                      0.0        1.0
#
# nutrient                                        meso-2,6-Diaminoheptanedioate  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)                                0.0
# Enterobacter_asburiae_LF7a (ASV_568)                                      1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)                            0.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)                             0.0
# Enterobacter_hormaechei_YT2 (ASV_568)                                     1.0
#
# nutrient                                        octadecanoate (n-C18:0)  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)                          0.0
# Enterobacter_asburiae_LF7a (ASV_568)                                0.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)                      0.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)                       0.0
# Enterobacter_hormaechei_YT2 (ASV_568)                               0.0
#
# nutrient                                        potassium  sulfate  \
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)            1.0      1.0
# Enterobacter_asburiae_LF7a (ASV_568)                  1.0      1.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)        1.0      1.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)         1.0      1.0
# Enterobacter_hormaechei_YT2 (ASV_568)                 1.0      1.0
#
# nutrient                                        tetradecanoate (n-C14:0)
# model
# Enterobacter_aerogenes_KCTC_2190 (ASV_568)                           0.0
# Enterobacter_asburiae_LF7a (ASV_568)                                 0.0
# Enterobacter_cancerogenus_ATCC_35316 (ASV_568)                       0.0
# Enterobacter_cloacae_EcWSU1 (ASV_30, ASV_568)                        0.0
# Enterobacter_hormaechei_YT2 (ASV_568)                                0.0

# %%
ax = sns.clustermap(df_essential_nutrients,
                    method='average',
                    metric='cityblock',
                    figsize=(10,8),
                    cmap=matplotlib.colors.ListedColormap(['white', 'red']),
                    vmin=0, 
                    vmax=1,
                    linewidths=0.5,
                    linecolor='black'
                   )

for tick_label in ax.ax_heatmap.axes.get_yticklabels():
    tick_text = tick_label.get_text()
    if tick_text in ['Klebsiella_oxytoca_KCTC_1686 (ASV_36)', # ASV 36
                     'Klebsiella_pneumoniae_pneumoniae_MGH78578 (ASV_30)', # ASV 30
                     'Escherichia_fergusonii_ATCC_35469 (ASV_3)', # ASV 3
                     'Enterobacter_aerogenes_KCTC_2190 (ASV_568)' # ASV 568, renamed to Klebsiella aerogenes
                    ]:
        tick_label.set_color('red')

# %% [markdown]
# # Parento frontier (westernn diet)

# %%
dict_western = pd.read_csv('../diet/WesternDietAGORA.txt', sep='\t', header=None, index_col=0).to_dict()[1]
dict_western = {k.replace('(e)',''):v for k,v in dict_western.items()}

# %%
models = {'Klebsiella_oxytoca_KCTC_1686':'ASV_36',
          'Klebsiella_pneumoniae_pneumoniae_MGH78578':'ASV_30',
          'Escherichia_fergusonii_ATCC_35469':'ASV_3',
          'Enterobacter_aerogenes_KCTC_2190':'ASV_568'}
          
pareto_front_western = []
for m1 in models.keys():
    for m2 in models.keys():
        taxonomy = pd.DataFrame([[m1,0.5],[m2,0.5]],columns=['model_name','biomass'])
        model = build_community_model(taxonomy,
                                      AGORA_model_dir='../metabolic_models/agora_original/',
                                      steady_com=False,
                                      biomass_coupling=True)
        model = set_culture_medium(model, dict_western)
        output = pareto_front_2species(model)
        pareto_front_western = pareto_front_western + output
pickle.dump(pareto_front_western, open("pareto_front_western.p","wb"))
# Out:
# --------------------------------------------
# Warning: your license will expire in 9 days
# --------------------------------------------
#
# Academic license - for non-commercial use only

# %% [markdown]
# # Parento frontier (high fiber diet)

# %%
dict_highfiber = pd.read_csv('../diet/HighFiberDietAGORA.txt', sep='\t', header=None, index_col=0).to_dict()[1]
dict_highfiber = {k.replace('(e)',''):v for k,v in dict_highfiber.items()}

# %%
models = {'Klebsiella_oxytoca_KCTC_1686':'ASV_36',
          'Klebsiella_pneumoniae_pneumoniae_MGH78578':'ASV_30',
          'Escherichia_fergusonii_ATCC_35469':'ASV_3',
          'Enterobacter_aerogenes_KCTC_2190':'ASV_568'}
          
pareto_front_highfiber = []
for m1 in models.keys():
    for m2 in models.keys():
        taxonomy = pd.DataFrame([[m1,0.5],[m2,0.5]],columns=['model_name','biomass'])
        model = build_community_model(taxonomy,
                                      AGORA_model_dir='../metabolic_models/agora_original/',
                                      steady_com=False,
                                      biomass_coupling=True)
        model = set_culture_medium(model, dict_highfiber)
        output = pareto_front_2species(model)
        pareto_front_highfiber = pareto_front_highfiber + output
pickle.dump(pareto_front_highfiber, open("pareto_front_highfiber.p","wb"))

# %% [markdown]
# # Plot

# %%
pareto_front_western = pickle.load(open("pareto_front_western.p", "rb"))
pareto_front_highfiber = pickle.load(open("pareto_front_highfiber.p", "rb"))

fig, ax = plt.subplots(figsize=(8,8), nrows=4, ncols=4, sharex=True, sharey=True)

# western diet
for l in np.arange(len(pareto_front_western)):
    ll = int(l/2)
    j = int(ll/4)
    i = ll%4
    data = pareto_front_western[l]
    if l%2==0:
        ax[i,j].plot(data[2], data[3], 'r-')
        ax[i,j].set_xlabel(models[data[0].split('__')[0]])
        ax[i,j].set_ylabel(models[data[1].split('__')[0]])
        ax[i,j].set_xlim([0,3])
        ax[i,j].set_ylim([0,3])
    else:
        ax[i,j].plot(data[3], data[2], 'r-')
        
# high fiber diet
for l in np.arange(len(pareto_front_highfiber)):
    ll = int(l/2)
    j = int(ll/4)
    i = ll%4
    data = pareto_front_highfiber[l]
    if l%2==0:
        ax[i,j].plot(data[2], data[3], 'b-')
    else:
        ax[i,j].plot(data[3], data[2], 'b-')
