# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
# %run -i '../../utils.py'

# %% [markdown]
# # Read data

# %%
df_bac = pd.read_csv('16S_relative_abundance_family.csv', index_col=0)
df_meta = pd.read_csv('metadata.csv', index_col=0)

# %% [markdown]
# # Generate stan program files

# %%
selected_bacteria_taxa = generate_stan_files_for_fiber_respones(
    df_bac, # 16S data (relative or absolute), rows are samples, columns are taxa
    df_meta, # meta data, rows are samples, columns are SubjectID, Day, and Dose
    prefix='creswell_2020_family', # prefix of stan file name
    topN=20, # select the topN taxa to run bayesian regression
    stan_path='/Users/liaoc/Documents/cmdstan-2.25.0/projects/microbiome_fiber_response_LD'
)

# %% [markdown]
# # Extract stan output and show significant fiber responses

# %%
fit = az.from_cmdstan(["creswell_2020_family_output_%d.csv"%(i) for i in [1,2,3]])

lines = []
# basal growth rate
for c in selected_bacteria_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# fiber response
for c in selected_bacteria_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['fiber_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# pairwise interactions
for c1 in selected_bacteria_taxa:
    for c2 in selected_bacteria_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.to_excel('bayesian_regression_summary_family.xlsx')

# %%
# select only significant ones
df_stan_output_summary[df_stan_output_summary.Significant==True]
# Out:
#                      Type                                      Taxa  Left  \
# 0       basal_growth_rate                           Lachnospiraceae  0.06
# 20         fiber_response                           Lachnospiraceae  0.02
# 22         fiber_response                        Bifidobacteriaceae  0.01
# 26         fiber_response                           Akkermansiaceae -0.06
# 42   pairwise_interaction     (Lachnospiraceae, Bifidobacteriaceae) -2.98
# 43   pairwise_interaction         (Lachnospiraceae, Bacteroidaceae) -2.56
# 45   pairwise_interaction         (Lachnospiraceae, Prevotellaceae) -2.78
# 46   pairwise_interaction        (Lachnospiraceae, Akkermansiaceae)  4.01
# 51   pairwise_interaction        (Lachnospiraceae, Veillonellaceae) -3.58
# 55   pairwise_interaction     (Lachnospiraceae, Enterobacteriaceae)  0.13
# 59   pairwise_interaction       (Lachnospiraceae, Selenomonadaceae) -3.69
# 60   pairwise_interaction        (Ruminococcaceae, Lachnospiraceae) -1.49
# 86   pairwise_interaction     (Bifidobacteriaceae, Akkermansiaceae)  0.27
# 102  pairwise_interaction      (Bacteroidaceae, Bifidobacteriaceae)  0.09
# 145  pairwise_interaction          (Prevotellaceae, Prevotellaceae)  0.49
# 162  pairwise_interaction     (Akkermansiaceae, Bifidobacteriaceae)  0.40
# 163  pairwise_interaction         (Akkermansiaceae, Bacteroidaceae)  0.50
# 166  pairwise_interaction        (Akkermansiaceae, Akkermansiaceae) -7.71
# 355  pairwise_interaction  (Enterobacteriaceae, Enterobacteriaceae) -3.35
# 439  pairwise_interaction      (Selenomonadaceae, Selenomonadaceae)  0.45
#
#      Right  Middle        SNR  Significant
# 0     1.14   0.600   2.170792         True
# 20    0.07   0.045   3.874751         True
# 22    0.05   0.030   2.555152         True
# 26   -0.01  -0.035  -2.967982         True
# 42   -1.27  -2.125  -4.881729         True
# 43   -0.75  -1.655  -3.604241         True
# 45   -1.23  -2.005  -5.099196         True
# 46    6.06   5.035   9.687111         True
# 51   -0.26  -1.920  -2.259273         True
# 55    2.30   1.215   2.227521         True
# 59   -0.40  -2.045  -2.421658         True
# 60   -0.12  -0.805  -2.317400         True
# 86    2.34   1.305   2.453566         True
# 102   1.80   0.945   2.164243         True
# 145   2.03   1.260   3.200615         True
# 162   2.14   1.270   2.908863         True
# 163   2.29   1.395   3.054047         True
# 166  -5.59  -6.650 -12.445097         True
# 355  -1.21  -2.280  -4.171582         True
# 439   3.72   2.085   2.475141         True
