# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_conc = pd.read_csv('use_conc/time_dependent_relerror.csv', index_col=0)
df_deriv = pd.read_csv('use_deriv/time_dependent_relerror.csv', index_col=0)

# %%
df_conc
# Out:
#      MiceID    Vendor  Day RandomizedGroup  SCFA_value_observed  \
# 0       SI3  Shanghai    0               A             5.055757
# 1       SI3  Shanghai    2               A            19.149833
# 2       SI3  Shanghai    5               A            17.736701
# 3       SI3  Shanghai   10               A            10.600160
# 4       SI3  Shanghai   13               A             8.158938
# ...     ...       ...  ...             ...                  ...
# 1741    SI2  Shanghai   10               B             3.481711
# 1742    SI2  Shanghai   13               B             2.034246
# 1743    SI2  Shanghai   19               B             4.211714
# 1744    SI2  Shanghai   25               B             5.781750
# 1745    SI2  Shanghai   31               B            10.141109
#
#       SCFA_deriv_observed  SCFA_deriv_predicted    SCFA_mol   Perturbation  \
# 0                5.055757             18.518185     Acetate  intrapolation
# 1               19.149833             16.626618     Acetate  intrapolation
# 2               17.736701             21.223508     Acetate  intrapolation
# 3               10.600160             19.038405     Acetate  intrapolation
# 4                8.158938             16.029440     Acetate  intrapolation
# ...                   ...                   ...         ...            ...
# 1741             3.481711              3.482355  Propionate  extrapolation
# 1742             2.034246              1.955441  Propionate  extrapolation
# 1743             4.211714              4.424376  Propionate  extrapolation
# 1744             5.781750              5.583168  Propionate  extrapolation
# 1745            10.141109             10.106994  Propionate  extrapolation
#
#       Feedback  SCFA_deriv_abserror  SCFA_deriv_relerror
# 0        False            13.462429           266.279213
# 1        False            -2.523215           -13.176172
# 2        False             3.486807            19.658711
# 3        False             8.438245            79.604881
# 4        False             7.870502            96.464793
# ...        ...                  ...                  ...
# 1741      True             0.000644             0.018504
# 1742      True            -0.078805            -3.873911
# 1743      True             0.212662             5.049296
# 1744      True            -0.198581            -3.434626
# 1745      True            -0.034115            -0.336399
#
# [1746 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(24,3), nrows=1, ncols=6, sharex=True)
feedback=False

for k1, scfa_ in enumerate(['Acetate','Propionate','Butyrate']):
    for k2, perturbation in enumerate(['intrapolation','extrapolation']):
        idx = k1*2+k2
        curr_df_deriv = df_deriv[(df_deriv.Perturbation==perturbation)&(df_deriv.Feedback==feedback)&(df_deriv.SCFA_mol==scfa_)]
        curr_df_conc = df_conc[(df_conc.Perturbation==perturbation)&(df_conc.Feedback==feedback)&(df_conc.SCFA_mol==scfa_)]
        _ = sns.lineplot(x='Day', y='SCFA_value_relerror', ci=68, marker='o', size=[100]*15, data=curr_df_deriv, ax=ax[idx])
        _ = sns.lineplot(x='Day', y='SCFA_deriv_relerror', ci=68, marker='s', data=curr_df_conc, ax=ax[idx])
        
        if k1==0:
            _ = ax[idx].set_ylim([-100,600])
        if k1==1:
            _ = ax[idx].set_ylim([-300,2800])
        if k1==2:
            _ = ax[idx].set_ylim([-200,1300])

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-258b1e4a386a> in <module>
#       5     for k2, perturbation in enumerate(['intrapolation','extrapolation']):
#       6         idx = k1*2+k2
# ----> 7         _ = sns.lineplot(x='Day', y='SCFA_value_relerror', ci=68, marker='o', size=[100]*139, data=df_deriv[(df_deriv.Perturbation==perturbation)&(df_deriv.Feedback==feedback)&(df_deriv.SCFA_mol==scfa_)], ax=ax[idx])
#       8         _ = sns.lineplot(x='Day', y='SCFA_deriv_relerror', ci=68, marker='s', data=df_conc[(df_conc.Perturbation==perturbation)&(df_conc.Feedback==feedback)&(df_conc.SCFA_mol==scfa_)], ax=ax[idx])
#       9
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     676
#     677     variables = _LinePlotter.get_semantics(locals())
# --> 678     p = _LinePlotter(
#     679         data=data, variables=variables,
#     680         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900                             f" and the vector passed to `{key}` has length {len(val)}."
#     901                         )
# --> 902                         raise ValueError(err)
#     903
#     904                 plot_data[key] = val
#
# ValueError: Length of list vectors must match length of `data` when both are used, but `data` has length 152 and the vector passed to `size` has length 139.
