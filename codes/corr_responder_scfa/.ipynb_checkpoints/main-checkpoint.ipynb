# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr, pearsonr
from sklearn.metrics import r2_score
from statsmodels.stats.multitest import multipletests
from scipy.integrate import simps
from copy import deepcopy
import warnings
from scipy import stats
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read data

# %%
# read meta data
df_meta = pd.read_csv('../../our_data/meta_data.csv', index_col=0)

# read bacterial relative abundance
df_16S_absab = pd.read_csv('../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# read qPCR
df_qpcr = pd.read_csv('../../our_data/qPCR.csv', index_col=0).rename({'Value':'qPCR'},axis=1)
                      
# read scfa
df_scfa = pd.read_csv('../../our_data/SCFA.csv', index_col=0)

# join tables
df = pd.merge(df_meta, df_16S_absab, left_index=True, right_index=True)
df = pd.merge(df, df_qpcr, left_index=True, right_index=True)
df = pd.merge(df, df_scfa, left_index=True, right_index=True)

# add total density of SCFA producers
for scfa in ['Acetate','Butyrate','Propionate']:
    df_scfa_producer = pd.read_csv('../../our_data/taxonomy_plus_scfa_producers.csv', index_col=0)
    df_16S_absab_asv = pd.read_csv('../../our_data/16S_absolute_abundance_asv.csv', index_col=0)
    df_16S_absab_asv = pd.merge(df_16S_absab_asv, df_scfa_producer[['Is%sProducer'%(scfa)]], left_index=True, right_index=True, how='left').fillna(0)
    df_16S_absab_asv = df_16S_absab_asv[df_16S_absab_asv['Is%sProducer'%(scfa)]>0.5]
    df_16S_absab_asv = df_16S_absab_asv.sum().to_frame()
    df_16S_absab_asv.columns = ['qPCR_%s_Producer'%(scfa)]
    df = pd.merge(df, df_16S_absab_asv, left_index=True, right_index=True)
    
# add primary degraders
primary_degraders = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides']
df['Degraders'] = df[primary_degraders].sum(axis=1)

df.head()
# Out:
#           MiceID   Vendor  Day     Diet RandomizedGroup   A2        ASF356  \
# sample131    BC1  Beijing    0  Control               C  0.0  108301.70190
# sample132    BC2  Beijing    0  Control               B  0.0  405068.03470
# sample133    BC3  Beijing    0  Control               A  0.0   36169.60395
# sample134    BC4  Beijing    0  Control               D  0.0  484302.05460
# sample135    BC5  Beijing    0  Control               E  0.0   91489.97053
#
#            Acetatifactor  Acetatifactor-muris  Acidovorax  ...  Propionate  \
# sample131    7101.750943                  0.0         0.0  ...    3.297966
# sample132   50064.588560                  0.0         0.0  ...    2.520570
# sample133   45332.570280                  0.0         0.0  ...    5.569482
# sample134   10150.043060                  0.0         0.0  ...    3.224844
# sample135   42374.302140                  0.0         0.0  ...    4.224119
#
#            Butyrate  Iso-butyrate  Iso-valerate  Valerate      Total  \
# sample131  2.729283      0.253521      0.143931  0.111531  26.741973
# sample132  2.439410      0.222235      0.095223  0.111324  21.178312
# sample133  2.176445      0.586308      0.292805  0.411654  34.101622
# sample134  2.513462      0.276614      0.126857  0.187956  23.310672
# sample135  3.107713      0.356514      0.182745  0.218644  29.891000
#
#            qPCR_Acetate_Producer  qPCR_Butyrate_Producer  \
# sample131           1.531493e+07            5.901555e+06
# sample132           2.040542e+07            9.247385e+06
# sample133           1.137221e+07            3.480963e+06
# sample134           7.006865e+07            2.158624e+07
# sample135           2.387888e+07            7.954812e+06
#
#            qPCR_Propionate_Producer     Degraders
# sample131              1.107607e+07  4.781964e+07
# sample132              1.540624e+07  5.342074e+07
# sample133              8.935339e+06  3.317331e+07
# sample134              5.474208e+07  8.290555e+07
# sample135              1.795418e+07  4.827492e+07
#
# [5 rows x 321 columns]

# %% [markdown]
# # Show correlation between qPCR and SCFA, as well as, SCFA producer composition vs. SCFA

# %%
fig, ax=plt.subplots(nrows=2, ncols=3, figsize=(15,8))

for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    # upper row, qPCR vs. SCFA
    _ = sns.regplot(x='qPCR', y=scfa, data=df, ax=ax[0,k], scatter=False, color='gray')
    _ = sns.scatterplot(x='qPCR', y=scfa, data=df, ax=ax[0,k], hue='Vendor')
    pearson_coef, pearson_P = pearsonr(df['qPCR'], df[scfa])
    _ = ax[0,k].set_title('%s, r=%2.2f (P=%2.2e)'%(scfa, pearson_coef, pearson_P))
    
    
    # bottom row, total qPCR of SCFA producers vs SCFA
    _ = sns.regplot(x='qPCR_%s_Producer'%(scfa), y=scfa, data=df, ax=ax[1,k], scatter=False, color='gray')
    _ = sns.scatterplot(x='qPCR_%s_Producer'%(scfa), y=scfa, data=df, ax=ax[1,k], hue='Vendor')
    pearson_coef, pearson_P = pearsonr(df['qPCR_%s_Producer'%(scfa)], df[scfa])
    _ = ax[1,k].set_title('%s, r=%2.2f (P=%2.2e)'%(scfa, pearson_coef, pearson_P))

plt.tight_layout()

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("correlation_qPCR_scfa.svg", format="svg")

# %% [markdown]
# # Show correlation between degraders and SCFA

# %%
fig, ax=plt.subplots(nrows=2, ncols=3, figsize=(15,8))

for k,degrader in enumerate(primary_degraders+['Degraders']):
    kr = int(k/3)
    kc = k % 3
    _ = sns.regplot(x=degrader, y='Propionate', data=df, ax=ax[kr,kc], scatter=False, color='gray')
    _ = sns.scatterplot(x=degrader, y='Propionate', data=df, ax=ax[kr,kc], hue='Vendor')
    pearson_coef, pearson_P = pearsonr(df[degrader], df['Propionate'])
    _ = ax[kr,kc].set_title('Propionate, r=%2.2f (P=%2.2e)'%(pearson_coef, pearson_P))
    if k==5:
        ax[kr,kc].set_xlim([-1e7,5.5e8])
    
plt.tight_layout()

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("correlation_degrader_propionate.svg", format="svg")

# %%
# Create dataset
height = [0.69,0.63,0.45,0.40,0.37,-0.09]
bars = ('Total', 'Muribaculaceae', 'Parasutterella', 'Bacteroides-acidifaciens', 'Faecalibaculum','Bacteroides')
x_pos = np.arange(len(bars))
 
# Create bars
plt.bar(x_pos, height)
 
# Create names on the x-axis
plt.xticks(x_pos, bars)

plt.ylim([-0.1,0.8])
 
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig("Pearson_correlation_barplot.svg", format="svg")

# %% [markdown]
# # Read data

# %%
# read bacterial relative abundance
df_16S_relab = pd.read_csv('../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# read qPCR
df_qpcr = pd.read_csv('../../our_data/qPCR.csv', index_col=0).rename({'Value':'qPCR'},axis=1)

# read scfa
df_scfa = pd.read_csv('../../our_data/SCFA.csv', index_col=0)

# read meta data
df_meta = pd.read_csv('../../our_data/meta_data.csv', index_col=0)
df_meta = df_meta[df_meta.Diet=='Inulin']
df_16S_relab = df_16S_relab.loc[df_meta.index]
df_qpcr = df_qpcr.loc[df_meta.index]
df_meta = pd.merge(df_meta, df_16S_relab, left_index=True, right_index=True)
df_meta = pd.merge(df_meta, df_qpcr, left_index=True, right_index=True)
df_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True)

# calculate total relative abundance of inulin responders
inulin_responders = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides']
df_meta['AllResponders'] = df_meta[inulin_responders].sum(axis=1)
df_meta['BaMu'] = df_meta[['Bacteroides-acidifaciens','Muribaculaceae']].sum(axis=1)
#df_meta['BaMu'] = stats.gmean(df_meta[['Bacteroides-acidifaciens','Muribaculaceae']], axis=1)
df_meta['BaMuFa'] = df_meta[['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum']].sum(axis=1)

df_meta.head()
# Out:
#           MiceID   Vendor  Day    Diet RandomizedGroup           A2  \
# SampleID
# sample141    BI1  Beijing    0  Inulin               A      0.00000
# sample142    BI2  Beijing    0  Inulin               B  79938.73811
# sample143    BI3  Beijing    0  Inulin               D      0.00000
# sample144    BI4  Beijing    0  Inulin               E  61973.98659
# sample145    BI5  Beijing    0  Inulin               C      0.00000
#
#                  ASF356  Acetatifactor  Acetatifactor-muris  Acidovorax  ...  \
# SampleID                                                                 ...
# sample141   58318.68678    98146.08263                  0.0         0.0  ...
# sample142   25274.74808    33503.73582                  0.0         0.0  ...
# sample143  137987.68630    64115.49061                  0.0         0.0  ...
# sample144  142310.63590    94108.64630                  0.0         0.0  ...
# sample145  122899.45460   119532.34630                  0.0         0.0  ...
#
#              Acetate  Propionate  Butyrate  Iso-butyrate  Iso-valerate  \
# SampleID
# sample141   5.233899    1.930933  1.109582      0.209460      0.103316
# sample142  13.459823    3.621771  1.546647      0.331414      0.176167
# sample143  18.075378    2.859916  1.682656      0.234600      0.144922
# sample144  12.580368    3.148773  1.477688      0.156928      0.105900
# sample145   8.065127    3.134209  1.835172      0.308168      0.174705
#
#            Valerate      Total  AllResponders          BaMu        BaMuFa
# SampleID
# sample141  0.115502   8.702693   4.824662e+07  2.631168e+07  4.134653e+07
# sample142  0.100110  19.235932   2.459233e+07  1.373653e+07  2.236521e+07
# sample143  0.220280  23.217751   5.642860e+07  4.684055e+07  5.399918e+07
# sample144  0.144724  17.614381   2.961668e+07  2.554935e+07  2.819816e+07
# sample145  0.060569  13.577951   6.287233e+07  4.820184e+07  5.895975e+07
#
# [5 rows x 320 columns]

# %% [markdown]
# # Correlation between baseline abundance of primary degraders and mean qPCR values

# %%
lines = []
covariants = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides', 'BaMu', 'AllResponders']
for responder in covariants:
    pearson_coef, pearson_P = pearsonr(np.asarray(df_meta[responder]), np.asarray(df_meta.qPCR))
    spearman_coef, spearman_P = spearmanr(np.asarray(df_meta[responder]), np.asarray(df_meta.qPCR))
    lines.append([responder, pearson_coef, pearson_P, spearman_coef, spearman_P, pearson_coef**2])
df_responder_qpcr_assoc = pd.DataFrame(lines, columns=['InulinResponder','Pearson','Pearson_P','Spearman','Spearman_P','R2'])
df_responder_qpcr_assoc
# Out:
#             InulinResponder   Pearson     Pearson_P  Spearman    Spearman_P  \
# 0  Bacteroides-acidifaciens  0.428636  3.604084e-08  0.689629  8.849009e-23
# 1            Muribaculaceae  0.770444  3.956422e-31  0.811303  8.595479e-37
# 2            Faecalibaculum  0.363991  4.033104e-06  0.414157  1.132590e-07
# 3            Parasutterella  0.265630  9.413279e-04  0.295105  2.235405e-04
# 4               Bacteroides -0.182036  2.479709e-02 -0.138109  8.973261e-02
# 5                      BaMu  0.851840  5.711838e-44  0.888996  9.577492e-53
# 6             AllResponders  0.851413  6.971698e-44  0.882616  4.947363e-51
#
#          R2
# 0  0.183728
# 1  0.593584
# 2  0.132490
# 3  0.070559
# 4  0.033137
# 5  0.725632
# 6  0.724903

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Pearson
_ = sns.barplot(x='InulinResponder', y='Pearson', data=df_responder_qpcr_assoc, ax=ax[0], ci=68)

# Bacteroides-acidifaciens + Muribaculaceae
_ = sns.regplot(x='BaMu', y='qPCR', color='gray', data=df_meta, ax=ax[1], ci=68)
_ = sns.scatterplot(x='BaMu', y='qPCR', hue='Vendor', size='Day', data=df_meta, ax=ax[1])
#_ = ax[1].set_xlim([-0.08,0.8])

plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('correlation_inulin_responder_vs_qpcr.svg', format='svg')

# %% [markdown]
# # Predict response (averaged absolute abundance) from total relative abundance of inulin responders in the baseline

# %%
lines = []
covariants = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides',
              'BaMu','AllResponders']

lines = []
lines2 = []
for responder in covariants:
    initial_relab = []
    qpcr_ave = []
    for mice in set(df_meta.MiceID):
        df_tmp = df_meta[df_meta.MiceID==mice].sort_values(by='Day')
        vendor = list(set(df_tmp.Vendor))[0]
        x = list(df_tmp.Day)
        y = list(df_tmp.qPCR)
        initial_relab.append(df_tmp.loc[df_tmp.Day==0,responder].values[0])
        qpcr_ave.append(simps(y,x)/np.max(x))
        
        if responder=='BaMu':
            lines2.append([initial_relab[-1],qpcr_ave[-1],vendor])
    pearson_coef, pearson_P = pearsonr(initial_relab, qpcr_ave)
    spearman_coef, spearman_P = spearmanr(initial_relab, qpcr_ave)
    lines.append([responder, pearson_coef, pearson_P, spearman_coef, spearman_P, pearson_coef**2])
df_responder_qpcr_assoc = pd.DataFrame(lines, columns=['InulinResponder','Pearson','Pearson_P','Spearman','Spearman_P','R2'])
df_responder_qpcr_assoc
# Out:
#             InulinResponder   Pearson  Pearson_P  Spearman  Spearman_P  \
# 0  Bacteroides-acidifaciens  0.349224   0.155476  0.665635    0.002568
# 1            Muribaculaceae  0.654464   0.003209  0.620227    0.006032
# 2            Faecalibaculum -0.093592   0.711843  0.065015    0.797715
# 3            Parasutterella  0.291099   0.241212  0.153767    0.542403
# 4               Bacteroides -0.580455   0.011549 -0.310630    0.209625
# 5                      BaMu  0.644571   0.003880  0.622291    0.005819
# 6             AllResponders  0.207385   0.408959  0.217750    0.385396
#
#          R2
# 0  0.121958
# 1  0.428323
# 2  0.008759
# 3  0.084739
# 4  0.336928
# 5  0.415472
# 6  0.043009

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Pearson
_ = sns.barplot(x='InulinResponder', y='Pearson', data=df_responder_qpcr_assoc, ax=ax[0])

# scatterplot
df_tmp = pd.DataFrame(lines2, columns=['BaMu','qPCR','Vendor'])
_ = sns.regplot(x='BaMu', y='qPCR', color='gray', data=df_tmp, ax=ax[1])
_ = sns.scatterplot(x='BaMu', y='qPCR', hue='Vendor', data=df_tmp, ax=ax[1])
#_ = ax[1].set_xlim([-0.05,0.5])

plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('correlation_baseline_inulin_responder_vs_qpcr_ave.svg', format='svg')

# %% [markdown]
# # Plot SCFA/qPCR

# %%
df = df_meta[['MiceID','Vendor','Day','qPCR','Acetate','Butyrate','Propionate']]
df['Acetate'] = np.log10(df['Acetate']/df['qPCR'])
df['Butyrate'] = np.log10(df['Butyrate']/df['qPCR'])
df['Propionate'] = np.log10(df['Propionate']/df['qPCR'])

# %% [markdown]
# # plot qPCR and SCFA correlation

# %%
df = df_meta[['MiceID','Vendor','Day','qPCR','Acetate','Butyrate','Propionate']]

fig, ax=plt.subplots(nrows=1, ncols=3, figsize=(15,4))
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    _ = sns.scatterplot(x='qPCR', y=scfa, data=df, ax=ax[k], hue='Vendor')

# %% [markdown]
# # Predict SCFA from initial primary degraders

# %%
# lines = []
covariants = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides',
              'BaMu','AllResponders']

lines = []
lines2 = []
for responder in covariants:
    for scfa in ['Acetate','Butyrate','Propionate','Total']:
        initial_relab = []
        scfa_ave = []
        for mice in set(df_meta.MiceID):
            df_tmp = df_meta[df_meta.MiceID==mice].sort_values(by='Day')
            vendor = list(set(df_tmp.Vendor))[0]
            x = list(df_tmp.Day)
            initial_relab.append(df_tmp.loc[df_tmp.Day==0,responder].values[0])
            y = list(df_tmp[scfa])
            scfa_ave.append(simps(y,x)/np.max(x))
            if responder=='BaMu' and scfa=='Propionate':
                lines2.append([initial_relab[-1],scfa_ave[-1],vendor])
        pearson_coef, pearson_P = pearsonr(initial_relab, scfa_ave)
        spearman_coef, spearman_P = spearmanr(initial_relab, scfa_ave)
        lines.append([responder, scfa, pearson_coef, pearson_P, spearman_coef, spearman_P, pearson_coef**2])
df_responder_qpcr_assoc = pd.DataFrame(lines, columns=['InulinResponder','SCFA','Pearson','Pearson_P','Spearman','Spearman_P','R2'])
df_responder_qpcr_assoc
# Out:
#              InulinResponder        SCFA   Pearson  Pearson_P  Spearman  \
# 0   Bacteroides-acidifaciens     Acetate -0.101882   0.687488  0.052632
# 1   Bacteroides-acidifaciens    Butyrate -0.462307   0.053400 -0.649123
# 2   Bacteroides-acidifaciens  Propionate  0.404107   0.096269  0.657379
# 3   Bacteroides-acidifaciens       Total  0.010164   0.968072  0.298246
# 4             Muribaculaceae     Acetate -0.014049   0.955877  0.031992
# 5             Muribaculaceae    Butyrate -0.509406   0.030825 -0.531476
# 6             Muribaculaceae  Propionate  0.746879   0.000369  0.680083
# 7             Muribaculaceae       Total  0.229158   0.360353  0.339525
# 8             Faecalibaculum     Acetate -0.073083   0.773202  0.025800
# 9             Faecalibaculum    Butyrate -0.122508   0.628191 -0.277606
# 10            Faecalibaculum  Propionate -0.059024   0.816039  0.164087
# 11            Faecalibaculum       Total -0.113389   0.654165  0.011352
# 12            Parasutterella     Acetate -0.443313   0.065381 -0.440660
# 13            Parasutterella    Butyrate -0.110438   0.662657  0.089783
# 14            Parasutterella  Propionate  0.287629   0.247123  0.077399
# 15            Parasutterella       Total -0.167319   0.506937 -0.095975
# 16               Bacteroides     Acetate -0.259935   0.297558 -0.238390
# 17               Bacteroides    Butyrate  0.380385   0.119426  0.131063
# 18               Bacteroides  Propionate -0.590213   0.009922 -0.457172
# 19               Bacteroides       Total -0.362150   0.139718 -0.356037
# 20                      BaMu     Acetate -0.038180   0.880443 -0.019608
# 21                      BaMu    Butyrate -0.550834   0.017831 -0.583075
# 22                      BaMu  Propionate  0.737026   0.000484  0.680083
# 23                      BaMu       Total  0.196778   0.433849  0.287926
# 24             AllResponders     Acetate -0.281798   0.257262 -0.226006
# 25             AllResponders    Butyrate -0.268498   0.281346 -0.335397
# 26             AllResponders  Propionate  0.283419   0.254419  0.263158
# 27             AllResponders       Total -0.112511   0.656688 -0.052632
#
#     Spearman_P        R2
# 0     0.835690  0.010380
# 1     0.003558  0.213728
# 2     0.003030  0.163302
# 3     0.229322  0.000103
# 4     0.899719  0.000197
# 5     0.023216  0.259494
# 6     0.001900  0.557829
# 7     0.168071  0.052513
# 8     0.919060  0.005341
# 9     0.264710  0.015008
# 10    0.515295  0.003484
# 11    0.964342  0.012857
# 12    0.067202  0.196527
# 13    0.723123  0.012196
# 14    0.760167  0.082731
# 15    0.704812  0.027996
# 16    0.340780  0.067566
# 17    0.604194  0.144692
# 18    0.056462  0.348352
# 19    0.147026  0.131153
# 20    0.938446  0.001458
# 21    0.011092  0.303418
# 22    0.001900  0.543208
# 23    0.246615  0.038722
# 24    0.367178  0.079410
# 25    0.173635  0.072091
# 26    0.291392  0.080326
# 27    0.835690  0.012659

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Pearson
_ = sns.barplot(x='InulinResponder', y='Pearson', data=df_responder_qpcr_assoc[df_responder_qpcr_assoc.SCFA=='Propionate'], ax=ax[0])

# scatterplot
df_tmp = pd.DataFrame(lines2, columns=['BaMu','qPCR','Vendor'])
_ = sns.regplot(x='BaMu', y='qPCR', color='gray', data=df_tmp, ax=ax[1])
_ = sns.scatterplot(x='BaMu', y='qPCR', hue='Vendor', data=df_tmp, ax=ax[1])
#_ = ax[1].set_xlim([-0.05,0.5])

plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('correlation_baseline_inulin_responder_vs_qpcr_ave.svg', format='svg')

# %% [markdown]
# # Plot correlation between top20 species in gLV model

# %%
# read meta data
df_meta = pd.read_csv('../../../our_data/meta_data.csv', index_col=0)
df_meta = df_meta[df_meta.Diet==diet]

# read bacterial absolute abundance
df_bac = pd.read_csv('../../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# select the species included in glv model
df_glv_inulin = pd.read_excel('../../figure3_fiber_responder/inulin/stan_output_summary_absolute_abundance_top20_species.xlsx', index_col=0)
df_glv_inulin = df_glv_inulin[df_glv_inulin.Type=='basal_growth_rate']
taxa_in_glv_model = [t.replace('_slash_','/').replace('_space_',' ').replace('_leftsquarebracket_','[').replace('_rightsquarebracket_',']').replace('_dash_','-').replace('_dot_','.').replace('_leftroundbracket','(').replace('_rightroundbracket_',')') for t in list(set(df_glv_inulin.Taxa))]
df_bac = df_bac[taxa_in_glv_model]

# plot clustermap
_ = sns.clustermap(df_bac.corr(method='pearson'),
                   cmap='RdYlBu_r',
                   vmin=-1,
                   vmax=1
                  )

# %% [markdown]
# # Plot point-to-point correlation between species w/ significant indivudalized responses

# %%
# read meta data
df_meta = pd.read_csv('../../../our_data/meta_data.csv', index_col=0)
df_meta = df_meta[df_meta.Diet==diet]

# read bacterial absolute abundance
df_bac = pd.read_csv('../../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# select the species included in glv model
df_sig_ir = pd.read_csv('../../figure4_individualized_response/inulin/bacterial_species_w_sig_individualized_response.csv', index_col=0)
df_bac = df_bac[list(df_sig_ir.index)]

# plot clustermap
df_corr = df_bac.corr(method='pearson').loc[list(df_bac.columns), list(df_bac.columns)]
fig = sns.clustermap(df_corr,
                   cmap='RdYlBu_r',
                   vmin=-1,
                   vmax=1,
                   figsize=(15,15)
                  )
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig('correlation_inulin_responder_vs_species_w_sig_ir.svg', format='svg')

# %% [markdown]
# # Identify baseline species that explains overall responses of responders (area under curve)

# %% [markdown]
# ## baseline absolute abundance vs. absolute abundance of species w/ individualized response

# %%
# read bacterial absolute abundance
df_bac = pd.read_csv('../../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# read meta data
df_meta = pd.read_csv('../../../our_data/meta_data.csv', index_col=0)
df_meta = df_meta[df_meta.Diet=='Inulin']
df_bac = df_bac.loc[df_meta.index]
df_meta_bac = pd.merge(df_meta, df_bac, left_index=True, right_index=True)

# use species that show significant individualized responses
inulin_responders = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides']
df_sig_ir = pd.read_csv('../../figure4_individualized_response/inulin/bacterial_species_w_sig_individualized_response.csv', index_col=0)
all_species = list(df_sig_ir.index)

lines = []
for sp in all_species:
    for responder in inulin_responders:
        baseline = []
        normalized_auc = []
        for mice in set(df_meta.MiceID):
            df_tmp = df_meta_bac[df_meta_bac.MiceID==mice].sort_values(by='Day')
            vendor = list(set(df_tmp['Vendor']))[0]
            baseline.append(list(df_tmp[sp])[0])
            x = list(df_tmp.Day)
            y = list(df_tmp[responder])
            normalized_auc.append(simps(y,x)/np.max(x)) # area under the curve divided by duration        
        scorr, sP = spearmanr(baseline,normalized_auc)
        rcorr, rP = pearsonr(baseline,normalized_auc)
        lines.append([sp, responder, scorr, sP, rcorr, rP])

# save spearman correlation file
df_baseline_responder_assoc = pd.DataFrame(lines, columns=['Species','Responder','PearsonCoef','PearsonP','SpearmanCoef','SpearmanP'])
df_baseline_responder_assoc = df_baseline_responder_assoc.dropna()
df_baseline_responder_assoc['PearsonPCorrected'] = multipletests(df_baseline_responder_assoc['PearsonP'],method='fdr_bh')[1]
df_baseline_responder_assoc['SpearmanCorrected'] = multipletests(df_baseline_responder_assoc['SpearmanP'],method='fdr_bh')[1]
df_baseline_responder_assoc.to_csv('baseline_species_vs_inulin_responder_correlation_absolute_abundance.csv')

# plot clustermap
df_corr = pd.pivot_table(df_baseline_responder_assoc[['Species','Responder','PearsonCoef']],
                         index='Species',
                         columns='Responder',
                         values='PearsonCoef').reset_index().set_index('Species')
fig = sns.clustermap(df_corr,
                     cmap='RdYlBu_r',
                     vmin=-1,
                     vmax=1,
                     figsize=(5,15)
                     )
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig('baseline_responder_correlation_inulin_absolute_abundance.svg', format='svg')

# %% [markdown]
# ## baseline relative abundance vs. absolute abundance of species w/ individualized response

# %%
# read bacterial relative abundance
df_bac = pd.read_csv('../../../our_data/16S_relative_abundance_species.csv', index_col=0)

# read bacterial absolute abundance
df_bac_baseline = pd.read_csv('../../../our_data/16S_absolute_abundance_species.csv', index_col=0)

# read meta data
df_meta = pd.read_csv('../../../our_data/meta_data.csv', index_col=0)
df_meta = df_meta[df_meta.Diet=='Inulin']
df_bac = df_bac.loc[df_meta.index]
df_meta_bac = pd.merge(df_meta, df_bac, left_index=True, right_index=True)

# use species that show significant individualized responses
inulin_responders = ['Bacteroides-acidifaciens','Muribaculaceae','Faecalibaculum','Parasutterella','Bacteroides']
df_sig_ir = pd.read_csv('../../figure4_individualized_response/inulin/bacterial_species_w_sig_individualized_response.csv', index_col=0)
all_species = list(df_sig_ir.index)

lines = []
for sp in all_species:
    for responder in inulin_responders:
        baseline = []
        normalized_auc = []
        for mice in set(df_meta.MiceID):
            df_tmp = df_meta_bac[df_meta_bac.MiceID==mice].sort_values(by='Day')
            sampleid = list(df_tmp.index)[0]
            vendor = list(set(df_tmp['Vendor']))[0]
            baseline.append(df_bac_baseline.loc[sampleid,sp])
            x = list(df_tmp.Day)
            y = list(df_tmp[responder])
            normalized_auc.append(simps(y,x)/np.max(x)) # area under the curve divided by duration        
        scorr, sP = spearmanr(baseline,normalized_auc)
        rcorr, rP = pearsonr(baseline,normalized_auc)
        lines.append([sp, responder, scorr, sP, rcorr, rP])

# save spearman correlation file
df_baseline_responder_assoc = pd.DataFrame(lines, columns=['Species','Responder','PearsonCoef','PearsonP','SpearmanCoef','SpearmanP'])
df_baseline_responder_assoc = df_baseline_responder_assoc.dropna()
df_baseline_responder_assoc['PearsonPCorrected'] = multipletests(df_baseline_responder_assoc['PearsonP'],method='fdr_bh')[1]
df_baseline_responder_assoc['SpearmanCorrected'] = multipletests(df_baseline_responder_assoc['SpearmanP'],method='fdr_bh')[1]
df_baseline_responder_assoc.to_csv('baseline_species_vs_inulin_responder_correlation_absolute_abundance.csv')

# plot clustermap
df_corr = pd.pivot_table(df_baseline_responder_assoc[['Species','Responder','PearsonCoef']],
                         index='Species',
                         columns='Responder',
                         values='PearsonCoef').reset_index().set_index('Species')
fig = sns.clustermap(df_corr,
                     cmap='RdYlBu_r',
                     vmin=-1,
                     vmax=1,
                     figsize=(5,15)
                     )
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig('baseline_responder_correlation_inulin_relative_abundance.svg', format='svg')
