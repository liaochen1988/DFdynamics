# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (remove Beijing mice data since their SCFA data are incomplete)

# %%
df_meta = pd.read_excel('../../../../../data/meta_data.xlsx', index_col=0)
df_meta = df_meta[df_meta.Vendor != 'Beijing']
df_meta = df_meta[df_meta.Diet == 'Resistant starch']
df_meta.head()
# Out:
#           MiceID     Vendor  Day              Diet
# SampleID
# sample406    GR1  Guangdong    0  Resistant starch
# sample407    GR2  Guangdong    0  Resistant starch
# sample408    GR3  Guangdong    0  Resistant starch
# sample409    GR4  Guangdong    0  Resistant starch
# sample410    GR5  Guangdong    0  Resistant starch

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_excel('../../../../../data/SCFA.xlsx', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
df_scfa = df_scfa.loc[df_meta.index]
df_scfa.head()
# Out:
#              Acetate  Butyrate  Propionate
# SampleID
# sample406   8.483426  1.263977    1.850869
# sample407  11.945646  0.956402    2.772971
# sample408  11.208475  1.813452    1.765664
# sample409  11.874095  2.632026    2.799104
# sample410  11.656958  1.719326    2.622626

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.664724    0.805789
# Butyrate    0.664724  1.000000    0.584910
# Propionate  0.805789  0.584910    1.000000

# %% [markdown]
# # Read 16S data (use relative abundance)

# %%
df_16S = pd.read_excel('../../../../../data/16S_relative_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_meta.index]
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#                  A2    ASF356  Acetatifactor  Acetatifactor_dash_muris  \
# SampleID
# sample406  0.000277  0.001022       0.001709                       0.0
# sample407  0.000509  0.000660       0.000522                       0.0
# sample408  0.000150  0.001869       0.000741                       0.0
# sample409  0.000163  0.001757       0.000296                       0.0
# sample410  0.000000  0.000797       0.000153                       0.0
#
#            Acidovorax  Acinetobacter  \
# SampleID
# sample406         0.0            0.0
# sample407         0.0            0.0
# sample408         0.0            0.0
# sample409         0.0            0.0
# sample410         0.0            0.0
#
#            Acinetobacter_dash_sp_dot__dash_CIP_dash_56_dot_2  \
# SampleID
# sample406                                                0.0
# sample407                                                0.0
# sample408                                                0.0
# sample409                                                0.0
# sample410                                                0.0
#
#            Acutalibacter_dash_muris  Adlercreutzia_dash_mucosicola  \
# SampleID
# sample406                       0.0                       0.000000
# sample407                       0.0                       0.000000
# sample408                       0.0                       0.000000
# sample409                       0.0                       0.000000
# sample410                       0.0                       0.000276
#
#            Adlercreutzia_dash_muris  ...  \
# SampleID                             ...
# sample406                       0.0  ...
# sample407                       0.0  ...
# sample408                       0.0  ...
# sample409                       0.0  ...
# sample410                       0.0  ...
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_ventriosum_dash_group  \
# SampleID
# sample406                                                0.0
# sample407                                                0.0
# sample408                                                0.0
# sample409                                                0.0
# sample410                                                0.0
#
#            _leftsquarebracket_Eubacterium_rightsquarebracket__dash_xylanophilum_dash_group  \
# SampleID
# sample406                                           0.001037
# sample407                                           0.001114
# sample408                                           0.001074
# sample409                                           0.000613
# sample410                                           0.000368
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_gnavus_dash_group  \
# SampleID
# sample406                                                0.0
# sample407                                                0.0
# sample408                                                0.0
# sample409                                                0.0
# sample410                                                0.0
#
#            _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# sample406                                                0.0
# sample407                                                0.0
# sample408                                                0.0
# sample409                                                0.0
# sample410                                                0.0
#
#            bacterium_dash_enrichment_dash_culture_dash_clone_dash_M153  \
# SampleID
# sample406                                                0.0
# sample407                                                0.0
# sample408                                                0.0
# sample409                                                0.0
# sample410                                                0.0
#
#            gut_dash_metagenome  human_dash_gut_dash_metagenome  \
# SampleID
# sample406             0.000497                             0.0
# sample407             0.001897                             0.0
# sample408             0.000419                             0.0
# sample409             0.000092                             0.0
# sample410             0.001518                             0.0
#
#            marine_dash_metagenome  metagenome  mouse_dash_gut_dash_metagenome
# SampleID
# sample406                     0.0         0.0                        0.000000
# sample407                     0.0         0.0                        0.000371
# sample408                     0.0         0.0                        0.001375
# sample409                     0.0         0.0                        0.001982
# sample410                     0.0         0.0                        0.000000
#
# [5 rows x 304 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#            Muribaculaceae  Parabacteroides_dash_goldsteinii  Bacteroides  \
# SampleID
# sample406        0.213719                          0.002921     0.005959
# sample407        0.170150                          0.004070     0.019373
# sample408        0.183744                          0.002954     0.048852
# sample409        0.342581                          0.002482     0.006251
# sample410        0.248183                          0.003251     0.013434
#
#            Faecalibaculum  Lachnospiraceae_dash_NK4A136_dash_group  \
# SampleID
# sample406        0.014707                                 0.030187
# sample407        0.001856                                 0.013873
# sample408        0.047606                                 0.018991
# sample409        0.106907                                 0.024842
# sample410        0.079144                                 0.006579
#
#            Bacteroides_dash_acidifaciens  Alloprevotella  Parasutterella  \
# SampleID
# sample406                       0.005652        0.182627        0.000570
# sample407                       0.019332        0.115468        0.000564
# sample408                       0.011923        0.093172        0.001482
# sample409                       0.005649        0.022758        0.002799
# sample410                       0.010382        0.220656        0.004647
#
#            Lachnospiraceae  Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SampleID
# sample406         0.036350                                       0.001066
# sample407         0.041345                                       0.000770
# sample408         0.040281                                       0.000935
# sample409         0.028571                                       0.000460
# sample410         0.008511                                       0.000383
#
#            ...  Odoribacter  Roseburia  Desulfovibrio  Tuzzerella  \
# SampleID   ...
# sample406  ...     0.016766   0.004308       0.000759    0.003607
# sample407  ...     0.038127   0.006119       0.000426    0.002860
# sample408  ...     0.006090   0.006359       0.001010    0.002546
# sample409  ...     0.013821   0.009489       0.000592    0.001502
# sample410  ...     0.006885   0.004202       0.000000    0.001702
#
#            Lachnospiraceae_dash_UCG_dash_006  Helicobacter_dash_mastomyrinus  \
# SampleID
# sample406                           0.003490                        0.002293
# sample407                           0.003190                        0.005582
# sample408                           0.003813                        0.005725
# sample409                           0.002053                        0.012329
# sample410                           0.001227                        0.008710
#
#            Lactobacillus  Lachnoclostridium  \
# SampleID
# sample406       0.001913           0.004746
# sample407       0.000935           0.006668
# sample408       0.006542           0.006295
# sample409       0.005240           0.002257
# sample410       0.003067           0.000629
#
#            Lachnospiraceae_dash_bacterium_dash_DW59  GCA_dash_900066575
# SampleID
# sample406                                  0.001271            0.010281
# sample407                                  0.000344            0.005830
# sample408                                  0.004383            0.003878
# sample409                                  0.001042            0.001440
# sample410                                  0.001472            0.000414
#
# [5 rows x 40 columns]

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.8577531552971929

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.MiceID):
    curr_df = df_scfa_meta[df_scfa_meta.MiceID==curr_mice]
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.MiceID==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#              Acetate   Butyrate  Propionate
# SampleID
# sample406   0.601950  -1.625813    0.182595
# sample407   0.176444  10.259601    0.518874
# sample408 -11.774813   0.475036   -0.738201
# sample409   7.877816   5.081010    6.151909
# sample410  -1.801557   5.524064   -1.269226

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#            Muribaculaceae  Parabacteroides_dash_goldsteinii  Bacteroides  \
# SampleID
# sample406        0.324089                          0.004429     0.009036
# sample407        0.258020                          0.006172     0.029378
# sample408        0.278634                          0.004479     0.074081
# sample409        0.519499                          0.003764     0.009480
# sample410        0.376351                          0.004930     0.020371
#
#            Faecalibaculum  Lachnospiraceae_dash_NK4A136_dash_group  \
# SampleID
# sample406        0.022301                                 0.045776
# sample407        0.002815                                 0.021038
# sample408        0.072191                                 0.028798
# sample409        0.162117                                 0.037671
# sample410        0.120016                                 0.009976
#
#            Bacteroides_dash_acidifaciens  Alloprevotella  Parasutterella  \
# SampleID
# sample406                       0.008571        0.276940        0.000864
# sample407                       0.029315        0.175099        0.000855
# sample408                       0.018080        0.141288        0.002248
# sample409                       0.008566        0.034511        0.004244
# sample410                       0.015743        0.334609        0.007046
#
#            Lachnospiraceae  Lachnospiraceae_dash_bacterium_dash_28_dash_4  \
# SampleID
# sample406         0.055122                                       0.001617
# sample407         0.062696                                       0.001168
# sample408         0.061082                                       0.001417
# sample409         0.043325                                       0.000697
# sample410         0.012906                                       0.000581
#
#            ...  Odoribacter  Roseburia  Desulfovibrio  Tuzzerella  \
# SampleID   ...
# sample406  ...     0.025424   0.006533       0.001152    0.005470
# sample407  ...     0.057817   0.009278       0.000646    0.004337
# sample408  ...     0.009236   0.009643       0.001531    0.003860
# sample409  ...     0.020958   0.014390       0.000898    0.002277
# sample410  ...     0.010441   0.006372       0.000000    0.002581
#
#            Lachnospiraceae_dash_UCG_dash_006  Helicobacter_dash_mastomyrinus  \
# SampleID
# sample406                           0.005293                        0.003477
# sample407                           0.004837                        0.008465
# sample408                           0.005782                        0.008682
# sample409                           0.003113                        0.018696
# sample410                           0.001860                        0.013209
#
#            Lactobacillus  Lachnoclostridium  \
# SampleID
# sample406       0.002901           0.007198
# sample407       0.001418           0.010112
# sample408       0.009920           0.009545
# sample409       0.007946           0.003423
# sample410       0.004651           0.000953
#
#            Lachnospiraceae_dash_bacterium_dash_DW59  GCA_dash_900066575
# SampleID
# sample406                                  0.001927            0.015591
# sample407                                  0.000521            0.008840
# sample408                                  0.006646            0.005880
# sample409                                  0.001580            0.002184
# sample410                                  0.002232            0.000628
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA                                 Variable   Pearson  Spearman
# 0  Acetate                           Muribaculaceae -0.003354  0.075344
# 1  Acetate         Parabacteroides_dash_goldsteinii -0.015511 -0.029841
# 2  Acetate                              Bacteroides -0.099920 -0.107102
# 3  Acetate                           Faecalibaculum -0.012102  0.031846
# 4  Acetate  Lachnospiraceae_dash_NK4A136_dash_group -0.020015  0.078778

# %%
df_corr.to_excel('correlation_top40.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
#df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasticnet.head()
# Out:
#              BestAlpha  L1Ratio   R2  Muribaculaceae  \
# SCFA
# Acetate     623.247588   0.0001  0.0   -0.000000e+00
# Butyrate    683.912788   0.0001  0.0   -0.000000e+00
# Propionate  153.069621   0.0001  0.0   -8.594196e-20
#
#             Parabacteroides_dash_goldsteinii  Bacteroides  Faecalibaculum  \
# SCFA
# Acetate                                 -0.0         -0.0            -0.0
# Butyrate                                 0.0          0.0            -0.0
# Propionate                              -0.0         -0.0            -0.0
#
#             Lachnospiraceae_dash_NK4A136_dash_group  \
# SCFA
# Acetate                                        -0.0
# Butyrate                                       -0.0
# Propionate                                     -0.0
#
#             Bacteroides_dash_acidifaciens  Alloprevotella  ...  Odoribacter  \
# SCFA                                                       ...
# Acetate                               0.0             0.0  ...          0.0
# Butyrate                             -0.0             0.0  ...          0.0
# Propionate                            0.0            -0.0  ...          0.0
#
#             Roseburia  Desulfovibrio  Tuzzerella  \
# SCFA
# Acetate          -0.0            0.0        -0.0
# Butyrate          0.0            0.0         0.0
# Propionate        0.0            0.0         0.0
#
#             Lachnospiraceae_dash_UCG_dash_006  Helicobacter_dash_mastomyrinus  \
# SCFA
# Acetate                                   0.0                             0.0
# Butyrate                                  0.0                             0.0
# Propionate                                0.0                             0.0
#
#             Lactobacillus  Lachnoclostridium  \
# SCFA
# Acetate               0.0               -0.0
# Butyrate              0.0                0.0
# Propionate            0.0                0.0
#
#             Lachnospiraceae_dash_bacterium_dash_DW59  GCA_dash_900066575
# SCFA
# Acetate                                          0.0                -0.0
# Butyrate                                         0.0                 0.0
# Propionate                                      -0.0                -0.0
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 20.6min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 23.9min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 19.3min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt         30                  5
# 1    Butyrate           200         auto         10                  2
# 2  Propionate           200         sqrt         30                  5
#
#    min_samples_leaf  bootstrap
# 0                 4       True
# 1                 4       True
# 2                 4       True

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Muribaculaceae  Parabacteroides_dash_goldsteinii  \
# 0     Acetate  0.470221        0.022605                          0.015416
# 1    Butyrate  0.685244        0.013541                          0.017253
# 2  Propionate  0.495973        0.024955                          0.019556
#
#    Bacteroides  Faecalibaculum  Lachnospiraceae_dash_NK4A136_dash_group  \
# 0     0.015588        0.011268                                 0.040876
# 1     0.011167        0.010632                                 0.018041
# 2     0.021706        0.025000                                 0.023856
#
#    Bacteroides_dash_acidifaciens  Alloprevotella  Parasutterella  ...  \
# 0                       0.027462        0.023185        0.040874  ...
# 1                       0.007617        0.026290        0.032123  ...
# 2                       0.015931        0.025888        0.036809  ...
#
#    Odoribacter  Roseburia  Desulfovibrio  Tuzzerella  \
# 0     0.026441   0.025383       0.015196    0.021558
# 1     0.000802   0.009891       0.005800    0.003830
# 2     0.020193   0.020633       0.014757    0.019637
#
#    Lachnospiraceae_dash_UCG_dash_006  Helicobacter_dash_mastomyrinus  \
# 0                           0.030825                        0.017640
# 1                           0.035057                        0.010313
# 2                           0.038722                        0.016291
#
#    Lactobacillus  Lachnoclostridium  Lachnospiraceae_dash_bacterium_dash_DW59  \
# 0       0.039597           0.028410                                  0.021967
# 1       0.021713           0.026115                                  0.011990
# 2       0.041587           0.040838                                  0.018292
#
#    GCA_dash_900066575
# 0            0.030248
# 1            0.010367
# 2            0.021024
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40.xlsx')

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA                                 Variable   Pearson
# 0  Acetate                           Muribaculaceae -0.003354
# 1  Acetate         Parabacteroides_dash_goldsteinii -0.015511
# 2  Acetate                              Bacteroides -0.099920
# 3  Acetate                           Faecalibaculum -0.012102
# 4  Acetate  Lachnospiraceae_dash_NK4A136_dash_group -0.020015

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40.xlsx', index_col=0)
df_elasnet.head()
# Out:
#       SCFA                                 Variable  Coefficient
# 0  Acetate                           Muribaculaceae          0.0
# 1  Acetate         Parabacteroides_dash_goldsteinii          0.0
# 2  Acetate                              Bacteroides          0.0
# 3  Acetate                           Faecalibaculum          0.0
# 4  Acetate  Lachnospiraceae_dash_NK4A136_dash_group          0.0

# %%
df_rf = pd.read_excel('rf_importance_top40.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA                                 Variable      Gini
# 0  Acetate                           Muribaculaceae  0.022605
# 1  Acetate         Parabacteroides_dash_goldsteinii  0.015416
# 2  Acetate                              Bacteroides  0.015588
# 3  Acetate                           Faecalibaculum  0.011268
# 4  Acetate  Lachnospiraceae_dash_NK4A136_dash_group  0.040876

# %%
#df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_rf, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA                          Taxon  RandomForest  ElasticNet
# 0  Acetate                 Muribaculaceae      0.022605         0.0
# 1  Acetate    Parabacteroides-goldsteinii      0.015416         0.0
# 2  Acetate                    Bacteroides      0.015588         0.0
# 3  Acetate                 Faecalibaculum      0.011268         0.0
# 4  Acetate  Lachnospiraceae-NK4A136-group      0.040876         0.0

# %%
fig, ax = plt.subplots(figsize=(10, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df.iloc[0:10, :]
     
    # normalize to -1 and 1
    for c in ['ElasticNet','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
