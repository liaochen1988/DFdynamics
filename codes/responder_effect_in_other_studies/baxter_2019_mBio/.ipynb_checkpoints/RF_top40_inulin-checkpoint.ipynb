# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler
from copy import deepcopy
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pprint
from scipy.stats import pearsonr, spearmanr
from scipy import stats
from scipy.interpolate import CubicSpline
import warnings
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score
import scipy.stats.kde as kde

# %% [markdown]
# # Read meta data (inulin)

# %%
df_meta = pd.read_csv('./metadata.txt', sep='\t', index_col=0)
df_meta = df_meta[['Group','Subject_ID','status']]
df_meta = df_meta[df_meta.Group=='inulin']
df_meta['Day'] = [0 if s=='before' else 21 for s in df_meta.status]
df_meta = df_meta.drop(['Group','status'], axis=1)
df_meta.columns = ['Subject','Day']
df_meta.head()
# Out:
#            Subject  Day
# #SampleID
# SRR6444202    U042    0
# SRR6444421    U042    0
# SRR6444927    U042    0
# SRR6444656    U042    0
# SRR6444596    U068    0

# %% [markdown]
# # Read SCFA

# %%
df_scfa = pd.read_csv('./metadata.txt', sep='\t', index_col=0)
df_scfa = df_scfa[['Acetate','Butyrate','Propionate']]
df_scfa = df_scfa.loc[df_meta.index].astype('float64')
df_scfa = df_scfa.loc[df_meta.index]
df_scfa.head()
# Out:
#               Acetate   Butyrate  Propionate
# #SampleID
# SRR6444202  16.920613   4.026742    2.359323
# SRR6444421  61.308286  23.527629   13.471580
# SRR6444927   6.919987   3.764215         NaN
# SRR6444656  42.398850  13.499688   15.648247
# SRR6444596  16.305808   3.409409    2.754982

# %%
df_scfa.corr()
# Out:
#              Acetate  Butyrate  Propionate
# Acetate     1.000000  0.618058    0.348127
# Butyrate    0.618058  1.000000    0.072414
# Propionate  0.348127  0.072414    1.000000

# %% [markdown]
# # Read 16S data (relative abundance)

# %%
df_16S = pd.read_excel('16S_relative_abundance.xlsx', index_col=0)
df_16S = df_16S.loc[df_meta.index]
df_16S.head()
# Out:
#             Absiella-argi  Absiella-dolichum  Acetanaerobacterium  \
# #SampleID
# SRR6444202            0.0                0.0                  0.0
# SRR6444421            0.0                0.0                  0.0
# SRR6444927            0.0                0.0                  0.0
# SRR6444656            0.0                0.0                  0.0
# SRR6444596            0.0                0.0                  0.0
#
#             Acetoanaerobium  Acetobacterium  Acidaminococcus-intestini  \
# #SampleID
# SRR6444202              0.0             0.0                        0.0
# SRR6444421              0.0             0.0                        0.0
# SRR6444927              0.0             0.0                        0.0
# SRR6444656              0.0             0.0                        0.0
# SRR6444596              0.0             0.0                        0.0
#
#             Acidaminococcus-sp.-Marseille-P2828  Acinetobacter  \
# #SampleID
# SRR6444202                                  0.0            0.0
# SRR6444421                                  0.0            0.0
# SRR6444927                                  0.0            0.0
# SRR6444656                                  0.0            0.0
# SRR6444596                                  0.0            0.0
#
#             Actinobacillus  Actinobacteria  ...  human-gut-metagenome  \
# #SampleID                                   ...
# SRR6444202             0.0             0.0  ...              0.002561
# SRR6444421             0.0             0.0  ...              0.000153
# SRR6444927             0.0             0.0  ...              0.001626
# SRR6444656             0.0             0.0  ...              0.000000
# SRR6444596             0.0             0.0  ...              0.007670
#
#             iron-reducing-bacterium-enrichment-culture-clone-HN70  \
# #SampleID
# SRR6444202                                                0.0
# SRR6444421                                                0.0
# SRR6444927                                                0.0
# SRR6444656                                                0.0
# SRR6444596                                                0.0
#
#             marine-group  marine-sediment-metagenome  metagenome  \
# #SampleID
# SRR6444202           0.0                         0.0    0.007456
# SRR6444421           0.0                         0.0    0.009080
# SRR6444927           0.0                         0.0    0.019772
# SRR6444656           0.0                         0.0    0.006894
# SRR6444596           0.0                         0.0    0.008728
#
#             rumen-bacterium-YS2  soil-metagenome  \
# #SampleID
# SRR6444202                  0.0              0.0
# SRR6444421                  0.0              0.0
# SRR6444927                  0.0              0.0
# SRR6444656                  0.0              0.0
# SRR6444596                  0.0              0.0
#
#             swine-fecal-bacterium-SD-Pec5  vadinBE97  wallaby-gut-metagenome
# #SampleID
# SRR6444202                            0.0        0.0                     0.0
# SRR6444421                            0.0        0.0                     0.0
# SRR6444927                            0.0        0.0                     0.0
# SRR6444656                            0.0        0.0                     0.0
# SRR6444596                            0.0        0.0                     0.0
#
# [5 rows x 533 columns]

# %% [markdown]
# # Select the 40 most abundant taxa

# %%
topX = 40
df_16S_T = df_16S.T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#             Bacteroides  Faecalibacterium  Lachnospiraceae  Alistipes  \
# #SampleID
# SRR6444202     0.461741          0.110484         0.090978   0.014837
# SRR6444421     0.450956          0.066613         0.085002   0.017664
# SRR6444927     0.252197          0.113225         0.066872   0.019508
# SRR6444656     0.476149          0.080666         0.054675   0.047702
# SRR6444596     0.053690          0.034382         0.028167   0.000000
#
#             Prevotella  Trichuris-trichiura-(human-whipworm)  Bifidobacterium  \
# #SampleID
# SRR6444202    0.000000                              0.000000         0.000000
# SRR6444421    0.000076                              0.000000         0.002442
# SRR6444927    0.000000                              0.000000         0.011116
# SRR6444656    0.000000                              0.000000         0.000000
# SRR6444596    0.308252                              0.173631         0.002645
#
#             Ruminococcus-sp.-N15.MGS-57  Anaerostipes   Blautia  ...  \
# #SampleID                                                        ...
# SRR6444202                     0.000000      0.002033  0.005272  ...
# SRR6444421                     0.000000      0.000000  0.010988  ...
# SRR6444927                     0.000000      0.009666  0.039851  ...
# SRR6444656                     0.000000      0.001664  0.022821  ...
# SRR6444596                     0.002909      0.000000  0.000000  ...
#
#             Burkholderiales  human-gut-metagenome  Odoribacter  \
# #SampleID
# SRR6444202         0.000000              0.002561     0.000000
# SRR6444421         0.000000              0.000153     0.000000
# SRR6444927         0.000000              0.001626     0.000000
# SRR6444656         0.000000              0.000000     0.000000
# SRR6444596         0.002645              0.007670     0.002909
#
#             Massiliprevotella-massiliensis  Burkholderia-sp.-K4410.MGS-135  \
# #SampleID
# SRR6444202                        0.000000                             0.0
# SRR6444421                        0.000000                             0.0
# SRR6444927                        0.000000                             0.0
# SRR6444656                        0.000000                             0.0
# SRR6444596                        0.031209                             0.0
#
#             [Eubacterium]-hallii-group  Enterobacteriaceae  Incertae-Sedis  \
# #SampleID
# SRR6444202                    0.000000            0.010619        0.001883
# SRR6444421                    0.001183            0.018504        0.002060
# SRR6444927                    0.017399            0.016081        0.038664
# SRR6444656                    0.002377            0.045087        0.006022
# SRR6444596                    0.001587            0.000000        0.001190
#
#             Veillonella  Blautia-faecis
# #SampleID
# SRR6444202     0.011899        0.000904
# SRR6444421     0.022853        0.003472
# SRR6444927     0.001582        0.009007
# SRR6444656     0.000634        0.003011
# SRR6444596     0.000000        0.000000
#
# [5 rows x 40 columns]

# %%
# sample with minimum absolute abundance coverage
(df_16S_topX.sum(axis=1)/df_16S.sum(axis=1)).min()
# Out:
# 0.6095100864553314

# %% [markdown]
# # merge with metadata

# %%
df_scfa_meta = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_scfa_meta = df_scfa_meta.groupby(['Subject','Day']).agg(np.nanmean).reset_index()
df_scfa_meta = df_scfa_meta.dropna()
df_scfa_meta = df_scfa_meta[df_scfa_meta.Subject.isin([s for s in df_scfa_meta.Subject if len(df_scfa_meta[df_scfa_meta.Subject==s])==2])].reset_index(drop=True)
df_scfa_meta.head()
# Out:
#   Subject  Day    Acetate   Butyrate  Propionate
# 0    U042    0  31.886934  11.204569   10.493050
# 1    U042   21  27.338590   7.497514   14.981003
# 2    U068    0  25.031128   7.599457   13.591014
# 3    U068   21  40.560575  10.940386   66.856917
# 4    U076    0  15.924509   2.915037   12.531653

# %%
df_16S_topX_meta = pd.merge(df_meta, df_16S_topX, left_index=True, right_index=True, how='inner')
df_16S_topX_meta = df_16S_topX_meta.groupby(['Subject','Day']).agg(np.nanmean).reset_index()
df_16S_topX_meta = pd.merge(df_16S_topX_meta, df_scfa_meta[['Subject','Day']], left_on=['Subject','Day'], right_on=['Subject','Day'], how='inner').reset_index(drop=True)
df_16S_topX_meta.head()
# Out:
#   Subject  Day  Bacteroides  Faecalibacterium  Lachnospiraceae  Alistipes  \
# 0    U042    0     0.410261          0.092747         0.074382   0.024928
# 1    U042   21     0.434823          0.034236         0.074183   0.035814
# 2    U068    0     0.042076          0.051676         0.039845   0.000134
# 3    U068   21     0.065115          0.085848         0.041233   0.000126
# 4    U076    0     0.511621          0.054229         0.058061   0.015886
#
#    Prevotella  Trichuris-trichiura-(human-whipworm)  Bifidobacterium  \
# 0    0.000019                              0.000000         0.003389
# 1    0.000280                              0.000000         0.006302
# 2    0.302923                              0.163450         0.001381
# 3    0.238497                              0.111047         0.017487
# 4    0.000095                              0.000000         0.009824
#
#    Ruminococcus-sp.-N15.MGS-57  ...  Burkholderiales  human-gut-metagenome  \
# 0                     0.000000  ...         0.000000              0.001085
# 1                     0.000000  ...         0.000000              0.001742
# 2                     0.001922  ...         0.003026              0.006206
# 3                     0.000217  ...         0.002772              0.007607
# 4                     0.000000  ...         0.000000              0.000000
#
#    Odoribacter  Massiliprevotella-massiliensis  \
# 0     0.000000                        0.000000
# 1     0.000000                        0.000000
# 2     0.001967                        0.023828
# 3     0.003200                        0.019303
# 4     0.000000                        0.000000
#
#    Burkholderia-sp.-K4410.MGS-135  [Eubacterium]-hallii-group  \
# 0                        0.000000                    0.005240
# 1                        0.000000                    0.004647
# 2                        0.002627                    0.000731
# 3                        0.005174                    0.004058
# 4                        0.054074                    0.002031
#
#    Enterobacteriaceae  Incertae-Sedis  Veillonella  Blautia-faecis
# 0            0.022573        0.012157     0.009242        0.004098
# 1            0.031276        0.013434     0.002687        0.002629
# 2            0.000067        0.002082     0.000040        0.000000
# 3            0.000000        0.006833     0.000000        0.000961
# 4            0.000173        0.000241     0.000469        0.000300
#
# [5 rows x 42 columns]

# %% [markdown]
# # Calculate derivative

# %%
df_scfa_deriv = deepcopy(df_scfa_meta)
for curr_mice in set(df_scfa_deriv.Subject):
    curr_df = df_scfa_meta[df_scfa_meta.Subject==curr_mice]
    for scfa in ['Acetate','Butyrate','Propionate']:
        xdata = np.array(curr_df['Day'])
        ydata = np.array(curr_df[scfa])
        cs = CubicSpline(xdata, ydata)
        csd1 = cs.derivative(nu=1)
        ydata_d1 = csd1(xdata)
        df_scfa_deriv.loc[df_scfa_deriv.Subject==curr_mice, scfa] = ydata_d1
    
df_scfa_deriv = df_scfa_deriv[['Acetate','Butyrate','Propionate']]
df_scfa_deriv.head()
# Out:
#     Acetate  Butyrate  Propionate
# 0 -0.216588 -0.176526    0.213712
# 1 -0.216588 -0.176526    0.213712
# 2  0.739497  0.159092    2.536472
# 3  0.739497  0.159092    2.536472
# 4  1.014163  0.198236   -0.117343

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
# normalize bacteria data using 
df_16S_topX = df_16S_topX_meta.drop(['Subject','Day'], axis=1)
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX = df_16S_topX/df_16S_topX.max().max()
df_16S_topX.head()
# Out:
#    Bacteroides  Faecalibacterium  Lachnospiraceae  Alistipes  Prevotella  \
# 0     0.463534          0.104790         0.084040   0.028165    0.000022
# 1     0.491286          0.038682         0.083816   0.040465    0.000317
# 2     0.047539          0.058387         0.045019   0.000152    0.342259
# 3     0.073570          0.096995         0.046587   0.000142    0.269467
# 4     0.578057          0.061271         0.065601   0.017949    0.000108
#
#    Trichuris-trichiura-(human-whipworm)  Bifidobacterium  \
# 0                              0.000000         0.003830
# 1                              0.000000         0.007120
# 2                              0.184675         0.001560
# 3                              0.125467         0.019758
# 4                              0.000000         0.011100
#
#    Ruminococcus-sp.-N15.MGS-57  Anaerostipes   Blautia  ...  Burkholderiales  \
# 0                     0.000000      0.003775  0.022295  ...         0.000000
# 1                     0.000000      0.003841  0.026938  ...         0.000000
# 2                     0.002172      0.000305  0.001401  ...         0.003419
# 3                     0.000245      0.002306  0.006313  ...         0.003132
# 4                     0.000000      0.006268  0.008612  ...         0.000000
#
#    human-gut-metagenome  Odoribacter  Massiliprevotella-massiliensis  \
# 0              0.001226     0.000000                        0.000000
# 1              0.001969     0.000000                        0.000000
# 2              0.007012     0.002222                        0.026922
# 3              0.008595     0.003615                        0.021810
# 4              0.000000     0.000000                        0.000000
#
#    Burkholderia-sp.-K4410.MGS-135  [Eubacterium]-hallii-group  \
# 0                        0.000000                    0.005920
# 1                        0.000000                    0.005251
# 2                        0.002968                    0.000826
# 3                        0.005846                    0.004585
# 4                        0.061096                    0.002295
#
#    Enterobacteriaceae  Incertae-Sedis  Veillonella  Blautia-faecis
# 0            0.025504        0.013736     0.010442        0.004631
# 1            0.035337        0.015179     0.003036        0.002970
# 2            0.000076        0.002352     0.000046        0.000000
# 3            0.000000        0.007720     0.000000        0.001086
# 4            0.000196        0.000273     0.000529        0.000339
#
# [5 rows x 40 columns]

# %% [markdown]
# # Simple Correlation

# %%
lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    for t in bacterial_taxa:
        lines.append([scfa,
                     t,
                     pearsonr(df_scfa_deriv[scfa],df_16S_topX[t])[0],
                     spearmanr(df_scfa_deriv[scfa],df_16S_topX[t])[0]]
                    )
df_corr = pd.DataFrame(lines, columns=['SCFA','Variable','Pearson','Spearman'])
df_corr.head()
# Out:
#       SCFA          Variable   Pearson  Spearman
# 0  Acetate       Bacteroides -0.080529  0.044406
# 1  Acetate  Faecalibacterium  0.403350  0.330434
# 2  Acetate   Lachnospiraceae  0.090948  0.076850
# 3  Acetate         Alistipes  0.168943  0.183678
# 4  Acetate        Prevotella -0.170257 -0.089923

# %%
df_corr.to_excel('correlation_top40_inulin.xlsx')

# %% [markdown]
# # Elastic net

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    l1_ratio = [1e-4, .1, .3, .5, .7, .9, .95, .99, 1]
    reg = ElasticNetCV(
        eps=1e-4,
        n_alphas=10000,
        cv=5,
        random_state=0,
        max_iter=100000,
        tol=1e-6,
        l1_ratio=l1_ratio
    ).fit(X, dydt)
    clf = ElasticNet(l1_ratio=reg.l1_ratio_, 
                     alpha=reg.alpha_, 
                     random_state=0,
                     max_iter=100000,
                     tol=1e-6,
                    ).fit(X,dydt)
    rows.append([scfa, reg.alpha_, reg.l1_ratio_, clf.score(X,dydt)]+ list(clf.coef_))
df_elasticnet = pd.DataFrame(rows, columns=['SCFA','BestAlpha','L1Ratio','R2']+list(df_16S_topX.columns)).set_index('SCFA')
#df_elasticnet = df_elasticnet.loc[:, (df_elasticnet != 0).any(axis=0)]
df_elasticnet.head()
# Out:
#             BestAlpha  L1Ratio        R2  Bacteroides  Faecalibacterium  \
# SCFA
# Acetate      0.005799   1.0000  0.166467    -0.205112          4.041133
# Butyrate     0.209000   0.0001  0.010623     0.024223          0.019870
# Propionate   0.051349   0.1000  0.031009    -0.276377          0.134532
#
#             Lachnospiraceae  Alistipes  Prevotella  \
# SCFA
# Acetate            0.000000   0.000000   -0.000000
# Butyrate          -0.001749   0.003125   -0.005833
# Propionate         0.000000  -0.000000    0.062406
#
#             Trichuris-trichiura-(human-whipworm)  Bifidobacterium  ...  \
# SCFA                                                               ...
# Acetate                                -1.005816         0.000000  ...
# Butyrate                               -0.021935        -0.001599  ...
# Propionate                              0.000000        -0.000000  ...
#
#             Burkholderiales  human-gut-metagenome  Odoribacter  \
# SCFA
# Acetate           -0.000000               0.00000    -0.000000
# Butyrate           0.000622              -0.00066    -0.000203
# Propionate         0.000000              -0.00000    -0.000000
#
#             Massiliprevotella-massiliensis  Burkholderia-sp.-K4410.MGS-135  \
# SCFA
# Acetate                           0.000000                             0.0
# Butyrate                         -0.001168                            -0.0
# Propionate                        0.000000                            -0.0
#
#             [Eubacterium]-hallii-group  Enterobacteriaceae  Incertae-Sedis  \
# SCFA
# Acetate                       -0.00000           -0.000000        0.000000
# Butyrate                      -0.00012           -0.001473        0.000036
# Propionate                     0.00000           -0.000000       -0.000000
#
#             Veillonella  Blautia-faecis
# SCFA
# Acetate        0.000000       -0.000000
# Butyrate       0.002321        0.000757
# Propionate    -0.000000       -0.000000
#
# [3 rows x 43 columns]

# %%
df_elasticnet = df_elasticnet.stack().reset_index()
df_elasticnet = df_elasticnet[~df_elasticnet.level_1.isin(['BestAlpha','L1Ratio','R2'])]
df_elasticnet.columns=['SCFA','Variable','Coefficient']
df_elasticnet = df_elasticnet.reset_index(drop=True)
df_elasticnet.to_excel('elasticnet_summary_top40_inulin.xlsx')

# %% [markdown]
# # Random forest regression

# %% [markdown]
# ## parameter optimization

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 30, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

lines = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)

    # grid search
    rf = RandomForestRegressor()
    rf_random = GridSearchCV(
        estimator = rf, 
        param_grid = random_grid, 
        cv = 5, 
        verbose=2, 
        n_jobs = -1)

    # fit the random search model
    rf_random.fit(X, dydt)
    
    # write to table
    lines.append([scfa,
           rf_random.best_params_['n_estimators'],
           rf_random.best_params_['max_features'],
           rf_random.best_params_['max_depth'],
           rf_random.best_params_['min_samples_split'],
           rf_random.best_params_['min_samples_leaf'],
           rf_random.best_params_['bootstrap']
           ])

df_opt_paras = pd.DataFrame(lines, columns=['SCFA','n_estimators','max_features','max_depth','min_samples_split','min_samples_leaf','bootstrap'])
df_opt_paras.head()
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 26.4min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 23.2min finished
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed: 24.0min finished
#          SCFA  n_estimators max_features  max_depth  min_samples_split  \
# 0     Acetate           200         sqrt       20.0                  5
# 1    Butyrate           200         sqrt       20.0                  5
# 2  Propionate           650         sqrt        NaN                  2
#
#    min_samples_leaf  bootstrap
# 0                 4       True
# 1                 2       True
# 2                 4       True

# %%
df_opt_paras.to_excel('optimal_rf_hyperparameters_top40_inulin.xlsx')

# %% [markdown]
# ## run RF using best parameters

# %%
rows = []
for scfa in ['Acetate','Butyrate','Propionate']:
    dydt = np.asarray(list(df_scfa_deriv[scfa]))
    X = np.asarray(df_16S_topX.values)
    regr = RandomForestRegressor(
        random_state=0,
        bootstrap=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'bootstrap'])[0],
        max_depth=None if str(list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0])=='nan' else list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_depth'])[0],
        max_features=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'max_features'])[0],
        min_samples_leaf=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_leaf'])[0],
        min_samples_split=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'min_samples_split'])[0],
        n_estimators=list(df_opt_paras.loc[df_opt_paras.SCFA==scfa,'n_estimators'])[0],
        n_jobs=-1
    )
    clf = regr.fit(X, dydt)
    rows.append([scfa, clf.score(X, dydt)]+ list(clf.feature_importances_))
df_rf = pd.DataFrame(rows, columns=['SCFA','R2']+list(df_16S_topX.columns))
df_rf.head()
# Out:
#          SCFA        R2  Bacteroides  Faecalibacterium  Lachnospiraceae  \
# 0     Acetate  0.708909     0.044817          0.081460         0.021856
# 1    Butyrate  0.822236     0.076144          0.064697         0.022594
# 2  Propionate  0.618553     0.038826          0.049574         0.010306
#
#    Alistipes  Prevotella  Trichuris-trichiura-(human-whipworm)  \
# 0   0.042944    0.022240                              0.022081
# 1   0.025795    0.017910                              0.023048
# 2   0.034611    0.021988                              0.004463
#
#    Bifidobacterium  Ruminococcus-sp.-N15.MGS-57  ...  Burkholderiales  \
# 0         0.045661                     0.014498  ...         0.002186
# 1         0.023230                     0.028751  ...         0.004881
# 2         0.024663                     0.010895  ...         0.079545
#
#    human-gut-metagenome  Odoribacter  Massiliprevotella-massiliensis  \
# 0              0.016902     0.037616                        0.001114
# 1              0.017634     0.019639                        0.004115
# 2              0.016342     0.018213                        0.024787
#
#    Burkholderia-sp.-K4410.MGS-135  [Eubacterium]-hallii-group  \
# 0                        0.004585                    0.014230
# 1                        0.004084                    0.021824
# 2                        0.002208                    0.027549
#
#    Enterobacteriaceae  Incertae-Sedis  Veillonella  Blautia-faecis
# 0            0.016262        0.024546     0.013839        0.009871
# 1            0.017806        0.018843     0.015905        0.025865
# 2            0.072482        0.009797     0.018191        0.017895
#
# [3 rows x 42 columns]

# %%
df_rf = df_rf.set_index('SCFA').stack().reset_index()
df_rf = df_rf[~df_rf.level_1.isin(['R2'])]
df_rf.columns=['SCFA','Variable','Gini']
df_rf = df_rf.reset_index(drop=True)
df_rf.to_excel('rf_importance_top40_inulin.xlsx')

# %% [markdown]
# # Combine results

# %%
df_corr = pd.read_excel('correlation_top40_inulin.xlsx', index_col=0)
df_corr = df_corr.drop('Spearman', axis=1)
df_corr.head()
# Out:
#       SCFA          Variable   Pearson
# 0  Acetate       Bacteroides -0.080529
# 1  Acetate  Faecalibacterium  0.403350
# 2  Acetate   Lachnospiraceae  0.090948
# 3  Acetate         Alistipes  0.168943
# 4  Acetate        Prevotella -0.170257

# %%
df_elasnet = pd.read_excel('elasticnet_summary_top40_inulin.xlsx', index_col=0)
df_elasnet.head()
# Out:
#       SCFA          Variable  Coefficient
# 0  Acetate       Bacteroides    -0.205112
# 1  Acetate  Faecalibacterium     4.041133
# 2  Acetate   Lachnospiraceae     0.000000
# 3  Acetate         Alistipes     0.000000
# 4  Acetate        Prevotella     0.000000

# %%
df_rf = pd.read_excel('rf_importance_top40_inulin.xlsx', index_col=0)
df_rf.head()
# Out:
#       SCFA          Variable      Gini
# 0  Acetate       Bacteroides  0.044817
# 1  Acetate  Faecalibacterium  0.081460
# 2  Acetate   Lachnospiraceae  0.021856
# 3  Acetate         Alistipes  0.042944
# 4  Acetate        Prevotella  0.022240

# %%
df_joined = pd.merge(df_rf, df_corr, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined = pd.merge(df_joined, df_elasnet, left_on=['SCFA','Variable'], right_on=['SCFA','Variable'], how='inner')
df_joined.columns = ['SCFA','Taxon','RandomForest','Pearson','ElasticNet']
df_joined['Taxon'] = [t.replace('_dash_','-').replace('_dot_','.') for t in df_joined['Taxon']]
df_joined.head()
# Out:
#       SCFA             Taxon  RandomForest   Pearson  ElasticNet
# 0  Acetate       Bacteroides      0.044817 -0.080529   -0.205112
# 1  Acetate  Faecalibacterium      0.081460  0.403350    4.041133
# 2  Acetate   Lachnospiraceae      0.021856  0.090948    0.000000
# 3  Acetate         Alistipes      0.042944  0.168943    0.000000
# 4  Acetate        Prevotella      0.022240 -0.170257    0.000000

# %%
df_joined[(df_joined.SCFA=='Propionate') & (df_joined.ElasticNet>0)].sort_values(by='RandomForest', ascending=False)
# Out:
#           SCFA             Taxon  RandomForest   Pearson  ElasticNet
# 81  Propionate  Faecalibacterium      0.049574  0.284249    0.134532
# 84  Propionate        Prevotella      0.021988  0.159418    0.062406

# %%
fig, ax = plt.subplots(figsize=(14, 6), nrows=1, ncols=3, constrained_layout=True, sharex=True)
cbar_ax = fig.add_axes([0.94, .45, .015, .2])
for k,scfa in enumerate(['Acetate','Butyrate','Propionate']):
    curr_df = df_joined[df_joined.SCFA==scfa].set_index('Taxon')
    curr_df = curr_df.drop('SCFA', axis=1)
    curr_df = curr_df.sort_values(by='RandomForest', ascending=False)
    curr_df = curr_df.iloc[0:10, :]
     
    # normalize to -1 and 1
    for c in ['ElasticNet','Pearson','RandomForest']:
        if c!='RandomForest':
            curr_df.loc[curr_df[c]<0,c] = curr_df.loc[curr_df[c]<0,c]/np.abs(curr_df.loc[curr_df[c]<0,c].min())
        curr_df.loc[curr_df[c]>=0,c] = curr_df.loc[curr_df[c]>=0,c]/curr_df.loc[curr_df[c]>=0,c].max()

    # plot    
    _ = sns.heatmap(curr_df.values, ax=ax[k], cmap='RdBu_r', vmin=-1, vmax=1, cbar = False if k!=2 else True, cbar_ax = None if k!=2 else cbar_ax, linewidths=0.25, linecolor='black')
    ax[k].set_xticklabels(['RandomForest','Pearson','ElasticNet'], rotation=90, fontsize=12)
    ax[k].set_title(scfa, fontsize=15)
    ax[k].set_yticklabels(curr_df.index, rotation=0, fontsize=12)
    ax[k].tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()

# %%
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("scfa_producer_top10.pdf", format="pdf")
