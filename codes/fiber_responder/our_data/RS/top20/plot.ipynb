# %%
import pandas as pd
import numpy as np
import arviz as az
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats.kde as kde
import matplotlib.patches as patches
from scipy.stats import norm

# %%
df_qpcr= pd.read_excel('../../../../../data/qPCR.xlsx', index_col=0)
df_meta = pd.read_excel('../../../../../data/meta_data.xlsx', index_col=0)
df_qpcr_meta = pd.merge(df_meta, df_qpcr, left_index=True, right_index=True, how='inner')
df_qpcr_meta.head()
# Out:
#           MiceID   Vendor  Day     Diet         Value
# SampleID
# sample131    BC1  Beijing    0  Control  9.157619e+07
# sample132    BC2  Beijing    0  Control  1.170283e+08
# sample133    BC3  Beijing    0  Control  5.842790e+07
# sample134    BC4  Beijing    0  Control  2.131828e+08
# sample135    BC5  Beijing    0  Control  8.844480e+07

# %%
df_16S_abs = pd.read_excel('../../../../../data/16S_absolute_abundance.xlsx', index_col=0)
df_16S_abs_meta = pd.merge(df_meta, df_16S_abs, left_index=True, right_index=True, how='inner')
df_16S_abs_meta.head()
# Out:
#           MiceID   Vendor  Day     Diet   A2         ASF356  Acetatifactor  \
# SampleID
# sample131    BC1  Beijing    0  Control  0.0  108301.701888    7101.750943
# sample132    BC2  Beijing    0  Control  0.0  405068.034693   50064.588558
# sample133    BC3  Beijing    0  Control  0.0   36169.603950   45332.570284
# sample134    BC4  Beijing    0  Control  0.0  484302.054587   10150.043060
# sample135    BC5  Beijing    0  Control  0.0   91489.970533   42374.302141
#
#            Acetatifactor-muris  Acidovorax  Acinetobacter  ...  \
# SampleID                                                   ...
# sample131                  0.0         0.0            0.0  ...
# sample132                  0.0         0.0            0.0  ...
# sample133                  0.0         0.0            0.0  ...
# sample134                  0.0         0.0            0.0  ...
# sample135                  0.0         0.0            0.0  ...
#
#            [Eubacterium]-ventriosum-group  [Eubacterium]-xylanophilum-group  \
# SampleID
# sample131                             0.0                      63028.039623
# sample132                             0.0                      80103.341692
# sample133                             0.0                          0.000000
# sample134                             0.0                     105850.449056
# sample135                             0.0                          0.000000
#
#            [Ruminococcus]-gnavus-group  [Ruminococcus]-torques-group  \
# SampleID
# sample131                          0.0                           0.0
# sample132                          0.0                           0.0
# sample133                          0.0                           0.0
# sample134                          0.0                           0.0
# sample135                          0.0                           0.0
#
#            bacterium-enrichment-culture-clone-M153  gut-metagenome  \
# SampleID
# sample131                                      0.0   165115.709436
# sample132                                      0.0   106501.033841
# sample133                                      0.0   221840.237562
# sample134                                      0.0   919303.900024
# sample135                                      0.0   581683.602124
#
#            human-gut-metagenome  marine-metagenome  metagenome  \
# SampleID
# sample131                   0.0                0.0         0.0
# sample132                   0.0                0.0         0.0
# sample133                   0.0                0.0         0.0
# sample134                   0.0                0.0         0.0
# sample135                   0.0                0.0         0.0
#
#            mouse-gut-metagenome
# SampleID
# sample131          1.322701e+05
# sample132          1.003112e+06
# sample133          1.866352e+05
# sample134          8.714537e+05
# sample135          5.335310e+05
#
# [5 rows x 308 columns]

# %%
df_16S_rel = pd.read_excel('../../../../../data/16S_relative_abundance.xlsx', index_col=0)
df_16S_rel_meta = pd.merge(df_meta, df_16S_rel, left_index=True, right_index=True, how='inner')
df_16S_rel_meta.head()
# Out:
#           MiceID   Vendor  Day     Diet   A2    ASF356  Acetatifactor  \
# SampleID
# sample131    BC1  Beijing    0  Control  0.0  0.001183       0.000078
# sample132    BC2  Beijing    0  Control  0.0  0.003461       0.000428
# sample133    BC3  Beijing    0  Control  0.0  0.000619       0.000776
# sample134    BC4  Beijing    0  Control  0.0  0.002272       0.000048
# sample135    BC5  Beijing    0  Control  0.0  0.001034       0.000479
#
#            Acetatifactor-muris  Acidovorax  Acinetobacter  ...  \
# SampleID                                                   ...
# sample131                  0.0         0.0            0.0  ...
# sample132                  0.0         0.0            0.0  ...
# sample133                  0.0         0.0            0.0  ...
# sample134                  0.0         0.0            0.0  ...
# sample135                  0.0         0.0            0.0  ...
#
#            [Eubacterium]-ventriosum-group  [Eubacterium]-xylanophilum-group  \
# SampleID
# sample131                             0.0                          0.000688
# sample132                             0.0                          0.000684
# sample133                             0.0                          0.000000
# sample134                             0.0                          0.000497
# sample135                             0.0                          0.000000
#
#            [Ruminococcus]-gnavus-group  [Ruminococcus]-torques-group  \
# SampleID
# sample131                          0.0                           0.0
# sample132                          0.0                           0.0
# sample133                          0.0                           0.0
# sample134                          0.0                           0.0
# sample135                          0.0                           0.0
#
#            bacterium-enrichment-culture-clone-M153  gut-metagenome  \
# SampleID
# sample131                                      0.0        0.001803
# sample132                                      0.0        0.000910
# sample133                                      0.0        0.003797
# sample134                                      0.0        0.004312
# sample135                                      0.0        0.006577
#
#            human-gut-metagenome  marine-metagenome  metagenome  \
# SampleID
# sample131                   0.0                0.0         0.0
# sample132                   0.0                0.0         0.0
# sample133                   0.0                0.0         0.0
# sample134                   0.0                0.0         0.0
# sample135                   0.0                0.0         0.0
#
#            mouse-gut-metagenome
# SampleID
# sample131              0.001444
# sample132              0.008572
# sample133              0.003194
# sample134              0.004088
# sample135              0.006032
#
# [5 rows x 308 columns]

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d.csv"%(i) for i in np.arange(1,4)])
# Out:
# /Users/liaoc/opt/anaconda3/lib/python3.8/site-packages/arviz/data/base.py:148: UserWarning: More chains (3) than draws (0). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# /Users/liaoc/opt/anaconda3/lib/python3.8/site-packages/arviz/data/base.py:148: UserWarning: More chains (3) than draws (0). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(

# %% [markdown]
# # Absolute abundance

# %%
fig, ax = plt.subplots(figsize=(12,4), nrows=2, ncols=4)

inulin_responders = ['Muribaculaceae','Faecalibaculum','Alloprevotella','Desulfovibrionaceae']
for k,c in enumerate(inulin_responders):
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    rect = patches.Rectangle((x0,0),x1-x0,3.2,linewidth=1,edgecolor=None,facecolor='lightgray',alpha=0.3)
    _ = ax[0,k].add_patch(rect)
    ax[0,k].hist(data, bins=50, density=True, color='skyblue')
    ax[0,k].plot([0,0],[0,3.2],'k--')
    ax[0,k].set_title(c)
    ax[0,k].set_ylim([0,3.2])
    ax[0,k].set_xlim([-1,2])
    
df_16S_abs_meta = df_16S_abs_meta[(df_16S_abs_meta.Diet=='Inulin') & (df_16S_abs_meta.Vendor!='Beijing')]
for k,c in enumerate(inulin_responders):
    sns.lineplot(x='Day',y=c.replace('_dash_','-'), marker='o', hue='Vendor', ci=68, data=df_16S_abs_meta, ax=ax[1,k])
    ax[1,k].set_yscale(('log'))
    ax[1,k].set_xlim([-1,32])
    ax[1,k].set_ylim([1e3,1e9])

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("bayesian_inference_rs_responder_abs.svg", format="svg")

# %% [markdown]
# # Relative abundance

# %%
fig, ax = plt.subplots(figsize=(12,4), nrows=2, ncols=4)

inulin_responders = ['Muribaculaceae','Faecalibaculum','Alloprevotella','Desulfovibrionaceae']
for k,c in enumerate(inulin_responders):
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    rect = patches.Rectangle((x0,0),x1-x0,3.2,linewidth=1,edgecolor=None,facecolor='lightgray',alpha=0.3)
    _ = ax[0,k].add_patch(rect)
    ax[0,k].hist(data, bins=50, density=True, color='skyblue')
    ax[0,k].plot([0,0],[0,3.2],'k--')
    ax[0,k].set_title(c)
    ax[0,k].set_ylim([0,3.2])
    ax[0,k].set_xlim([-1,2])
    
df_16S_rel_meta = df_16S_rel_meta[(df_16S_rel_meta.Diet=='Inulin') & (df_16S_rel_meta.Vendor!='Beijing')]
for k,c in enumerate(inulin_responders):
    sns.lineplot(x='Day',y=c.replace('_dash_','-'), marker='o', hue='Vendor', ci=68, data=df_16S_rel_meta, ax=ax[1,k])
    ax[1,k].set_xlim([-1,32])
    ax[1,k].set_ylim([1e-5,2])
    ax[1,k].set_yscale('log')

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("bayesian_inference_rs_responder_rel.svg", format="svg")

# %% [markdown]
# # qPCR

# %%
fig, ax = plt.subplots(figsize=(5,4), nrows=1, ncols=1)
curr_df = df_qpcr_meta[(df_qpcr_meta.Diet=='Resistant starch') & (df_qpcr_meta.Vendor!='Beijing')]
sns.lineplot(x='Day',y='Value', marker='o', hue='Vendor', ci=68, data=curr_df, ax=ax)
ax.set_yscale(('log'))
_ = ax.set_ylim([4e7,1e9])
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("qpcr_vendor_time_series.svg", format="svg")

# %% [markdown]
# # Plot posterior distribution

# %%
df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True].reset_index(drop=True)

fig, ax = plt.subplots(figsize=(3,10), nrows=len(df_stan_output_summary.index), ncols=1, sharex=True)

for idx in df_stan_output_summary.index:
    _type = df_stan_output_summary.loc[idx,'Type']
    _taxa = df_stan_output_summary.loc[idx,'Taxa']
    _left = df_stan_output_summary.loc[idx,'Left']
    _middle = df_stan_output_summary.loc[idx,'Middle']
    _right = df_stan_output_summary.loc[idx,'Right']
    if _type == 'rs_response':
        var = 'epsilon__%s'%(_taxa)
    if _type == 'pairwise_interaction':
        var = 'beta__%s_%s'%(eval(_taxa)[0],eval(_taxa)[1])
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    mean,std=norm.fit(data)
    x = np.linspace(-8, 5, 100)
    y = norm.pdf(x, mean, std)
    ax[idx].plot(x,y)
    ax[idx].plot([_left,_left],[0,np.max(y)], 'k--')
    ax[idx].plot([_right,_right],[0,np.max(y)], 'k--')
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("bayesian_inference_gLV.svg", format="svg")
