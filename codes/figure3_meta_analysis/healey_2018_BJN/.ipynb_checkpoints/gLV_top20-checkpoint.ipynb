# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.interpolate import CubicSpline
from sklearn.metrics import mean_squared_error
import warnings
import itertools
warnings.filterwarnings("ignore")
import arviz as az
import scipy
import matplotlib.patches as patches
import statsmodels.stats.api as sms
import scipy.stats.kde as kde

# %% [markdown]
# # Read 16S data

# %%
df_16S = pd.read_excel('./16S_relative_abundance.xlsx', index_col=0)
df_16S.columns = [c.replace('/','_slash_').replace(' ','_space_').replace('[','_leftsquarebracket_').replace(']','_rightsquarebracket_').replace('-','_dash_').replace('.','_dot_').replace('(','_leftroundbracket').replace(')','_rightroundbracket_') for c in df_16S.columns]
df_16S.head()
# Out:
#             Abiotrophia  Acetanaerobacterium  Acidaminococcus  \
# SampleID
# SRR6185161          0.0                  0.0         0.004546
# SRR6185162          0.0                  0.0         0.000000
# SRR6185163          0.0                  0.0         0.000000
# SRR6185164          0.0                  0.0         0.000000
# SRR6185165          0.0                  0.0         0.000000
#
#             Actinidia_dash_chinensis  Actinomyces  \
# SampleID
# SRR6185161                       0.0     0.000000
# SRR6185162                       0.0     0.000000
# SRR6185163                       0.0     0.000000
# SRR6185164                       0.0     0.000114
# SRR6185165                       0.0     0.000000
#
#             Actinomyces_dash_massiliensis  Adlercreutzia  Agathobacter  \
# SampleID
# SRR6185161                            0.0            0.0      0.013533
# SRR6185162                            0.0            0.0      0.001597
# SRR6185163                            0.0            0.0      0.018110
# SRR6185164                            0.0            0.0      0.002307
# SRR6185165                            0.0            0.0      0.052867
#
#             Akkermansia  Akkermansia_dash_muciniphila  ...  \
# SampleID                                               ...
# SRR6185161     0.002041                           0.0  ...
# SRR6185162     0.000000                           0.0  ...
# SRR6185163     0.000000                           0.0  ...
# SRR6185164     0.000000                           0.0  ...
# SRR6185165     0.000000                           0.0  ...
#
#             _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# SRR6185161                                           0.003009
# SRR6185162                                           0.002067
# SRR6185163                                           0.007531
# SRR6185164                                           0.000773
# SRR6185165                                           0.020375
#
#             bacterium_dash_YE57  \
# SampleID
# SRR6185161                  0.0
# SRR6185162                  0.0
# SRR6185163                  0.0
# SRR6185164                  0.0
# SRR6185165                  0.0
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_BBMC_dash_9  \
# SampleID
# SRR6185161                                                0.0
# SRR6185162                                                0.0
# SRR6185163                                                0.0
# SRR6185164                                                0.0
# SRR6185165                                                0.0
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_Ecwsrb026  \
# SampleID
# SRR6185161                                           0.000000
# SRR6185162                                           0.000000
# SRR6185163                                           0.000000
# SRR6185164                                           0.000177
# SRR6185165                                           0.000220
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_RB7c  \
# SampleID
# SRR6185161                                                0.0
# SRR6185162                                                0.0
# SRR6185163                                                0.0
# SRR6185164                                                0.0
# SRR6185165                                                0.0
#
#             butyrate_dash_producing_dash_bacterium_dash_L2_dash_10  \
# SampleID
# SRR6185161                                                0.0
# SRR6185162                                                0.0
# SRR6185163                                                0.0
# SRR6185164                                                0.0
# SRR6185165                                                0.0
#
#             gut_dash_metagenome  human_dash_gut_dash_metagenome  metagenome  \
# SampleID
# SRR6185161             0.003486                        0.000066    0.004507
# SRR6185162             0.001174                        0.000869    0.034805
# SRR6185163             0.005917                        0.000000    0.026358
# SRR6185164             0.008329                        0.000254    0.034066
# SRR6185165             0.002736                        0.000000    0.083844
#
#             vadinBE97
# SampleID
# SRR6185161        0.0
# SRR6185162        0.0
# SRR6185163        0.0
# SRR6185164        0.0
# SRR6185165        0.0
#
# [5 rows x 469 columns]

# %% [markdown]
# # Add pseudocount for zeros

# %%
for sample_id in df_16S.index:
    sample = np.array(df_16S.loc[sample_id])
    minval = np.min(sample[np.nonzero(sample)]) # minimum non-zero value
    sample[sample==0] = minval
    df_16S.loc[sample_id] = sample
df_16S.head()
# Out:
#             Abiotrophia  Acetanaerobacterium  Acidaminococcus  \
# SampleID
# SRR6185161     0.000013             0.000013         0.004546
# SRR6185162     0.000117             0.000117         0.000117
# SRR6185163     0.000717             0.000717         0.000717
# SRR6185164     0.000025             0.000025         0.000025
# SRR6185165     0.000073             0.000073         0.000073
#
#             Actinidia_dash_chinensis  Actinomyces  \
# SampleID
# SRR6185161                  0.000013     0.000013
# SRR6185162                  0.000117     0.000117
# SRR6185163                  0.000717     0.000717
# SRR6185164                  0.000025     0.000114
# SRR6185165                  0.000073     0.000073
#
#             Actinomyces_dash_massiliensis  Adlercreutzia  Agathobacter  \
# SampleID
# SRR6185161                       0.000013       0.000013      0.013533
# SRR6185162                       0.000117       0.000117      0.001597
# SRR6185163                       0.000717       0.000717      0.018110
# SRR6185164                       0.000025       0.000025      0.002307
# SRR6185165                       0.000073       0.000073      0.052867
#
#             Akkermansia  Akkermansia_dash_muciniphila  ...  \
# SampleID                                               ...
# SRR6185161     0.002041                      0.000013  ...
# SRR6185162     0.000117                      0.000117  ...
# SRR6185163     0.000717                      0.000717  ...
# SRR6185164     0.000025                      0.000025  ...
# SRR6185165     0.000073                      0.000073  ...
#
#             _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group  \
# SampleID
# SRR6185161                                           0.003009
# SRR6185162                                           0.002067
# SRR6185163                                           0.007531
# SRR6185164                                           0.000773
# SRR6185165                                           0.020375
#
#             bacterium_dash_YE57  \
# SampleID
# SRR6185161             0.000013
# SRR6185162             0.000117
# SRR6185163             0.000717
# SRR6185164             0.000025
# SRR6185165             0.000073
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_BBMC_dash_9  \
# SampleID
# SRR6185161                                           0.000013
# SRR6185162                                           0.000117
# SRR6185163                                           0.000717
# SRR6185164                                           0.000025
# SRR6185165                                           0.000073
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_Ecwsrb026  \
# SampleID
# SRR6185161                                           0.000013
# SRR6185162                                           0.000117
# SRR6185163                                           0.000717
# SRR6185164                                           0.000177
# SRR6185165                                           0.000220
#
#             bacterium_dash_enrichment_dash_culture_dash_clone_dash_RB7c  \
# SampleID
# SRR6185161                                           0.000013
# SRR6185162                                           0.000117
# SRR6185163                                           0.000717
# SRR6185164                                           0.000025
# SRR6185165                                           0.000073
#
#             butyrate_dash_producing_dash_bacterium_dash_L2_dash_10  \
# SampleID
# SRR6185161                                           0.000013
# SRR6185162                                           0.000117
# SRR6185163                                           0.000717
# SRR6185164                                           0.000025
# SRR6185165                                           0.000073
#
#             gut_dash_metagenome  human_dash_gut_dash_metagenome  metagenome  \
# SampleID
# SRR6185161             0.003486                        0.000066    0.004507
# SRR6185162             0.001174                        0.000869    0.034805
# SRR6185163             0.005917                        0.000717    0.026358
# SRR6185164             0.008329                        0.000254    0.034066
# SRR6185165             0.002736                        0.000073    0.083844
#
#             vadinBE97
# SampleID
# SRR6185161   0.000013
# SRR6185162   0.000117
# SRR6185163   0.000717
# SRR6185164   0.000025
# SRR6185165   0.000073
#
# [5 rows x 469 columns]

# %% [markdown]
# # Read metadata for inulin and control

# %%
df_meta = pd.read_csv('metadata.txt', sep='\t', index_col=0)
df_meta = df_meta[['Group','Subject_ID','status','dose']]
df_meta['Day'] = [0 if s=='pre' else 21 for s in df_meta.status]
df_meta['Diet'] = [1 if g=='Prebiotic' else 0 for g in df_meta['Group']]
df_meta.head()
# Out:
#                 Group Subject_ID status  dose  Day
# #SampleID
# SRR6185259  Prebiotic    ADAPT03   post    16   21
# SRR6185177    Placebo    ADAPT03   post    16   21
# SRR6185262    Placebo    ADAPT04   post    16   21
# SRR6185178  Prebiotic    ADAPT04   post    16   21
# SRR6185264    Placebo    ADAPT06   post    16   21

# %% [markdown]
# # Select the 20 most abundant taxa

# %%
topX = 20
df_16S_T = df_16S.loc[df_meta.index].T
df_16S_T['mean'] = df_16S_T.mean(axis=1)
df_16S_T = df_16S_T.sort_values(by=['mean'],axis=0,ascending=False)
df_16S_T = df_16S_T.drop('mean', axis=1)
df_16S_topX = df_16S_T.iloc[0:topX].T
df_16S_topX.head()
# Out:
#              Blautia  Faecalibacterium  Bifidobacterium  metagenome  \
# #SampleID
# SRR6185224  0.094739          0.034865         0.003189    0.044047
# SRR6185259  0.066649          0.040161         0.101466    0.069750
# SRR6185212  0.068807          0.015762         0.012607    0.049940
# SRR6185177  0.060489          0.044513         0.003528    0.050959
# SRR6185278  0.164667          0.074385         0.004485    0.039542
#
#             Anaerostipes  Agathobacter  Prevotella  Subdoligranulum  \
# #SampleID
# SRR6185224      0.025218      0.007017    0.000326         0.039055
# SRR6185259      0.076858      0.008313    0.000033         0.049645
# SRR6185212      0.020162      0.000855    0.000025         0.065287
# SRR6185177      0.019494      0.001221    0.000155         0.060468
# SRR6185278      0.027734      0.083783    0.000041         0.039328
#
#             Bacteroides  Fusicatenibacter  \
# #SampleID
# SRR6185224     0.037309          0.004085
# SRR6185259     0.030776          0.025531
# SRR6185212     0.012306          0.020250
# SRR6185177     0.016390          0.034870
# SRR6185278     0.037355          0.035342
#
#             Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# #SampleID
# SRR6185224                                           0.000047
# SRR6185259                                           0.000033
# SRR6185212                                           0.000025
# SRR6185177                                           0.000031
# SRR6185278                                           0.134308
#
#             Christensenellaceae_dash_R_dash_7_dash_group  \
# #SampleID
# SRR6185224                                      0.062539
# SRR6185259                                      0.051409
# SRR6185212                                      0.086455
# SRR6185177                                      0.079993
# SRR6185278                                      0.023239
#
#             _leftsquarebracket_Eubacterium_rightsquarebracket__dash_hallii_dash_group  \
# #SampleID
# SRR6185224                                           0.029233
# SRR6185259                                           0.042289
# SRR6185212                                           0.047375
# SRR6185177                                           0.059433
# SRR6185278                                           0.019161
#
#             Coprococcus     Dorea  UCG_dash_002  Lachnospiraceae  \
# #SampleID
# SRR6185224     0.012754  0.013441      0.014570         0.029559
# SRR6185259     0.014102  0.014662      0.007208         0.014679
# SRR6185212     0.009842  0.012318      0.017246         0.039318
# SRR6185177     0.007729  0.005691      0.013896         0.030896
# SRR6185278     0.051655  0.014096      0.005390         0.005055
#
#             gut_dash_metagenome  Clostridia_dash_UCG_dash_014  \
# #SampleID
# SRR6185224             0.038717                      0.034097
# SRR6185259             0.021788                      0.018819
# SRR6185212             0.031864                      0.060234
# SRR6185177             0.042888                      0.032914
# SRR6185278             0.001688                      0.004739
#
#             _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group
# #SampleID
# SRR6185224                                           0.030629
# SRR6185259                                           0.023107
# SRR6185212                                           0.015071
# SRR6185177                                           0.023953
# SRR6185278                                           0.000203

# %%
list(df_16S_topX.columns)
# Out:
# ['Blautia',
#  'Faecalibacterium',
#  'Bifidobacterium',
#  'metagenome',
#  'Anaerostipes',
#  'Agathobacter',
#  'Prevotella',
#  'Subdoligranulum',
#  'Bacteroides',
#  'Fusicatenibacter',
#  'Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57',
#  'Christensenellaceae_dash_R_dash_7_dash_group',
#  '_leftsquarebracket_Eubacterium_rightsquarebracket__dash_hallii_dash_group',
#  'Coprococcus',
#  'Dorea',
#  'UCG_dash_002',
#  'Lachnospiraceae',
#  'gut_dash_metagenome',
#  'Clostridia_dash_UCG_dash_014',
#  '_leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group']

# %% [markdown]
# # Normalize max value of 16S data to 1

# %%
bacterial_taxa = list(df_16S_topX.columns)
df_16S_topX_w_meta = pd.merge(df_meta, df_16S_topX/df_16S_topX.max().max(), left_index=True, right_index=True, how='inner')
df_16S_topX_w_meta.head()
# Out:
#                 Group Subject_ID status  Day  Diet   Blautia  \
# #SampleID
# SRR6185224  Prebiotic    ADAPT03    pre    0     1  0.147887
# SRR6185259  Prebiotic    ADAPT03   post   21     1  0.104039
# SRR6185212    Placebo    ADAPT03    pre    0     0  0.107408
# SRR6185177    Placebo    ADAPT03   post   21     0  0.094423
# SRR6185278    Placebo    ADAPT04    pre    0     0  0.257045
#
#             Faecalibacterium  Bifidobacterium  metagenome  Anaerostipes  ...  \
# #SampleID                                                                ...
# SRR6185224          0.054425         0.004977    0.068757      0.039365  ...
# SRR6185259          0.062691         0.158389    0.108880      0.119976  ...
# SRR6185212          0.024605         0.019680    0.077956      0.031473  ...
# SRR6185177          0.069485         0.005508    0.079547      0.030430  ...
# SRR6185278          0.116115         0.007001    0.061725      0.043293  ...
#
#             Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# #SampleID
# SRR6185224                                           0.000073
# SRR6185259                                           0.000051
# SRR6185212                                           0.000039
# SRR6185177                                           0.000048
# SRR6185278                                           0.209656
#
#             Christensenellaceae_dash_R_dash_7_dash_group  \
# #SampleID
# SRR6185224                                      0.097623
# SRR6185259                                      0.080250
# SRR6185212                                      0.134956
# SRR6185177                                      0.124869
# SRR6185278                                      0.036276
#
#             _leftsquarebracket_Eubacterium_rightsquarebracket__dash_hallii_dash_group  \
# #SampleID
# SRR6185224                                           0.045632
# SRR6185259                                           0.066013
# SRR6185212                                           0.073953
# SRR6185177                                           0.092776
# SRR6185278                                           0.029910
#
#             Coprococcus     Dorea  UCG_dash_002  Lachnospiraceae  \
# #SampleID
# SRR6185224     0.019910  0.020981      0.022744         0.046141
# SRR6185259     0.022013  0.022888      0.011251         0.022914
# SRR6185212     0.015364  0.019229      0.026921         0.061376
# SRR6185177     0.012065  0.008883      0.021692         0.048229
# SRR6185278     0.080633  0.022004      0.008414         0.007890
#
#             gut_dash_metagenome  Clostridia_dash_UCG_dash_014  \
# #SampleID
# SRR6185224             0.060437                      0.053226
# SRR6185259             0.034010                      0.029376
# SRR6185212             0.049740                      0.094026
# SRR6185177             0.066949                      0.051379
# SRR6185278             0.002635                      0.007398
#
#             _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group
# #SampleID
# SRR6185224                                           0.047812
# SRR6185259                                           0.036070
# SRR6185212                                           0.023526
# SRR6185177                                           0.037391
# SRR6185278                                           0.000318
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate log-derivatives (dlog(B)/dt)

# %%
df_deriv = deepcopy(df_16S_topX_w_meta)
for curr_sub in set(df_deriv.Subject_ID):
    for group in ['Prebiotic','Placebo']:
        curr_df = df_deriv[(df_deriv.Subject_ID==curr_sub) & (df_deriv.Group==group)].sort_values(by='Day')
        if len(curr_df.index) == 0:
            continue
        for taxon in bacterial_taxa:
            xdata = np.array(curr_df['Day'])
            ydata = np.array(curr_df[taxon])
            cs = CubicSpline(xdata, ydata)
            csd1 = cs.derivative(nu=1)
            ydata_d1 = csd1(xdata)
            df_deriv.loc[(df_deriv.Subject_ID==curr_sub)&(df_deriv.Group==group), taxon] = ydata_d1
df_deriv.head()
# Out:
#                 Group Subject_ID status  Day  Diet   Blautia  \
# #SampleID
# SRR6185224  Prebiotic    ADAPT03    pre    0     1 -0.002088
# SRR6185259  Prebiotic    ADAPT03   post   21     1 -0.002088
# SRR6185212    Placebo    ADAPT03    pre    0     0 -0.000618
# SRR6185177    Placebo    ADAPT03   post   21     0 -0.000618
# SRR6185278    Placebo    ADAPT04    pre    0     0 -0.002717
#
#             Faecalibacterium  Bifidobacterium  metagenome  Anaerostipes  ...  \
# #SampleID                                                                ...
# SRR6185224          0.000394         0.007305    0.001911      0.003839  ...
# SRR6185259          0.000394         0.007305    0.001911      0.003839  ...
# SRR6185212          0.002137        -0.000675    0.000076     -0.000050  ...
# SRR6185177          0.002137        -0.000675    0.000076     -0.000050  ...
# SRR6185278          0.000875         0.002291   -0.001571      0.001320  ...
#
#             Ruminococcus_dash_sp_dot__dash_N15_dot_MGS_dash_57  \
# #SampleID
# SRR6185224                                      -1.008151e-06
# SRR6185259                                      -1.008151e-06
# SRR6185212                                       4.386858e-07
# SRR6185177                                       4.386858e-07
# SRR6185278                                      -2.784231e-03
#
#             Christensenellaceae_dash_R_dash_7_dash_group  \
# #SampleID
# SRR6185224                                     -0.000827
# SRR6185259                                     -0.000827
# SRR6185212                                     -0.000480
# SRR6185177                                     -0.000480
# SRR6185278                                     -0.001420
#
#             _leftsquarebracket_Eubacterium_rightsquarebracket__dash_hallii_dash_group  \
# #SampleID
# SRR6185224                                           0.000970
# SRR6185259                                           0.000970
# SRR6185212                                           0.000896
# SRR6185177                                           0.000896
# SRR6185278                                           0.000243
#
#             Coprococcus     Dorea  UCG_dash_002  Lachnospiraceae  \
# #SampleID
# SRR6185224     0.000100  0.000091     -0.000547        -0.001106
# SRR6185259     0.000100  0.000091     -0.000547        -0.001106
# SRR6185212    -0.000157 -0.000493     -0.000249        -0.000626
# SRR6185177    -0.000157 -0.000493     -0.000249        -0.000626
# SRR6185278    -0.002790 -0.000377      0.000395         0.000018
#
#             gut_dash_metagenome  Clostridia_dash_UCG_dash_014  \
# #SampleID
# SRR6185224            -0.001258                     -0.001136
# SRR6185259            -0.001258                     -0.001136
# SRR6185212             0.000819                     -0.002031
# SRR6185177             0.000819                     -0.002031
# SRR6185278             0.000273                     -0.000346
#
#             _leftsquarebracket_Ruminococcus_rightsquarebracket__dash_torques_dash_group
# #SampleID
# SRR6185224                                          -0.000559
# SRR6185259                                          -0.000559
# SRR6185212                                           0.000660
# SRR6185177                                           0.000660
# SRR6185278                                           0.000003
#
# [5 rows x 25 columns]

# %% [markdown]
# # Construct regression matrix

# %%
# Ymat should be samples by bacteria
Ymat = df_deriv[bacterial_taxa].values
Ymat = Ymat.flatten(order='F')
Ymat = StandardScaler().fit_transform(Ymat.reshape(-1,1)).reshape(1,-1)[0] # standardize
Ymat
# Out:
# array([-0.87410934, -0.87410934, -0.28067247, ..., -0.14311646,
#        -0.31333864, -0.31333864])

# %%
len(Ymat)
# Out:
# 2680

# %%
Xmat = np.zeros(shape=(topX*len(df_deriv.index), (topX+2)*topX))
for k in np.arange(topX):
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)] = 1
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+1] = df_deriv.Diet.values
    Xmat[k*len(df_deriv.index):(k+1)*len(df_deriv.index),k*(topX+2)+2:(k+1)*(topX+2)] = df_16S_topX_w_meta[bacterial_taxa].values
Xmat
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 1.47887459e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 1.04039337e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 1.07407674e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.46143086e-02, 1.27524508e-04, 1.50989017e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.81549771e-02, 4.20851676e-05, 1.93802197e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         5.44162667e-03, 2.06905957e-05, 4.69676522e-03]])

# %% [markdown]
# # Write stan program

# %% [markdown]
# ## write data

# %%
json_str = '{\n"N" : %d,\n'%(len(Ymat))

# y variable
json_str += '\"dlogX\" : [%s],\n'%(','.join(list(Ymat.astype(str))))

# x variable
for k1,c1 in enumerate(bacterial_taxa):
    # growth rate
    json_str += '\"growth_rate_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)].astype(str))))
    # diet response
    json_str += '\"inulin_response_%s\" : [%s],\n'%(c1,','.join(list(Xmat[:,k1*(topX+2)+1].astype(str))))
    # bacterial interactions
    for k2,c2 in enumerate(bacterial_taxa):
        v = list(Xmat[:,k1*(topX+2)+2+k2].astype(str))
        json_str += '\"pairwise_interaction_%s_%s\" : [%s]'%(c1,c2,','.join(v))
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            json_str += '\n}'
        else:
            json_str += ',\n'
#print(json_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.data.json", "w")
text_file.write("%s" % json_str)
text_file.close()

# %% [markdown]
# ## write model

# %%
# data block
model_str = 'data {\n'
model_str += '\tint<lower=0> N;\n'
model_str += '\tvector[N] dlogX;\n'
for c1 in bacterial_taxa:
    model_str += '\tvector[N] growth_rate_%s;\n'%(c1)
    model_str += '\tvector[N] inulin_response_%s;\n'%(c1)
    for c2 in bacterial_taxa:
        model_str += '\tvector[N] pairwise_interaction_%s_%s;\n'%(c1,c2)
model_str += '}\n'

# parameter block
model_str += 'parameters {\n\treal<lower=0,upper=1> sigma;\n'
for c1 in bacterial_taxa:
    model_str += '\treal alpha__%s;\n'%(c1) # growth rate
    model_str += '\treal epsilon__%s;\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\treal beta__%s_%s;\n'%(c1,c2)
model_str += '}\n'       
        
# model block
model_str += 'model {\n\tsigma ~ uniform(0,1);\n'
for c1 in bacterial_taxa:
    model_str += '\talpha__%s ~ normal(0,1);\n'%(c1) # growth rate
    model_str += '\tepsilon__%s ~ normal(0,1);\n'%(c1) # inulin response
    for c2 in bacterial_taxa:
        model_str += '\tbeta__%s_%s ~ normal(0,1);\n'%(c1,c2)
model_str += '\tdlogX ~ normal('
for c1 in bacterial_taxa:
    model_str += 'alpha__%s*growth_rate_%s+'%(c1,c1) # growth rate
    model_str += 'epsilon__%s*inulin_response_%s+'%(c1,c1) # inulin response
    for c2 in bacterial_taxa:
        if c1 == bacterial_taxa[-1] and c2 == bacterial_taxa[-1]:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s'%(c1,c2,c1,c2)
        else:
            model_str += 'beta__%s_%s*pairwise_interaction_%s_%s+'%(c1,c2,c1,c2)
model_str += ', sigma);\n}'
#print(model_str)

text_file = open("/Users/liaoc/Documents/cmdstan-2.24.1/examples/mice_scfa/mice_scfa.stan", "w")
text_file.write("%s" % model_str)
text_file.close()

# %% [markdown]
# # Plot stan output

# %%
def hpd_grid(sample, alpha=0.05, roundto=2):
    """Calculate highest posterior density (HPD) of array for given alpha. 
    The HPD is the minimum width Bayesian credible interval (BCI). 
    The function works for multimodal distributions, returning more than one mode
    Parameters
    ----------
    
    sample : Numpy array or python list
        An array containing MCMC samples
    alpha : float
        Desired probability of type I error (defaults to 0.05)
    roundto: integer
        Number of digits after the decimal point for the results
    Returns
    ----------
    hpd: array with the lower 
          
    """
    sample = np.asarray(sample)
    sample = sample[~np.isnan(sample)]
    # get upper and lower bounds
    l = np.min(sample)
    u = np.max(sample)
    density = kde.gaussian_kde(sample)
    x = np.linspace(l, u, 2000)
    y = density.evaluate(x)
    #y = density.evaluate(x, l, u) waitting for PR to be accepted
    xy_zipped = zip(x, y/np.sum(y))
    xy = sorted(xy_zipped, key=lambda x: x[1], reverse=True)
    xy_cum_sum = 0
    hdv = []
    for val in xy:
        xy_cum_sum += val[1]
        hdv.append(val[0])
        if xy_cum_sum >= (1-alpha):
            break
    hdv.sort()
    diff = (u-l)/20  # differences of 5%
    hpd = []
    hpd.append(round(min(hdv), roundto))
    for i in range(1, len(hdv)):
        if hdv[i]-hdv[i-1] >= diff:
            hpd.append(round(hdv[i-1], roundto))
            hpd.append(round(hdv[i], roundto))
    hpd.append(round(max(hdv), roundto))
    ite = iter(hpd)
    hpd = list(zip(ite, ite))
    modes = []
    for value in hpd:
        x_hpd = x[(x > value[0]) & (x < value[1])]
        y_hpd = y[(x > value[0]) & (x < value[1])]
        modes.append(round(x_hpd[np.argmax(y_hpd)], roundto))
    return hpd, x, y, modes

# %%
fit = az.from_cmdstan(["output_%d.csv"%(i) for i in np.arange(1,4)])

# %%
lines = []
    
# basal growth rate
for c in bacterial_taxa:
    var = 'alpha__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['basal_growth_rate', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
# inulin response
for c in bacterial_taxa:
    var = 'epsilon__%s'%(c)
    data = []
    for i in np.arange(0,3):
        data.extend(list(fit.posterior[var][i].values))
    hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
    assert len(hpd_mu) == 1
    (x0, x1) = hpd_mu[0]
    lines.append(['inulin_response', c, x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])

# pairwise interactions
for c1 in bacterial_taxa:
    for c2 in bacterial_taxa:
        var = 'beta__%s_%s'%(c1,c2)
        data = []
        for i in np.arange(0,3):
            data.extend(list(fit.posterior[var][i].values))
        hpd_mu, x_mu, y_mu, modes_mu = hpd_grid(data)
        assert len(hpd_mu) == 1
        (x0, x1) = hpd_mu[0]
        lines.append(['pairwise_interaction', (c1,c2), x0, x1, (x0+x1)/2, np.mean(data)/np.std(data), x0*x1>0])
    
df_stan_output_summary = pd.DataFrame(lines, columns = ['Type','Taxa','Left','Right','Middle','SNR','Significant'])
df_stan_output_summary.head()
# Out:
#                 Type                           Taxa  Left  Right  Middle  \
# 0  basal_growth_rate                 Muribaculaceae -0.16   0.15  -0.005
# 1  basal_growth_rate  Bacteroides_dash_acidifaciens -0.01   0.30   0.145
# 2  basal_growth_rate   Akkermansia_dash_muciniphila -0.27   0.04  -0.115
# 3  basal_growth_rate                 Faecalibaculum -0.20   0.12  -0.040
# 4  basal_growth_rate                 Parasutterella -0.20   0.12  -0.040
#
#         SNR  Significant
# 0 -0.044859        False
# 1  1.835619        False
# 2 -1.416896        False
# 3 -0.531562        False
# 4 -0.540205        False

# %%
df_stan_output_summary.to_excel('bayesian_regression_summary_top20.xlsx')

# %% [markdown]
# # Plot

# %%
df_stan_output_summary = pd.read_excel('bayesian_regression_summary_top20.xlsx', index_col=0)
df_stan_output_summary = df_stan_output_summary[df_stan_output_summary.Significant==True]
df_stan_output_summary
# Out:
#                      Type                                    Taxa  Left  \
# 6       basal_growth_rate                              Prevotella -0.99
# 22        inulin_response                         Bifidobacterium  1.57
# 24        inulin_response                            Anaerostipes  0.94
# 26        inulin_response                              Prevotella  0.12
# 28        inulin_response                             Bacteroides -0.66
# 33        inulin_response                             Coprococcus -0.65
# 40   pairwise_interaction                  ('Blautia', 'Blautia') -3.91
# 41   pairwise_interaction         ('Blautia', 'Faecalibacterium') -3.30
# 42   pairwise_interaction          ('Blautia', 'Bifidobacterium') -3.51
# 82   pairwise_interaction  ('Bifidobacterium', 'Bifidobacterium')  1.35
# 161  pairwise_interaction      ('Prevotella', 'Faecalibacterium')  0.23
# 166  pairwise_interaction            ('Prevotella', 'Prevotella') -6.48
#
#      Right  Middle        SNR  Significant
# 6    -0.02  -0.505  -2.050357         True
# 22    2.19   1.880  12.046869         True
# 24    1.56   1.250   7.995026         True
# 26    0.73   0.425   2.720541         True
# 28   -0.04  -0.350  -2.239965         True
# 33   -0.03  -0.340  -2.163012         True
# 40   -1.19  -2.550  -3.696627         True
# 41   -0.11  -1.705  -2.138517         True
# 42   -0.87  -2.190  -3.272662         True
# 82    3.97   2.660   3.995891         True
# 161   3.40   1.815   2.260957         True
# 166  -4.34  -5.410  -9.988830         True
