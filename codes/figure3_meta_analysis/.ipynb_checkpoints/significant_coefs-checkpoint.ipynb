# %%
import pandas as pd

# %%
df = None
folders = ['healey_2018_BJN', 'baxter_2019_mbio', 'vandeputte_2017_gut','creswell_2020_GM']
for k,f in enumerate(folders):
    _df = pd.read_excel('%s/bayesian_regression_summary.xlsx'%(f), index_col=0)
    _df = _df[_df.Significant==True]
    _df['Study'] = f
    if k==0:
        df = _df
    else:
        df = pd.concat([df,_df], axis=0)

# %%
df
# Out:
#                      Type                                               Taxa  \
# 6       basal_growth_rate                                         Prevotella
# 22         fiber_response                                    Bifidobacterium
# 24         fiber_response                                       Anaerostipes
# 26         fiber_response                                         Prevotella
# 40   pairwise_interaction                             ('Blautia', 'Blautia')
# 41   pairwise_interaction                    ('Blautia', 'Faecalibacterium')
# 42   pairwise_interaction                     ('Blautia', 'Bifidobacterium')
# 82   pairwise_interaction             ('Bifidobacterium', 'Bifidobacterium')
# 161  pairwise_interaction                 ('Prevotella', 'Faecalibacterium')
# 166  pairwise_interaction                       ('Prevotella', 'Prevotella')
# 8       basal_growth_rate                                    Bifidobacterium
# 21         fiber_response                                   Faecalibacterium
# 23         fiber_response  Trichuris_dash_trichiura_dash__leftroundbracke...
# 28         fiber_response                                    Bifidobacterium
# 30         fiber_response                                       Anaerostipes
# 42   pairwise_interaction                 ('Bacteroides', 'Lachnospiraceae')
# 43   pairwise_interaction  ('Bacteroides', 'Trichuris_dash_trichiura_dash...
# 48   pairwise_interaction                 ('Bacteroides', 'Bifidobacterium')
# 61   pairwise_interaction           ('Faecalibacterium', 'Faecalibacterium')
# 112  pairwise_interaction  ('Trichuris_dash_trichiura_dash__leftroundbrac...
# 145  pairwise_interaction                       ('Prevotella', 'Prevotella')
# 200  pairwise_interaction                 ('Bifidobacterium', 'Bacteroides')
# 208  pairwise_interaction             ('Bifidobacterium', 'Bifidobacterium')
# 22         fiber_response                                    Lachnospiraceae
# 29         fiber_response                                       Anaerostipes
# 32         fiber_response                                    Bifidobacterium
# 40   pairwise_interaction                     ('Bacteroides', 'Bacteroides')
# 41   pairwise_interaction                ('Bacteroides', 'Faecalibacterium')
# 43   pairwise_interaction  ('Bacteroides', 'Ruminococcus_dash_sp_dot__das...
# 46   pairwise_interaction                         ('Bacteroides', 'Blautia')
# 51   pairwise_interaction  ('Bacteroides', 'Christensenellaceae_dash_R_da...
# 61   pairwise_interaction           ('Faecalibacterium', 'Faecalibacterium')
# 292  pairwise_interaction             ('Bifidobacterium', 'Bifidobacterium')
# 50   pairwise_interaction     ('Lachnospiraceae', 'Akkermansia_muciniphila')
# 58   pairwise_interaction      ('Lachnospiraceae', 'Roseburia_intestinalis')
# 75   pairwise_interaction  ('Faecalibacterium_prausnitzii', 'Gemmiger_for...
# 164  pairwise_interaction        ('Prevotella_copri', 'Anaerostipes_hadrus')
# 165  pairwise_interaction  ('Prevotella_copri', 'Bifidobacterium_adolesce...
# 166  pairwise_interaction           ('Prevotella_copri', 'Prevotella_copri')
# 229  pairwise_interaction           ('Roseburia_faecis', 'Roseburia_faecis')
# 244  pairwise_interaction  ('Akkermansia_muciniphila', 'Anaerostipes_hadr...
# 245  pairwise_interaction  ('Akkermansia_muciniphila', 'Bifidobacterium_a...
# 250  pairwise_interaction  ('Akkermansia_muciniphila', 'Akkermansia_mucin...
#
#      Left  Right  Middle        SNR  Significant                Study
# 6   -1.00  -0.03  -0.515  -2.052566         True      healey_2018_BJN
# 22   0.10   0.14   0.120  12.336286         True      healey_2018_BJN
# 24   0.06   0.10   0.080   8.065097         True      healey_2018_BJN
# 26   0.01   0.05   0.030   2.737115         True      healey_2018_BJN
# 40  -3.96  -1.20  -2.580  -3.685521         True      healey_2018_BJN
# 41  -3.29  -0.13  -1.710  -2.181092         True      healey_2018_BJN
# 42  -3.48  -0.86  -2.170  -3.268102         True      healey_2018_BJN
# 82   1.33   3.93   2.630   3.994283         True      healey_2018_BJN
# 161  0.21   3.40   1.805   2.238596         True      healey_2018_BJN
# 166 -6.46  -4.34  -5.400 -10.151601         True      healey_2018_BJN
# 8    0.04   1.05   0.545   2.093838         True     baxter_2019_mbio
# 21   0.01   0.04   0.025   3.879450         True     baxter_2019_mbio
# 23   0.01   0.04   0.025   2.899654         True     baxter_2019_mbio
# 28   0.02   0.05   0.035   5.346078         True     baxter_2019_mbio
# 30   0.01   0.04   0.025   2.876799         True     baxter_2019_mbio
# 42  -4.75  -1.14  -2.945  -3.218318         True     baxter_2019_mbio
# 43  -3.53  -0.67  -2.100  -2.891421         True     baxter_2019_mbio
# 48  -4.07  -0.58  -2.325  -2.644192         True     baxter_2019_mbio
# 61   0.57   3.95   2.260   2.647707         True     baxter_2019_mbio
# 112 -3.47  -0.30  -1.885  -2.364622         True     baxter_2019_mbio
# 145  0.71   3.77   2.240   2.909484         True     baxter_2019_mbio
# 200 -1.73  -0.17  -0.950  -2.417836         True     baxter_2019_mbio
# 208  4.48   8.02   6.250   6.954381         True     baxter_2019_mbio
# 22   0.01   0.06   0.035   2.753969         True  vandeputte_2017_gut
# 29   0.01   0.06   0.035   2.738454         True  vandeputte_2017_gut
# 32   0.02   0.07   0.045   3.269076         True  vandeputte_2017_gut
# 40   0.49   1.92   1.205   3.298998         True  vandeputte_2017_gut
# 41  -7.67  -4.90  -6.285  -8.951352         True  vandeputte_2017_gut
# 43   0.60   4.22   2.410   2.642690         True  vandeputte_2017_gut
# 46  -3.72  -0.09  -1.905  -2.074094         True  vandeputte_2017_gut
# 51   0.21   3.92   2.065   2.189751         True  vandeputte_2017_gut
# 61   1.53   4.28   2.905   4.193006         True  vandeputte_2017_gut
# 292  0.36   3.93   2.145   2.360378         True  vandeputte_2017_gut
# 50   0.11   1.63   0.870   2.270559         True     creswell_2020_GM
# 58   0.59   3.42   2.005   2.780318         True     creswell_2020_GM
# 75   0.20   3.54   1.870   2.234029         True     creswell_2020_GM
# 164 -2.41  -0.63  -1.520  -3.372511         True     creswell_2020_GM
# 165  0.28   1.87   1.075   2.674802         True     creswell_2020_GM
# 166  0.17   1.18   0.675   2.628095         True     creswell_2020_GM
# 229  0.11   2.22   1.165   2.202735         True     creswell_2020_GM
# 244 -2.08  -0.30  -1.190  -2.648681         True     creswell_2020_GM
# 245 -1.59  -0.02  -0.805  -2.011412         True     creswell_2020_GM
# 250 -2.49  -0.97  -1.730  -4.480156         True     creswell_2020_GM
