# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from random import random
from scipy.optimize import minimize
from numpy import array
from sklearn.metrics import r2_score
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read metadata

# %%
df_meta = pd.read_csv('../../our_data/meta_data.csv', index_col=0)
df_scfa = pd.read_csv('../../our_data/SCFA.csv', index_col=0)
df_meta_scfa = pd.merge(df_meta, df_scfa, left_index=True, right_index=True, how='inner')
df_meta_scfa.head()
# Out:
#           MiceID   Vendor  Day     Diet RandomizedGroup    Acetate  \
# SampleID
# sample131    BC1  Beijing    0  Control               C  20.205741
# sample132    BC2  Beijing    0  Control               B  15.789550
# sample133    BC3  Beijing    0  Control               A  25.064928
# sample134    BC4  Beijing    0  Control               D  16.980939
# sample135    BC5  Beijing    0  Control               E  21.801265
#
#            Propionate  Butyrate      Total
# SampleID
# sample131    3.297966  2.729283  26.741973
# sample132    2.520570  2.439410  21.178312
# sample133    5.569482  2.176445  34.101622
# sample134    3.224844  2.513462  23.310672
# sample135    4.224119  3.107713  29.891000

# %% [markdown]
# # Fit harmonic oscillator model (for each SCFA and each mice)

# %%
def overdampling(params,xdata):
    k1,k2,D,H,Ai = params
    ypred = H/k1/k2+((D+k2*Ai-H/k1)*np.exp(-k1*xdata)-(D+k1*Ai-H/k2)*np.exp(-k2*xdata))/(k2-k1)
    return ypred

# %%
def residual(params,xdata,ydata):
    ypred = overdampling(params,xdata)
    return -r2_score(ydata, ypred)

# %% [markdown]
# ## inulin

# %%
df_meta_scfa_inulin = df_meta_scfa[df_meta_scfa.Diet=='Inulin']
all_mice = list(set(df_meta_scfa_inulin.MiceID))
initial_condition = 'fixedIC' # free initial condition or fixed initial condition

lines = []
for i, scfa_ in enumerate(['Acetate','Propionate','Butyrate','Total']):
    for j, mice_ in enumerate(all_mice):
        curr_df = df_meta_scfa_inulin[df_meta_scfa_inulin.MiceID==mice_].sort_values(by='Day')
        vendor_ = list(set(curr_df.Vendor))[0]
        
        # get X and Y data
        xdata = np.array(curr_df.Day)
        ydata = np.array(curr_df[scfa_])

        # model fitting
        min_obj_over = 1e10
        best_sol_over = None
        trial=0
        while trial < 100:
            try:
                if initial_condition=='freeIC':
                    res = minimize(residual, 
                                   [random(),random(),random(),random(),random()], 
                                   args=(xdata,ydata),
                                   bounds = ((0, 1), (0, 1), (0, None), (0, None), (0,None)),
                                   method='Powell', # Powell
                                   tol=1e-8,
                                   options={'maxiter':1000}
                                  )
                elif initial_condition=='fixedIC':
                    res = minimize(residual, 
                       [random(),random(),random(),random(),ydata[0]], 
                       args=(xdata,ydata),
                       bounds = ((0, 1), (0, 1), (0, None), (0, None), (ydata[0],ydata[0])),
                       method='Powell', # Powell
                       tol=1e-8,
                       options={'maxiter':1000}
                      )
                else:
                    print('unknown initial condition: %s'%(initial_condition))
                    raise
                assert res.success==True
                if res.fun < min_obj_over:
                    best_sol_over = res.x
                    min_obj_over = res.fun
                trial += 1
            except:
                pass
        print(scfa_, mice_)
        print(best_sol_over)
        lines.append([mice_, vendor_, scfa_] + list(best_sol_over) + [r2_score(ydata, overdampling(best_sol_over, xdata))])

    # write to file
    df_bfit = pd.DataFrame(lines, columns=['MiceID','Vendor','SCFA','k1','k2','D','H','Ai','R2'])
    df_bfit['zeta'] = [(k1+k2)/2/np.sqrt(k1*k2) for k1,k2 in zip(df_bfit['k1'],df_bfit['k2'])]
    df_bfit.to_csv('best_fit_parameters_inulin_r2_%s.csv'%(initial_condition))
# Out:
# Acetate GI4
# [0.03023044 0.28954908 7.93554741 0.0167699  8.4866322 ]
# Acetate GI3
# [ 0.42694985  0.4269503  18.90834302  3.73490798  8.6126283 ]
# Acetate BI1
# [ 0.57480079  0.57480041 23.76109175  5.38860023  5.23389922]
# Acetate HI5
# [ 0.23522746  0.23522739  4.65063896  0.66296165 13.79321843]
# Acetate HI2
# [ 0.39003852  0.39003865 15.52487899  2.13348848  2.06124266]
# Acetate SI1
# [ 0.22256115  0.22256115 17.03300103  0.37051636  3.65146118]
# Acetate SI4
# [ 0.0784891   1.         18.87516684  0.86393623  7.91718273]
# Acetate SI5
# [ 0.2899772   0.28997721  7.6953416   1.12961841 10.29078305]
# Acetate HI4
# [ 0.0881517   0.08815301  1.31528809  0.07215377 11.09616374]
# Acetate GI1
# [3.73339165e-09 3.46384662e-01 2.62972364e+00 7.41841213e-02
#  1.24667730e+01]
# Acetate BI4
# [3.73768597e-09 9.99999982e-01 4.93123126e+00 1.11894517e-01
#  1.25803680e+01]
# Acetate BI2
# [ 0.08110385  0.08110367  1.40277012  0.05113775 13.45982298]
# Acetate HI1
# [5.60683174e-02 5.59675840e-02 1.71015967e+00 5.99786560e-10
#  9.12634780e+00]
# Acetate BI3
# [ 0.77825096  0.77825232 45.88832973 10.19195487 18.07537795]
# Acetate SI2
# [ 0.30686706  0.30686706  8.59156445  1.20222658 20.0154278 ]
# Acetate GI2
# [4.11071512e-03 6.01971524e-01 6.37099199e+00 4.35498042e-10
#  8.10601560e+00]
# Acetate SI3
# [ 0.43577074  0.43577095 16.09861265  1.79686622  5.0557566 ]
# Acetate BI5
# [ 1.          0.06395836 11.96316115  0.66300327  8.06512734]
# Propionate GI4
# [1.27886597e-02 1.00000000e+00 1.00311096e+01 2.51761220e-10
#  2.03531466e+00]
# Propionate GI3
# [ 0.37338079  0.37338083 12.66267044  1.36132638  1.96243106]
# Propionate BI1
# [ 0.24521357  0.84627063 16.61493525  1.07107513  1.93093338]
# Propionate HI5
# [0.69099934 0.01886406 6.15238486 0.11113005 3.73432545]
# Propionate HI2
# [0.27238869 0.27238869 7.75670796 0.86373365 1.14031156]
# Propionate SI1
# [8.51804773e-09 9.99999995e-01 2.69037293e+00 8.20911834e-02
#  7.21203306e-01]
# Propionate SI4
# [1.01925136e-09 9.99989807e-01 1.67219505e+00 7.34540214e-02
#  2.16615356e+00]
# Propionate SI5
# [1.24583357e-06 8.03398464e-07 4.08627946e-02 1.10796865e-02
#  2.17005998e+00]
# Propionate HI4
# [0.1071911  0.22479782 4.84953025 0.18632686 4.15631187]
# Propionate GI1
# [0.32858943 0.32858944 7.18878    0.91220946 2.24424584]
# Propionate BI4
# [1.73922546e-01 3.19133407e-02 1.81040328e+00 9.60899985e-12
#  3.14877291e+00]
# Propionate BI2
# [ 0.68837893  1.         21.04596661  4.51218727  3.62177133]
# Propionate HI1
# [ 0.99999999  0.99999991 20.68847365  6.7142188   3.0444339 ]
# Propionate BI3
# [ 0.89527284  0.89526793 41.04150775  5.8887988   2.85991567]
# Propionate SI2
# [1.77374785e-08 5.22380728e-04 9.18485586e-04 1.14515646e-02
#  3.24210555e+00]
# Propionate GI2
# [ 0.0612455   1.         13.3006127   0.2593788   1.43897784]
# Propionate SI3
# [3.73764271e-09 9.99999970e-01 1.50464431e+00 1.14137990e-01
#  1.41105087e+00]
# Propionate BI5
# [0.20451801 0.20451801 4.63890994 0.21286616 3.13420936]
# Butyrate GI4
# [4.40380424e-02 2.45633149e-01 3.70782280e+00 1.00692244e-10
#  1.86793103e+00]
# Butyrate GI3
# [0.40439334 0.14281201 5.50065832 0.22968183 2.30184606]
# Butyrate BI1
# [0.4508261  0.45082617 8.43280603 0.44236735 1.10958198]
# Butyrate HI5
# [0.15035938 0.15035939 1.84176597 0.06763851 3.21456067]
# Butyrate HI2
# [0.56976849 0.56976849 6.92598317 1.6990771  1.14214733]
# Butyrate SI1
# [0.17630185 0.17630175 5.12041435 0.07166153 1.16631506]
# Butyrate SI4
# [ 0.96783136  0.0945487  15.63001701  0.22608349  3.45168233]
# Butyrate SI5
# [0.20195603 0.20195604 6.2468347  0.15746099 1.81284881]
# Butyrate HI4
# [0.19932176 0.19932176 3.18223354 0.15718982 2.8045531 ]
# Butyrate GI1
# [0.17824843 0.17824839 2.07408133 0.17909274 3.63118175]
# Butyrate BI4
# [ 0.99999998  0.99999997 32.40095222  4.14964935  1.47768847]
# Butyrate BI2
# [0.11760667 0.11760714 1.59513977 0.01195383 1.54664719]
# Butyrate HI1
# [ 0.88266686  0.88266688 10.29695152  4.8286873   3.17374572]
# Butyrate BI3
# [ 0.99999998  0.99999998 12.14827145  3.9069009   1.6826558 ]
# Butyrate SI2
# [ 0.35012244  0.35012243 13.12176169  0.43436452  2.65363752]
# Butyrate GI2
# [0.09274841 0.38865162 4.71243491 0.09154984 0.94204398]
# Butyrate SI3
# [ 1.          0.18215441 17.28975671  0.62459041  1.20165388]
# Butyrate BI5
# [0.31951689 0.31951698 2.88481083 0.40388717 1.83517228]
# Total GI4
# [2.85022858e-02 3.08926794e-01 1.66869537e+01 2.70314275e-11
#  1.31223351e+01]
# Total GI3
# [ 0.38548738  0.38548739 37.94407985  5.37835434 13.60364211]
# Total BI1
# [ 0.52468627  0.5246865  49.29123157  6.86180804  8.7026931 ]
# Total HI5
# [ 0.22062039  0.22062043 10.28081266  1.33206322 22.20772216]
# Total HI2
# [ 0.39093376  0.39093378 30.66930765  4.89597232  4.56751401]
# Total SI1
# [ 0.22465825  0.22465822 24.71952672  0.86858619  5.81269826]
# Total SI4
# [ 1.          0.10171746 37.56639521  2.16199491 14.57331017]
# Total SI5
# [ 0.28950489  0.28950621 15.59401726  2.1657106  15.35263129]
# Total HI4
# [ 0.15165498  0.15165487  8.67301038  0.55277431 19.36155048]
# Total GI1
# [9.82690077e-01 9.62383066e-01 4.81666436e-11 3.97273453e+01
#  1.93732485e+01]
# Total BI4
# [ 0.82243938  0.9591505  62.14089257 25.2191504  17.61438059]
# Total BI2
# [1.79107485e-02 1.00000000e+00 1.76920423e+01 2.08256935e-02
#  1.92359320e+01]
# Total HI1
# [ 0.99999997  1.         25.37650087 31.25472924 16.50990602]
# Total BI3
# [  0.86193946   0.86193953 100.54280801  21.58148113  23.21775134]
# Total SI2
# [ 0.35539504  0.35539504 24.14091248  2.91351289 27.64792268]
# Total GI2
# [1.71474855e-02 7.47483187e-01 2.39102174e+01 3.44414981e-09
#  1.10293444e+01]
# Total SI3
# [ 0.48312547  0.48312581 35.15985079  4.50344625  8.28472943]
# Total BI5
# [ 0.23286499  0.23286496 13.18772935  1.18661084 13.57795091]

# %% [markdown]
# ## cellulose

# %%
df_meta_scfa_cellulose = df_meta_scfa[df_meta_scfa.Diet=='Control']
all_mice = list(set(df_meta_scfa_cellulose.MiceID))
initial_condition = 'fixedIC' # free initial condition or fixed initial condition

lines = []
for i, scfa_ in enumerate(['Acetate','Propionate','Butyrate','Total']):
    for j, mice_ in enumerate(all_mice):
        curr_df = df_meta_scfa_cellulose[df_meta_scfa_cellulose.MiceID==mice_].sort_values(by='Day')
        vendor_ = list(set(curr_df.Vendor))[0]
        
        # get X and Y data
        xdata = np.array(curr_df.Day)
        ydata = np.array(curr_df[scfa_])

        # model fitting
        min_obj_over = 1e10
        best_sol_over = None
        trial=0
        while trial < 100:
            try:
                if initial_condition=='freeIC':
                    res = minimize(residual, 
                                   [random(),random(),random(),random(),random()], 
                                   args=(xdata,ydata),
                                   bounds = ((0, 1), (0, 1), (0, None), (0, None), (0,None)),
                                   method='Powell', # Powell
                                   tol=1e-8,
                                   options={'maxiter':1000}
                                  )
                elif initial_condition=='fixedIC':
                    res = minimize(residual, 
                       [random(),random(),random(),random(),ydata[0]], 
                       args=(xdata,ydata),
                       bounds = ((0, 1), (0, 1), (0, None), (0, None), (ydata[0],ydata[0])),
                       method='Powell', # Powell
                       tol=1e-8,
                       options={'maxiter':1000}
                      )
                else:
                    print('unknown initial condition: %s'%(initial_condition))
                    raise
                assert res.success==True
                if res.fun < min_obj_over:
                    best_sol_over = res.x
                    min_obj_over = res.fun
                trial += 1
            except:
                pass
        print(scfa_, mice_)
        print(best_sol_over)
        lines.append([mice_, vendor_, scfa_] + list(best_sol_over) + [r2_score(ydata, overdampling(best_sol_over, xdata))])

    # write to file
    df_bfit = pd.DataFrame(lines, columns=['MiceID','Vendor','SCFA','k1','k2','D','H','Ai','R2'])
    df_bfit['zeta'] = [(k1+k2)/2/np.sqrt(k1*k2) for k1,k2 in zip(df_bfit['k1'],df_bfit['k2'])]
    df_bfit.to_csv('best_fit_parameters_cellulose_r2_%s.csv'%(initial_condition))
# Out:
# Acetate HC5
# [9.99999985e-01 9.99999955e-01 6.18336816e-08 5.62965506e+00
#  1.34543144e+01]
# Acetate BC1
# [ 0.99999999  0.99999999 18.61544129  7.25862594 20.20574092]
# Acetate BC4
# [3.78002619e-01 3.78001773e-01 5.79405410e-09 1.47389693e+00
#  1.69809388e+01]
# Acetate GC5
# [0.49881359 0.49881365 7.05267521 2.49917331 6.59674328]
# Acetate BC2
# [ 0.24148496  0.24148488  2.14785645  0.38138667 15.78955016]
# Acetate HC3
# [0.14264135 0.14264134 2.82702395 0.05823096 8.04422658]
# Acetate GC4
# [ 0.55316706  0.55316723 11.80479565  3.02496256  7.83399173]
# Acetate SC5
# [1.17914026e-08 9.99999996e-01 1.34532597e+00 8.59922744e-02
#  2.74873182e+00]
# Acetate BC5
# [9.99999982e-01 9.99999991e-01 3.22489312e-07 9.64571134e+00
#  2.18012645e+01]
# Acetate SC3
# [9.99999971e-01 9.99999968e-01 4.43013454e-08 5.56696744e+00
#  9.59736031e+00]
# Acetate BC3
# [ 0.99999998  0.99999995  9.72525539  9.02652852 25.06492835]
# Acetate SC2
# [1.36812189e-06 7.81331618e-07 1.02974035e-06 3.15093361e-03
#  5.60243034e+00]
# Acetate GC2
# [8.85495721e-07 1.13109004e-06 2.50532585e-01 1.54135365e-02
#  7.77405403e+00]
# Acetate SC4
# [8.65038271e-07 1.36202987e-06 6.06599554e-07 2.02952945e-02
#  3.76772844e+00]
# Acetate HC2
# [ 0.47828248  0.47828247  8.85528801  1.90155906 12.20430058]
# Acetate HC4
# [ 0.68122036  0.68122035 28.86266816  4.37615007 12.17608755]
# Acetate SC1
# [9.99999971e-01 9.99999975e-01 1.05416176e-08 2.90031840e+00
#  4.39951647e+00]
# Acetate HC1
# [1.12190743e-01 1.12189702e-01 5.98056206e-09 6.21747969e-02
#  1.35654253e+01]
# Acetate GC1
# [9.99999937e-01 9.99999935e-01 4.96609358e-07 8.74782781e+00
#  2.10666213e+01]
# Acetate GC3
# [1.20432296e-01 1.20432329e-01 1.66472029e+00 7.43018791e-03
#  1.12853340e+01]
# Propionate HC5
# [9.99999970e-01 9.99999972e-01 3.27881380e-08 1.51533187e+00
#  4.19672500e+00]
# Propionate BC1
# [0.99999996 0.99999997 5.3154629  2.26486107 3.29796565]
# Propionate BC4
# [1.         0.04001733 0.36471729 0.02528855 3.22484439]
# Propionate GC5
# [0.67084204 0.670842   2.37893993 0.95152743 1.50079464]
# Propionate BC2
# [5.13608623e-02 4.35110568e-01 8.96508437e-01 1.79311832e-11
#  2.52056999e+00]
# Propionate HC3
# [0.25162147 0.25162143 0.78076926 0.10632404 1.97630111]
# Propionate GC4
# [0.99999996 0.99999998 4.73667702 2.33139095 1.70013028]
# Propionate SC5
# [1.43582114e-05 1.71616698e-04 4.43963096e-09 7.32913647e-04
#  1.20541625e+00]
# Propionate BC5
# [9.99999994e-01 5.56107773e-01 4.68313830e-09 9.76912836e-01
#  4.22411890e+00]
# Propionate SC3
# [9.99999989e-01 9.99999995e-01 3.68637010e-08 1.21450950e+00
#  2.16591096e+00]
# Propionate BC3
# [0.99999996 0.99999999 2.56987837 1.89082046 5.56948232]
# Propionate SC2
# [7.39389617e-07 3.76367548e-07 1.48681011e-07 1.19059070e-03
#  1.29664195e+00]
# Propionate GC2
# [9.99999996e-01 1.13987676e-08 4.99690430e-01 1.96232889e-02
#  1.83038412e+00]
# Propionate SC4
# [8.22417602e-07 1.45815961e-06 7.80952708e-08 2.11037640e-03
#  1.24648078e+00]
# Propionate HC2
# [0.4696979  0.46969795 0.49536958 0.52761373 4.04070878]
# Propionate HC4
# [0.58094423 0.58094424 3.69102037 0.70154549 1.9763306 ]
# Propionate SC1
# [9.99999987e-01 9.99999987e-01 7.76299648e-09 8.82690039e-01
#  1.07693945e+00]
# Propionate HC1
# [9.99999977e-01 9.99999971e-01 6.72558241e-08 1.85794465e+00
#  5.04345712e+00]
# Propionate GC1
# [9.99999970e-01 9.99999973e-01 2.07870178e-08 1.84054976e+00
#  5.81007169e+00]
# Propionate GC3
# [5.24187477e-02 5.24163423e-02 2.12155917e-02 2.86238662e-10
#  2.37055629e+00]
# Butyrate HC5
# [9.99999934e-01 9.99999884e-01 8.35688497e-08 1.27490359e+00
#  1.97532916e+00]
# Butyrate BC1
# [0.1113903  0.99999999 0.01376322 0.05948292 2.7292827 ]
# Butyrate BC4
# [9.62681677e-02 9.58823903e-02 1.39236654e-01 2.32886314e-10
#  2.51346187e+00]
# Butyrate GC5
# [0.4274853  0.42748532 5.47023901 0.20639687 0.65768814]
# Butyrate BC2
# [1.25233505e-01 8.34446799e-02 4.61041155e-09 1.20602703e-16
#  2.43941010e+00]
# Butyrate HC3
# [0.14499068 0.14499075 0.47166392 0.01757885 1.2130759 ]
# Butyrate GC4
# [9.99999980e-01 9.99999991e-01 4.83931322e-09 1.81592063e+00
#  2.86500929e+00]
# Butyrate SC5
# [0.21842801 0.218428   0.3528187  0.04250295 0.60051203]
# Butyrate BC5
# [9.17145814e-02 9.17112981e-02 6.10142975e-09 5.97834107e-10
#  3.10771294e+00]
# Butyrate SC3
# [1.00000000e+00 3.10202899e-01 4.75667511e-09 2.18284217e-01
#  2.97490559e+00]
# Butyrate BC3
# [0.99999998 0.99999998 8.98360328 1.11480054 2.17644457]
# Butyrate SC2
# [9.99999967e-01 9.99999973e-01 7.42264484e-09 1.01240164e+00
#  1.24599674e+00]
# Butyrate GC2
# [2.62996490e-01 2.62996469e-01 6.19296642e-09 1.51994134e-01
#  1.36524381e+00]
# Butyrate SC4
# [0.7201029  0.72010292 2.72731373 0.6645687  1.00200568]
# Butyrate HC2
# [0.30127744 0.3012774  0.91693925 0.15498603 2.36402156]
# Butyrate HC4
# [0.4343611  0.43436112 4.20747443 0.3293037  1.42272943]
# Butyrate SC1
# [0.13025984 0.13025994 0.34897783 0.00359265 0.51247775]
# Butyrate HC1
# [9.99999960e-01 9.99999955e-01 5.61864820e-09 1.70920274e+00
#  2.92307613e+00]
# Butyrate GC1
# [9.99999982e-01 9.99999983e-01 2.89567923e-08 1.50595366e+00
#  3.61615894e+00]
# Butyrate GC3
# [1.24093877e-01 1.24095210e-01 3.53015167e-09 3.95543816e-10
#  3.67322255e+00]
# Total HC5
# [9.99999979e-01 9.99999945e-01 4.01859788e-08 8.88413957e+00
#  2.12200707e+01]
# Total BC1
# [ 0.99999999  0.99999999 34.50607575 10.93774011 26.74197261]
# Total BC4
# [1.49675035e-01 4.46135624e-01 6.19202109e-09 9.08030917e-01
#  2.33106717e+01]
# Total GC5
# [ 0.47678656  0.47678652 14.98753017  3.2090224   9.24104754]
# Total BC2
# [ 0.11745973  0.33096509  2.5147383   0.28214919 21.17831233]
# Total HC3
# [ 0.15287528  0.15287531  4.03924852  0.141714   12.05440509]
# Total GC4
# [ 0.57912287  0.57912258 13.31026294  5.03486456 13.15526868]
# Total SC5
# [5.02201437e-09 9.99999999e-01 1.79087749e+00 9.93031399e-02
#  4.93093731e+00]
# Total BC5
# [9.99999945e-01 9.99999945e-01 2.85083190e-07 1.36023316e+01
#  2.98909997e+01]
# Total SC3
# [9.99999974e-01 9.99999974e-01 1.14889581e-07 8.18765798e+00
#  1.59212999e+01]
# Total BC3
# [ 0.99999997  0.99999996 23.19083441 12.13604359 34.10162214]
# Total SC2
# [3.09460505e-07 1.35906346e-06 2.65270266e-07 4.69137608e-03
#  8.68037637e+00]
# Total GC2
# [3.73769516e-09 9.99999349e-01 2.04531315e+00 4.58562751e-01
#  1.16009566e+01]
# Total SC4
# [1.52574401e-06 4.99097684e-07 6.73036645e-08 2.40025573e-02
#  6.75342105e+00]
# Total HC2
# [ 0.42191408  0.42191412  8.97909169  2.36821702 20.26554336]
# Total HC4
# [ 0.58977664  0.58977665 34.98361283  4.87255299 16.14356332]
# Total SC1
# [3.67894098e-02 6.10039139e-02 1.29612448e-02 4.19610251e-10
#  6.30499002e+00]
# Total HC1
# [9.99999964e-01 9.99999959e-01 2.13050505e-08 1.33553794e+01
#  2.34649361e+01]
# Total GC1
# [9.99999953e-01 9.99999946e-01 4.70505635e-08 1.27941889e+01
#  3.21024837e+01]
# Total GC3
# [1.04129910e-01 1.04129904e-01 1.33840924e+00 5.42703661e-09
#  1.86653462e+01]

# %% [markdown]
# # Plot harmonic fitting for inulin mice

# %%
fig, ax = plt.subplots(figsize=(15, 10), nrows=4, ncols=4, sharex=True, sharey='row')
df_bfit = pd.read_csv('best_fit_parameters_inulin_r2_fixedIC.csv', index_col=0)

df_meta_scfa_inulin = df_meta_scfa[df_meta_scfa.Diet=='Inulin']
colors = ['#FFB300', # Vivid Yellow,
          '#803E75', # Strong Purple
          '#FF6800', # Vivid Orange
          '#A6BDD7', # Very Light Blue
          '#C10020'] # Vivid Red'
for i, scfa_ in enumerate(['Acetate','Propionate','Butyrate','Total']):
    for j, vendor_ in enumerate(['Beijing','Guangdong','Hunan','Shanghai']):
        curr_df = df_meta_scfa_inulin[df_meta_scfa_inulin.Vendor==vendor_]
        for k, mice_ in enumerate(set(curr_df.MiceID)):
            curr_df2 = curr_df[curr_df.MiceID==mice_].sort_values(by='Day')
            
            # get X and Y data
            xdata = np.array(curr_df2.Day)
            ydata = np.array(curr_df2[scfa_])
            ax[i,j].plot(xdata, ydata, marker='o', linestyle = 'None', markersize=8, color=colors[k])

            xdata_dense = np.linspace(0,31,100)
            best_sol_over = df_bfit.loc[(df_bfit.MiceID==mice_)&(df_bfit.SCFA==scfa_), ['k1','k2','D','H','Ai']].values[0]
            ypred = overdampling(best_sol_over, xdata_dense)
            ax[i,j].plot(xdata_dense, ypred, color=colors[k])
            ax[i,j].set_title(vendor_)
            ax[i,j].set_xlabel('Day')
            ax[i,j].set_ylabel(scfa_)
                
plt.tight_layout()

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("harmonic_fitting_scfa_inulin_fixedIC.svg", format="svg")

# %% [markdown]
# # Plot harmonic fitting for cellulose mice

# %%
fig, ax = plt.subplots(figsize=(15, 10), nrows=4, ncols=4, sharex=True, sharey='row')
df_bfit = pd.read_csv('best_fit_parameters_cellulose_r2_fixedIC.csv', index_col=0)

df_meta_scfa_inulin = df_meta_scfa[df_meta_scfa.Diet=='Control']
colors = ['#FFB300', # Vivid Yellow,
          '#803E75', # Strong Purple
          '#FF6800', # Vivid Orange
          '#A6BDD7', # Very Light Blue
          '#C10020'] # Vivid Red'
for i, scfa_ in enumerate(['Acetate','Propionate','Butyrate','Total']):
    for j, vendor_ in enumerate(['Beijing','Guangdong','Hunan','Shanghai']):
        curr_df = df_meta_scfa_inulin[df_meta_scfa_inulin.Vendor==vendor_]
        for k, mice_ in enumerate(set(curr_df.MiceID)):
            curr_df2 = curr_df[curr_df.MiceID==mice_].sort_values(by='Day')
            
            # get X and Y data
            xdata = np.array(curr_df2.Day)
            ydata = np.array(curr_df2[scfa_])
            ax[i,j].plot(xdata, ydata, marker='o', linestyle = 'None', markersize=8, color=colors[k])

            xdata_dense = np.linspace(0,31,100)
            best_sol_over = df_bfit.loc[(df_bfit.MiceID==mice_)&(df_bfit.SCFA==scfa_), ['k1','k2','D','H','Ai']].values[0]
            ypred = overdampling(best_sol_over, xdata_dense)
            ax[i,j].plot(xdata_dense, ypred, color=colors[k])
            ax[i,j].set_title(vendor_)
            ax[i,j].set_xlabel('Day')
            ax[i,j].set_ylabel(scfa_)
                
plt.tight_layout()

plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("harmonic_fitting_scfa_cellulose_fixedIC.svg", format="svg")

# %% [markdown]
# # Analyze individualized response for D and zeta

# %%
# combine inulin and cellulose results
df_bfit_cellulose = pd.read_csv('best_fit_parameters_cellulose_r2_fixedIC.csv', index_col=0)
df_bfit_cellulose['Diet'] = 'Control'
df_bfit_inulin = pd.read_csv('best_fit_parameters_inulin_r2_fixedIC.csv', index_col=0)
df_bfit_inulin['Diet'] = 'Inulin'
df_bfit = pd.concat([df_bfit_inulin, df_bfit_cellulose], ignore_index=True)
df_bfit['log10zeta'] = np.log10(df_bfit['zeta'])
df_bfit = df_bfit[['MiceID','SCFA','Vendor','Diet','D','log10zeta']]

# plot statistical comparison
fig, ax = plt.subplots(figsize=(15, 5), nrows=2, ncols=4, sharex=True, sharey='row')
PROPS = {
    'boxprops':{'facecolor':'none', 'edgecolor':'black'},
    'medianprops':{'color':'black'},
    'whiskerprops':{'color':'black'},
    'capprops':{'color':'black'}
}
order = ['Beijing','Guangdong','Hunan','Shanghai']
for i,par in enumerate(['D','log10zeta']):
    for j,scfa in enumerate(['Acetate','Propionate','Butyrate','Total']):
        _ = sns.swarmplot(x="Vendor", y=par, hue="Diet",data=df_bfit[df_bfit.SCFA==scfa], size=6, palette="Set2", dodge=True, ax=ax[i,j])
        _ = sns.boxplot(x="Vendor", y=par, hue="Diet", order=order,
                        data=df_bfit[df_bfit.SCFA==scfa], color=None, palette="Set2", 
                        dodge=True, ax=ax[i,j], showfliers=False, **PROPS)
        
        box_pairs=[("Beijing", "Guangdong"), ("Beijing", "Hunan"), ("Beijing", "Shanghai"),
                   ("Hunan", "Guangdong"), ("Shanghai", "Hunan"), ("Guangdong", "Shanghai")]
               
        for pair in box_pairs:
            # inulin
            xdata = list(df_bfit.loc[(df_bfit.SCFA==scfa)&(df_bfit.Diet=='Inulin')&(df_bfit.Vendor==pair[0]),par])
            ydata = list(df_bfit.loc[(df_bfit.SCFA==scfa)&(df_bfit.Diet=='Inulin')&(df_bfit.Vendor==pair[1]),par])
            try:
                _, p = stats.mannwhitneyu(xdata,ydata)
                if p<0.05:
                    print(scfa, 'inulin', par, pair[0], pair[1], p)
            except:
                pass
                
            # cellulose
            xdata = list(df_bfit.loc[(df_bfit.SCFA==scfa)&(df_bfit.Diet=='Control')&(df_bfit.Vendor==pair[0]),par])
            ydata = list(df_bfit.loc[(df_bfit.SCFA==scfa)&(df_bfit.Diet=='Control')&(df_bfit.Vendor==pair[1]),par])
            try:
                _, p = stats.mannwhitneyu(xdata,ydata)
                if p<0.05:
                    print(scfa, 'cellulose', par, pair[0], pair[1], p)
            except:
                pass
        
# save figure
plt.rcParams['svg.fonttype'] = 'none'
fig.savefig("individualized_response_harmonic_model_D_log10zeta.svg", format="svg")
# Out:
# Acetate inulin D Shanghai Hunan 0.03309628986109672
# Acetate cellulose D Guangdong Shanghai 0.047346471299737944
# Propionate inulin D Beijing Shanghai 0.01078587397386046
# Propionate cellulose D Beijing Shanghai 0.047346471299737944
# Propionate inulin D Shanghai Hunan 0.009982226652608022
# Propionate inulin D Guangdong Shanghai 0.009982226652608022
# Propionate cellulose D Guangdong Shanghai 0.030051402969433157
# Butyrate inulin D Guangdong Shanghai 0.01866820796033144
# Acetate cellulose log10zeta Beijing Shanghai 0.036002828777749005
# Acetate cellulose log10zeta Shanghai Hunan 0.036002828777749005
# Propionate cellulose log10zeta Beijing Hunan 0.036002828777749005
# Propionate inulin log10zeta Beijing Shanghai 0.018072571023281126
# Propionate inulin log10zeta Shanghai Hunan 0.03253185343940995
# Propionate cellulose log10zeta Shanghai Hunan 0.036002828777749005
# Propionate inulin log10zeta Guangdong Shanghai 0.03253185343940995
# Butyrate inulin log10zeta Beijing Guangdong 0.020810031464182765
# Butyrate cellulose log10zeta Beijing Guangdong 0.036002828777749005
# Butyrate cellulose log10zeta Beijing Hunan 0.036002828777749005
# Butyrate inulin log10zeta Hunan Guangdong 0.034459222144751014
# Total inulin log10zeta Hunan Guangdong 0.034459222144751014
# Total cellulose log10zeta Shanghai Hunan 0.012684929911026828
